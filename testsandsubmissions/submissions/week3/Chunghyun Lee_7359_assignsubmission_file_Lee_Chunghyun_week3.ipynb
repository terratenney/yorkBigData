# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### PART TWO: DATA

# %%
gnac_col = "id|postedTime|body|None|['twitter_entiteis:urls:url']|['None']|['actor:languages_list-items']|gnip:language:value|twitter_lang|[u'geo:coordinates_list-items']|geo:type|None|None|None|None|actor:utcOffset|None|None|None|None|None|None|None|None|None|actor:displayName|actor:preferredUsername|actor:id|gnip:klout_score|actor:followersCount|actor:friendsCount|actor:listedCount|actor:statusesCount|Tweet|None|None|None"
x_names = gnac_col.split('|')

# %%
pd.set_option("display.max_columns", None)

dframe1 = pd.read_csv('./Data/twitter_sample.csv', sep='|', names=x_names)

dframe1.tail(7)
# Out:
#                                                 id                postedTime  \
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 88                             @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# ...

# %%
print dframe1.columns
print dframe1.drop([u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10',
       u'None.11', u'None.12', u'None.13'],axis=1).columns
# Out:
# Index([u'id', u'postedTime', u'body', u'None',
#        u'['twitter_entiteis:urls:url']', u'['None']',
#        u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
#        u'None.1', u'None.2', u'None.3', u'None.4', u'actor:utcOffset',
#        u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10',
#        u'None.11', u'None.12', u'None.13', u'actor:displayName',
#        u'actor:preferredUsername', u'actor:id', u'gnip:klout_score',
#        u'actor:followersCount', u'actor:friendsCount', u'actor:listedCount',
#        u'actor:statusesCount', u'Tweet', u'None.14', u'None.15', u'None.16'],
#       dtype='object')
# Index([u'id', u'postedTime', u'body', u'None',
#        u'['twitter_entiteis:urls:url']', u'['None']',
#        u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
# ...

# %%
dframe1.tail(6)
# Out:
#                                                 id                postedTime  \
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# 92  O matheus André ta me falando aqui , tem quase...  None
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...  None
# 94                                           😕 Hmm...  None
#
# ...

# %%
dframe1[dframe1.twitter_lang == 'en'].head()
# Out:
#                                                 id                postedTime  \
# 8   tag:search.twitter.com,2005:351835318028222465  2013-07-01T22:50:51.000Z
# 9   tag:search.twitter.com,2005:351835318346981377  2013-07-01T22:50:51.000Z
# 11  tag:search.twitter.com,2005:351835318024028161  2013-07-01T22:50:51.000Z
# 12  tag:search.twitter.com,2005:351835318497980416  2013-07-01T22:50:51.000Z
# 15  tag:search.twitter.com,2005:351835318724468737  2013-07-01T22:50:51.000Z
#
#                                                  body  None  \
# 8                                @pafcdan Aww good! X  None
# 9   Newest hobby: sending videos back and forth of...  None
# 11                              ~FINALLY OFF OF WORK~  None
# 12  Rubbing/massaging my feet is like giving me he...  None
# 15         @Hayley_Brownn Same!!!! Very sad times😞😞😞😞  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# ...

# %%
dframe2 = dframe1[["gnip:klout_score","actor:followersCount", "actor:friendsCount", "actor:listedCount"]]
dframe2.head()
# Out:
#   gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0               35                   178                 129
# 1               32                   144                 215
# 2               18                    37                  54
# 3               50                   438                 174
# 4               21                    12                   6
#
#    actor:listedCount
# 0                  0
# 1                  0
# 2                  0
# 3                  1
# 4                  0

# %%
dframe2.dtypes
# Out:
# gnip:klout_score        object
# actor:followersCount     int64
# actor:friendsCount       int64
# actor:listedCount        int64
# dtype: object

# %%
def floatify(val):
    if val == None or val == 'None':
        return 0.0
    else:
        return float(val)

# %%
dframe2['gnip:klout_score'] = dframe2 ['gnip:klout_score'].map(floatify)
dframe2.dtypes
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# gnip:klout_score        float64
# actor:followersCount      int64
# actor:friendsCount        int64
# actor:listedCount         int64
# dtype: object

# %%
dframe2 = dframe2.astype(float)
dframe2.dtypes
# Out:
# gnip:klout_score        float64
# actor:followersCount    float64
# actor:friendsCount      float64
# actor:listedCount       float64
# dtype: object

# %%
dframe2['fol/fr'] = dframe2['gnip:klout_score'] / dframe2['actor:followersCount']
dframe2.head()
# Out:
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0              35.0                 178.0               129.0
# 1              32.0                 144.0               215.0
# 2              18.0                  37.0                54.0
# 3              50.0                 438.0               174.0
# 4              21.0                  12.0                 6.0
#
#    actor:listedCount    fol/fr
# 0                0.0  0.196629
# 1                0.0  0.222222
# 2                0.0  0.486486
# 3                1.0  0.114155
# 4                0.0  1.750000

# %%
dframe2.describe()
# Out:
#        gnip:klout_score  actor:followersCount  actor:friendsCount  \
# count         95.000000             95.000000           95.000000
# mean          37.842105           1062.747368          442.747368
# std            9.907354           4345.287974          609.239375
# min            0.000000              0.000000            1.000000
# 25%           33.000000            149.500000          125.500000
# 50%           39.000000            243.000000          231.000000
# 75%           43.000000            514.500000          436.500000
# max           64.000000          40543.000000         3802.000000
#
#        actor:listedCount     fol/fr
# count          95.000000  94.000000
# mean            7.494737   0.224291
# std            50.270306   0.251564
# min             0.000000   0.000000
# 25%             0.000000   0.066096
# 50%             0.000000   0.153499
# 75%             1.000000   0.271652
# max           486.000000   1.750000

# %%
# Grouping
dframe1.head()
# Out:
#                                                id                postedTime  \
# 0  tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1  tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 2  tag:search.twitter.com,2005:351835317747191808  2013-07-01T22:50:51.000Z
# 3  tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 4  tag:search.twitter.com,2005:351835317755592705  2013-07-01T22:50:51.000Z
#
#                                                 body  \
# 0                         kavga edelim ama konuşalım
# 1                              @shane_joersz wooooow
# 2                           お前との肌のふれあいなんぞ求めてない。自重しろ。
# 3  @Gabo_navoficial yo tambien creo en ti mi char...
# 4  только ты об этом не знаешь... http://t.co/MOH...
#
#                                                 None  \
# 0                                               None
# 1                                               None
# ...

# %%
popular_df = dframe1[dframe1["actor:followersCount"] >= 100]

# %%
popular_df['gnip:klout_score'] = popular_df['gnip:klout_score'].map(floatify)
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
popular_df.head()
# Out:
#                                                id                postedTime  \
# 0  tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1  tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 3  tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 5  tag:search.twitter.com,2005:351835317801730048  2013-07-01T22:50:51.000Z
# 6  tag:search.twitter.com,2005:351835317554257920  2013-07-01T22:50:51.000Z
#
#                                                 body  \
# 0                         kavga edelim ama konuşalım
# 1                              @shane_joersz wooooow
# 3  @Gabo_navoficial yo tambien creo en ti mi char...
# 5  I'm at Büyükçekmece Sahil w/ @emineetrk http:/...
# 6                          Dile Al Amor &gt;&gt;&gt;
#
#                             None ['twitter_entiteis:urls:url']  \
# 0                           None                          None
# ...

# %%
popular_df.groupby('twitter_lang').size()
# Out:
# twitter_lang
# ar      1
# en     34
# es     14
# fr      1
# he      1
# id      4
# it      2
# ja      1
# ko      1
# lv      1
# pl      1
# pt     10
# tr      5
# und     2
# vi      1
# dtype: int64

# %%
popular_df.groupby('twitter_lang').sum()
# Out:
#                  actor:id  gnip:klout_score  actor:followersCount  \
# twitter_lang
# ar             1438925934              40.0                   458
# en            12735573215            1330.0                 61069
# es             6280451207             553.0                 19030
# fr             1270875637              40.0                   116
# he             1318589041              37.0                   151
# id             2118954370             173.0                  1548
# it             1116298302              99.0                  7083
# ja               81327848              28.0                   152
# ko             1016681408              39.0                   170
# lv              323440706              41.0                   297
# pl             1041817357              48.0                  2037
# pt             3794723448             399.0                  4421
# tr             1640448378             160.0                  1449
# ...

# %%
popular_df.groupby('twitter_lang').mean()
# Out:
#                   actor:id  gnip:klout_score  actor:followersCount  \
# twitter_lang
# ar            1.438926e+09         40.000000            458.000000
# en            3.745757e+08         39.117647           1796.147059
# es            4.486037e+08         39.500000           1359.285714
# fr            1.270876e+09         40.000000            116.000000
# he            1.318589e+09         37.000000            151.000000
# id            5.297386e+08         43.250000            387.000000
# it            5.581492e+08         49.500000           3541.500000
# ja            8.132785e+07         28.000000            152.000000
# ko            1.016681e+09         39.000000            170.000000
# lv            3.234407e+08         41.000000            297.000000
# pl            1.041817e+09         48.000000           2037.000000
# pt            3.794723e+08         39.900000            442.100000
# tr            3.280897e+08         32.000000            289.800000
# ...

# %%
lang_GR = popular_df[['twitter_lang',\
             'gnip:klout_score',\
             'actor:followersCount',\
             'actor:friendsCount',\
             'actor:statusesCount']].groupby('twitter_lang')
lang_GR.head(2)
# Out:
#    twitter_lang  gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0            tr              35.0                   178                 129
# 1            es              32.0                   144                 215
# 3            es              50.0                   438                 174
# 5            tr              41.0                   226                 346
# 6            pt              42.0                   247                  64
# 8            en              38.0                   380                 860
# 9            en              41.0                   160                 135
# 16          und              53.0                  1179                 628
# 18           he              37.0                   151                 284
# 20           it              46.0                  1999                 293
# 21           pt              43.0                   137                  89
# ...

# %%
lang_GR_MN = lang_GR.aggregate(np.mean)
lang_GR_MN.head()
# Out:
#               gnip:klout_score  actor:followersCount  actor:friendsCount  \
# twitter_lang
# ar                   40.000000            458.000000          413.000000
# en                   39.117647           1796.147059          582.735294
# es                   39.500000           1359.285714          441.142857
# fr                   40.000000            116.000000          122.000000
# he                   37.000000            151.000000          284.000000
#
#               actor:statusesCount
# twitter_lang
# ar                    1061.000000
# en                   16364.352941
# es                    8953.357143
# fr                    3174.000000
# he                     641.000000

# %% [markdown]
# # PART THREE: PLOTTING

# %%
lang_GR_MN['actor:followersCount'].plot(kind='bar', color='r')

# %%
plt.scatter(x=lang_GR_MN['actor:followersCount'],\
           y=lang_GR_MN['actor:friendsCount'],\
           alpha=0.5,\
           s=50,\
           color='green',\
           marker='s')

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(lang_GR_MN, alpha=0.5, figsize=(12,12), diagonal='kde', s=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f863deba210>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f863daaa150>]], dtype=object)

# %%
datf = pd.DataFrame(np.random.randn(1000,4), index=pd.date_range('1/1/2000', periods=1000), columns=list('ABCD'))
datf= datf.cumsum()
datf.head()
# Out:
#                    A         B         C         D
# 2000-01-01  0.333979 -0.118154 -1.305955 -0.160953
# 2000-01-02 -1.234622 -0.134855  0.232027  1.749473
# 2000-01-03 -1.445356 -0.533627  0.970469  1.933249
# 2000-01-04 -3.313716 -1.686138 -0.539529  0.593857
# 2000-01-05 -3.321979 -1.704514 -1.132746 -0.230119

# %%
datf.plot()
datf.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8646331d90>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8646623d10>]], dtype=object)

# %%
import prettyplotlib

# %%
datf.plot()
datf.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8646711350>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f863c1447d0>]], dtype=object)

# %% [markdown]
# # Visualizing the distribution of a dataset

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, 'distributions')))

# %% [markdown]
# ### Plotting Univariate Dist.

# %%
a = np.random.normal(size=100)
sns.distplot(a);

# %%
sns.distplot(a, kde=False, rug=True);

# %%
sns.distplot(a, bins=20, kde=False, rug=True);

# %%
sns.distplot(a, hist=False, rug=True);

# %%
b = np.random.normal(0, 1, size=30)
band_w = 1.06 * b.std() * b.size ** (-1/5.)
spt= np.linspace(-4,4, 200)

krls = []
for b_i in b:
    
    krl = stats.norm(b_i, band_w).pdf(spt)
    krls.append(krl)
    plt.plot(spt, krl, color="g")
    
sns.rugplot(b, color=".2", linewidth=3);

# %%
dn = np.sum(krls, axis=0)
dn /= integrate.trapz(dn, spt)
plt.plot(spt, dn);

# %%
sns.kdeplot(b, shade=True);

# %%
sns.kdeplot(b)
sns.kdeplot(b, bw=.2, label="bw: 0.2")
sns.kdeplot(b, bw=2, label="bw: 2")
plt.legend();

# %%
sns.kdeplot(b, shade=True, cut=0)
sns.rugplot(b);

# %%
p = np.random.gamma(6, size=200)
sns.distplot(p, kde=False, fit=stats.gamma);

# %% [markdown]
# ### Plotting bivariate distributions

# %%
mn, cv = [0, 1], [(1, .5), (.5, 1)]
dat = np.random.multivariate_normal(mn, cv, 200)
dframe = pd.DataFrame(dat, columns=["x", "y"])

# %%
#Scatterplot
sns.jointplot(x="x", y="y", data=dframe);

# %%
#Hexbin plots

x, y = np.random.multivariate_normal(mn, cv, 1000).T
with sns.axes_style("white"):
    sns.jointplot(x=y, y=y, kind="hex", color="k");

# %%
#Kernel density estimation

sns.jointplot(x="x", y="y", data=dframe, kind='kde');

# %%
#2-D KD Plot

f, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(dframe.x, dframe.y, ax=ax)
sns.rugplot(dframe.x, color="g", ax=ax)
sns.rugplot(dframe.y, vertical=True, ax=ax);

# %%
f, ax = plt.subplots(figsize=(6,6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(dframe.x, dframe.y, cmap=cmap, n_levels=60, shade=True);

# %%
# joint plot

G2 = sns.jointplot(x='x', y='y', data=dframe, kind='kde', color='m')
G2.plot_joint(plt.scatter, c='w', s=30, linewidth=1, marker='+')
G2.ax_joint.collections[0].set_alpha(0)
G2.set_axis_labels('$X$', '$Y$');

# %% [markdown]
# # Visualizing Pairwise relationships in a Dataset

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris);

# %%
G3 = sns.PairGrid(iris)
G3.map_diag(sns.kdeplot)
G3.map_offdiag(sns.kdeplot, cmap="Blues_d", n_levels=6);
# Out:
# No handlers could be found for logger "matplotlib.legend"
# /bda/app/anaconda2/lib/python2.7/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)

# %% [markdown]
# # Visualizing Linear Relationships

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "regression")))

# %%
tips = sns.load_dataset('tips')

# %%
#Linear Regression Models
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
#x and y variables must be speced as strings
sns.lmplot(x='total_bill', y='tip', data=tips);

# %%
sns.lmplot(x='size', y='tip', data=tips);

# %%
sns.lmplot(x='size',y='tip', data=tips, x_jitter=.05);

# %%
sns.lmplot(x='size', y='tip', data=tips, x_estimator=np.mean);

# %% [markdown]
# ### Fitting different kinds of models

# %%
anscombe = sns.load_dataset('anscombe')

# %%
sns.lmplot(x='x', y='y', data=anscombe.query("dataset == 'I'"),
          ci=None, scatter_kws={"s": 80});

# %%
#polynominal regression model
sns.lmplot(x='x', y='y', data=anscombe.query("dataset == 'II'"),
           order=2, ci=None, scatter_kws={'s':80});

# %%
sns.lmplot(x='x', y='y', data=anscombe.query("dataset == 'III'"),
           ci=None, scatter_kws={'s': 80});

# %%
sns.lmplot(x='x', y='y', data=anscombe.query("dataset =='III'"), # " to embedded ' (Note to self)
           robust=True, ci=None, scatter_kws={'s': 80});

# %%
tips["big_tip"] = (tips.tip / tips.total_bill) > .15
sns.lmplot(x="total_bill", y="big_tip", data=tips,
          y_jitter=.03);

# %%
#logistic regression line
sns.lmplot(x='total_bill', y='big_tip', data=tips,
          logistic=True, y_jitter=.03);

# %%
#Lowess smoother #fit a non parametric regression
sns.lmplot(x='total_bill',y='tip',data=tips,lowess=True);

# %%
#residplot 
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'I'"),
              scatter_kws={"s": 80});

# %%
#If there is structure in the res, linear regression my not be appropriate
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'II'"),
              scatter_kws={"s": 80});

# %% [markdown]
# ### Conditioning on other var.

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips);

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips,
          markers=['o','x'], palette='Set2');

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', col='time', data=tips);

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker',
          col='time', row='sex', data=tips);

# %% [markdown]
# ### Controlling the size & shape of plots

# %%
#Regplots
f, ax = plt.subplots(figsize=(5,6))
sns.regplot(x="total_bill", y='tip', data=tips, ax=ax);

# %%
#lmplot
sns.lmplot(x="total_bill", y="tip", col="day", data=tips,
           col_wrap=3, size=3);

# %%
sns.lmplot(x="total_bill", y="tip", col="day", data=tips,
           aspect=.7);

# %% [markdown]
# ### Plotting a regression in other contexts

# %%
#REG
sns.jointplot(x='total_bill', y='tip',data=tips, kind='reg');

# %%
#pairplot
sns.pairplot(tips, x_vars=['total_bill','size'], y_vars=['tip'],
            size=4, aspect=.8, kind='reg');

# %%
#pairplot using hue 
sns.pairplot(tips, x_vars=['total_bill', 'size'], y_vars=['tip'],
             hue='smoker', size=5, aspect=.8, kind='reg');

# %% [markdown]
# # Plotting with categorical data

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
np.random.seed(sum(map(ord, "categorical")))

# %%
titan = sns.load_dataset("titanic")
tip = sns.load_dataset("tips")
ir = sns.load_dataset("iris")

# %% [markdown]
# ## Categorical scatterplots

# %%
sns.stripplot(x='day',y='total_bill', data=tip);

# %%
sns.stripplot(x='day', y='total_bill', data=tip, jitter=True)

# %%
#swarmplot avoids overlaps
sns.swarmplot(x='day', y='total_bill', data=tip);

# %%
#swarmplot hue parameter
sns.swarmplot(x='day',y='total_bill', hue='sex', data=tip);

# %%
sns.swarmplot(x='size', y='total_bill', data=tip);

# %%
sns.swarmplot(x='total_bill', y='day', hue='time', data=tip);

# %% [markdown]
# ## Distributions of observations within categories

# %%
#Boxplots
sns.boxplot(x='day', y='total_bill', hue='time', data=tip);

# %%
tip['weekend']=tip['day'].isin(['Sat','Sun'])
sns.boxplot(x='day', y='total_bill', hue='weekend', data=tip, dodge=False);

# %%
#ViolinPlots
sns.violinplot(x='total_bill', y='day', hue='time', data=tip);

# %%
sns.violinplot(x='total_bill', y='day', hue='time', data=tip,
              bw=.1, scale='count',scale_hue=False);

# %%
sns.violinplot(x='day',y='total_bill', hue='sex', data=tip, split=True);

# %%
sns.violinplot(x='day', y='total_bill', hue='sex', data=tip,
              split=True, inner='stick', palette='Set3');

# %%
sns.violinplot(x='day',y='total_bill',data=tip, inner=None)
sns.swarmplot(x='day', y='total_bill', data=tip, color='w', alpha=.5);

# %% [markdown]
# ## Statistical estimation within categories

# %%
#Barplots
sns.barplot(x='sex', y='survived', hue='class',data=titan);

# %%
sns.countplot(x='deck', data=titan, palette='Oranges_d');

# %%
sns.countplot(y='deck', hue='class', data=titan, palette='Blues_d');

# %%
#point plots
sns.pointplot(x='sex',y='survived', hue='class', data=titan);

# %%
sns.pointplot(x='class', y='survived', hue='sex', data=titan,
             palette={'male': 'r', 'female': 'm'},
             markers=['^','o'], linestyles=['-','--']);

# %% [markdown]
# ### Plotting 'wide-form' data

# %%
sns.boxplot(data=iris, orient='h');

# %%
#these fuctions accept vectors from pandas or numpy objects
sns.violinplot(x=iris.species, y=iris.sepal_length);

# %%
f, ax=plt.subplots(figsize=(8,5))
sns.countplot(y='deck', data=titan, color='c');

# %% [markdown]
# ### Drawing multi-panel categorical plots

# %%
sns.factorplot(x='day', y='total_bill', hue='smoker',data=tip);

# %%
#Kind=XXXX choose type of plots
sns.factorplot(x='day', y='total_bill', hue='smoker',data=tip, kind='bar');

# %%
#factorplot easy to facet the plot to investigate the role of other cata vari. 
sns.factorplot(x='day',y='total_bill', hue='smoker',
              col='time', data=tip, kind='swarm');

# %%
#size and aspect arguments
sns.factorplot(x='time',y='total_bill', hue='smoker',
              col='day',data=tip, kind='box', size=5, aspect=.5);

# %%
G1 = sns.PairGrid(tip,
                 x_vars=['smoker', 'time', 'sex'],
                 y_vars=['total_bill','tip'],
                 aspect=.75, size=3.5)
G1.map(sns.violinplot, palette='pastel');
