# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s1 = pd.Series([2,4,6,np.nan,7,9,10])
s1
# Out:
# 0     2.0
# 1     4.0
# 2     6.0
# 3     NaN
# 4     7.0
# 5     9.0
# 6    10.0
# dtype: float64

# %%
s1[5]
# Out:
# 9.0

# %%
s2, s3 = pd.Series(np.random.randn(6)), pd.Series(np.random.randn())

# %%
df_1 = pd.DataFrame({'A':s1,'B':s2,'C':s3})
df_1
# Out:
#       A         B         C
# 0   2.0  2.559859  0.229869
# 1   4.0 -1.140447 -0.182804
# 2   6.0  0.937987  0.157072
# 3   NaN  0.924140 -0.831929
# 4   7.0 -0.662979 -1.038206
# 5   9.0  0.065695  0.149959
# 6  10.0       NaN       NaN

# %%
s4 = pd.Series(np.random.randn(8))
df1=pd.DataFrame({'A':s1, 'B':s2,'C':s3,'D':s4})
df1
# Out:
#       A         B         C         D
# 0   2.0  2.559859  0.229869 -0.319492
# 1   4.0 -1.140447 -0.182804 -0.527066
# 2   6.0  0.937987  0.157072  0.205076
# 3   NaN  0.924140 -0.831929  0.511053
# 4   7.0 -0.662979 -1.038206 -0.793798
# 5   9.0  0.065695  0.149959 -1.085821
# 6  10.0       NaN       NaN  0.392063
# 7   NaN       NaN       NaN  0.802991

# %%
df2=pd.DataFrame(np.random.randn(7,5))
df2
# Out:
#           0         1         2         3         4
# 0 -1.331888  1.941725  0.675815 -0.069631  0.835731
# 1 -0.169098  0.655793  1.101188 -0.141214  0.174110
# 2 -0.199572 -1.100079 -1.162474  1.460206  1.281798
# 3  0.358105  0.476951  0.915348 -0.581206 -0.223412
# 4  0.243282 -0.021048 -1.054333  1.027946 -1.276031
# 5 -1.465941 -0.338590  0.067943  0.799570 -0.575995
# 6 -1.509794 -0.866249  1.011813  0.855635  0.867423

# %%
df2.head(3)
# Out:
#           0         1         2         3         4
# 0 -1.331888  1.941725  0.675815 -0.069631  0.835731
# 1 -0.169098  0.655793  1.101188 -0.141214  0.174110
# 2 -0.199572 -1.100079 -1.162474  1.460206  1.281798

# %%
cols = ['a','b','c','d', 'e']
df2.columns=cols
dates = pd.date_range(start='2014-12-25 12:45:13',freq='W', periods=7)
df2.index = dates
df2
# Out:
#                             a         b         c         d         e
# 2014-12-28 12:45:13 -1.331888  1.941725  0.675815 -0.069631  0.835731
# 2015-01-04 12:45:13 -0.169098  0.655793  1.101188 -0.141214  0.174110
# 2015-01-11 12:45:13 -0.199572 -1.100079 -1.162474  1.460206  1.281798
# 2015-01-18 12:45:13  0.358105  0.476951  0.915348 -0.581206 -0.223412
# 2015-01-25 12:45:13  0.243282 -0.021048 -1.054333  1.027946 -1.276031
# 2015-02-01 12:45:13 -1.465941 -0.338590  0.067943  0.799570 -0.575995
# 2015-02-08 12:45:13 -1.509794 -0.866249  1.011813  0.855635  0.867423

# %%
print 'what is a date_range object?\n\n', dates
# Out:
# what is a date_range object?
#
# DatetimeIndex(['2014-12-28 12:45:13', '2015-01-04 12:45:13',
#                '2015-01-11 12:45:13', '2015-01-18 12:45:13',
#                '2015-01-25 12:45:13', '2015-02-01 12:45:13',
#                '2015-02-08 12:45:13'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
df2.loc['2015-02-01 12:45:13']
# Out:
# a   -1.465941
# b   -0.338590
# c    0.067943
# d    0.799570
# e   -0.575995
# Name: 2015-02-01 12:45:13, dtype: float64

# %%
df2.loc['2015-02-08 12:45:13','e']
# Out:
# 0.86742310154534485

# %%
df1=pd.DataFrame(np.random.randn(7,4), index=list('abcdefg'),columns=list('HIJK'))
df1
# Out:
#           H         I         J         K
# a -0.165090  0.301047  2.849999 -0.175357
# b -0.254115 -0.836842 -0.683818  0.958494
# c -0.183829  0.258688  1.571049 -1.105861
# d -1.744305  1.534530  1.170453 -0.330492
# e  1.399184  1.398369 -1.662736 -0.265283
# f -0.304473  1.230041  0.028819 -1.793655
# g  0.287515  0.147003  0.905321  0.000071

# %%
df1.loc[['e','g'],'I':'K']
# Out:
#           I         J         K
# e  1.398369 -1.662736 -0.265283
# g  0.147003  0.905321  0.000071

# %%
gnacs_x = "id|postedTime|body|None|['twitter_entiteis:urls:url']|['None']|['actor:languages_list-items']|gnip:language:value|twitter_lang|[u'geo:coordinates_list-items']|geo:type|None|None|None|None|actor:utcOffset|None|None|None|None|None|None|None|None|None|actor:displayName|actor:preferredUsername|actor:id|gnip:klout_score|actor:followersCount|actor:friendsCount|actor:listedCount|actor:statusesCount|Tweet|None|None|None"
colnames = gnacs_x.split('|')

# %%
pd.set_option("display.max_columns",None)
df1=pd.read_csv('../data/twitter_sample.csv',sep='|',names=colnames)
df1.tail(7)
# Out:
#                                                 id                postedTime  \
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 88                             @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# 92  O matheus André ta me falando aqui , tem quase...  None
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...  None
# 94                                           😕 Hmm...  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 88                          None     None                         ['en']
# 89                          None     None                         ['it']
# 90                          None     None                         ['it']
# 91                          None     None                         ['pt']
# 92                          None     None                         ['pt']
# 93                          None     None                         ['en']
# 94                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 88                  en           vi      [53.28722009, -3.21569687]    Point
# 89                  it           it                            None     None
# 90                  it           it          [41.73604, 12.2890263]    Point
# 91                  pt           pt                            None     None
# 92                  pt           pt    [-22.72046574, -43.57919689]    Point
# 93                  en           en       [52.21599153, 6.88528201]    Point
# 94                None           en     [42.21746118, -78.03367083]    Point
#
#                                                None.1   None.2  \
# 88  ['[-3.400604, 53.072143999999994]', '[-3.40060...  Polygon
# 89  ['[14.1332005, 40.7920697]', '[14.1332005, 40....  Polygon
# 90  ['[12.2344266, 41.6558738]', '[12.2344266, 42....  Polygon
# 91  ['[-50.899727999999996, -21.454719]', '[-50.89...  Polygon
# 92  ['[-43.645123999999996, -22.783967999999998]',...  Polygon
# 93  ['[6.7559955, 52.1611799]', '[6.7559955, 52.28...  Polygon
# 94  ['[-78.045887, 42.212985]', '[-78.045887, 42.2...  Polygon
#
#                        None.3 None.4 actor:utcOffset  \
# 88     Flintshire, Flintshire     GB               0
# 89             Napoli, Napoli     IT            None
# 90                 Roma, Roma     IT            7200
# 91       Araçatuba, São Paulo     BR          -10800
# 92  Queimados, Rio de Janeiro     BR          -10800
# 93                   Enschede     NL            3600
# 94                Belmont, NY     US            None
#
#                            None.5 None.6 None.7 None.8 None.9 None.10 None.11  \
# 88  Leeds- UK / Greenfield- Wales   None   None   None   None    None    None
# 89         #bagdr @limitdemibagdr   None   None   None   None    None    None
# 90                  Big Ben's tip   None   None   None   None    None    None
# 91             na cama do mari :p   None   None   None   None    None    None
# 92                 Rio de Janeiro   None   None   None   None    None    None
# 93           Netherlands\Enschede   None   None   None   None    None    None
# 94                           None   None   None   None   None    None    None
#
#    None.12 None.13    actor:displayName actor:preferredUsername    actor:id  \
# 88    None    None              marshaa            marshaleighm   269323425
# 89    None    None                demi.               demibagdr  1542203100
# 90    None    None     She's my Louis ❤            xliamsdreams   562092674
# 91    None    None         lorena uai ∞            Fc_GritaAmor   397609113
# 92    None    None              Shelyda             ShelydaDays    70959019
# 93    None    None                    L                Karkooba  1252736376
# 94    None    None  Lindsey Chamberlain             Linnyy_Kayy   466042520
#
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 88               44                   767                 486
# 89               44                    64                  58
# 90               53                  5084                3802
# 91               44                  1248                1962
# 92               40                   128                  76
# 93               30                    48                  88
# 94               41                   198                 188
#
#     actor:listedCount  actor:statusesCount  Tweet  \
# 88                  0                17549  Reply
# 89                  0                 1872  Reply
# 90                 11                30163  Reply
# 91                  0                11161  Tweet
# 92                  0                 1419  Tweet
# 93                  0                  957  Reply
# 94                  0                 1897  Tweet
#
#                                               None.14 None.15 None.16
# 88  http://twitter.com/CheniseFowlisX/statuses/351...    None    None
# 89  http://twitter.com/justinbagdr/statuses/351833...    None    None
# 90  http://twitter.com/xhazzasdimples/statuses/351...    None    None
# 91                                               None    None    None
# 92                                               None    None    None
# 93  http://twitter.com/Mulayhim/statuses/351817617...    None    None
# 94                                               None    None    None

# %%
del df1['None']

# %%
df1.tail(6)
# Out:
#                                                 id                postedTime  \
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  \
# 89           @justinbagdr no, non mi far star meglio.
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...
# 91  Mandei a foto do Piqué e o fc n respondeu até ...
# 92  O matheus André ta me falando aqui , tem quase...
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...
# 94                                           😕 Hmm...
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 89                          None     None                         ['it']
# 90                          None     None                         ['it']
# 91                          None     None                         ['pt']
# 92                          None     None                         ['pt']
# 93                          None     None                         ['en']
# 94                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 89                  it           it                            None     None
# 90                  it           it          [41.73604, 12.2890263]    Point
# 91                  pt           pt                            None     None
# 92                  pt           pt    [-22.72046574, -43.57919689]    Point
# 93                  en           en       [52.21599153, 6.88528201]    Point
# 94                None           en     [42.21746118, -78.03367083]    Point
#
#                                                None.1   None.2  \
# 89  ['[14.1332005, 40.7920697]', '[14.1332005, 40....  Polygon
# 90  ['[12.2344266, 41.6558738]', '[12.2344266, 42....  Polygon
# 91  ['[-50.899727999999996, -21.454719]', '[-50.89...  Polygon
# 92  ['[-43.645123999999996, -22.783967999999998]',...  Polygon
# 93  ['[6.7559955, 52.1611799]', '[6.7559955, 52.28...  Polygon
# 94  ['[-78.045887, 42.212985]', '[-78.045887, 42.2...  Polygon
#
#                        None.3 None.4 actor:utcOffset                  None.5  \
# 89             Napoli, Napoli     IT            None  #bagdr @limitdemibagdr
# 90                 Roma, Roma     IT            7200           Big Ben's tip
# 91       Araçatuba, São Paulo     BR          -10800      na cama do mari :p
# 92  Queimados, Rio de Janeiro     BR          -10800          Rio de Janeiro
# 93                   Enschede     NL            3600    Netherlands\Enschede
# 94                Belmont, NY     US            None                    None
#
#    None.6 None.7 None.8 None.9 None.10 None.11 None.12 None.13  \
# 89   None   None   None   None    None    None    None    None
# 90   None   None   None   None    None    None    None    None
# 91   None   None   None   None    None    None    None    None
# 92   None   None   None   None    None    None    None    None
# 93   None   None   None   None    None    None    None    None
# 94   None   None   None   None    None    None    None    None
#
#       actor:displayName actor:preferredUsername    actor:id gnip:klout_score  \
# 89                demi.               demibagdr  1542203100               44
# 90     She's my Louis ❤            xliamsdreams   562092674               53
# 91         lorena uai ∞            Fc_GritaAmor   397609113               44
# 92              Shelyda             ShelydaDays    70959019               40
# 93                    L                Karkooba  1252736376               30
# 94  Lindsey Chamberlain             Linnyy_Kayy   466042520               41
#
#     actor:followersCount  actor:friendsCount  actor:listedCount  \
# 89                    64                  58                  0
# 90                  5084                3802                 11
# 91                  1248                1962                  0
# 92                   128                  76                  0
# 93                    48                  88                  0
# 94                   198                 188                  0
#
#     actor:statusesCount  Tweet  \
# 89                 1872  Reply
# 90                30163  Reply
# 91                11161  Tweet
# 92                 1419  Tweet
# 93                  957  Reply
# 94                 1897  Tweet
#
#                                               None.14 None.15 None.16
# 89  http://twitter.com/justinbagdr/statuses/351833...    None    None
# 90  http://twitter.com/xhazzasdimples/statuses/351...    None    None
# 91                                               None    None    None
# 92                                               None    None    None
# 93  http://twitter.com/Mulayhim/statuses/351817617...    None    None
# 94                                               None    None    None

# %%
df2 = df1[["gnip:klout_score","actor:followersCount", "actor:friendsCount", "actor:listedCount"]]

df2.head()
# Out:
#   gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0               35                   178                 129
# 1               32                   144                 215
# 2               18                    37                  54
# 3               50                   438                 174
# 4               21                    12                   6
#
#    actor:listedCount
# 0                  0
# 1                  0
# 2                  0
# 3                  1
# 4                  0

# %%
df2.dtypes
# Out:
# gnip:klout_score        object
# actor:followersCount     int64
# actor:friendsCount       int64
# actor:listedCount        int64
# dtype: object

# %%
def floatify(val):
    if val == None or val == 'None':
        return 0.0
    else:
        return float(val)

# %%
df2['gnip:klout_score']=df2['gnip:klout_score'].map(floatify)
df2.dtypes
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# gnip:klout_score        float64
# actor:followersCount      int64
# actor:friendsCount        int64
# actor:listedCount         int64
# dtype: object

# %%
df2=df2.astype(float)
df2.dtypes
# Out:
# gnip:klout_score        float64
# actor:followersCount    float64
# actor:friendsCount      float64
# actor:listedCount       float64
# dtype: object

# %%
df2['fol/fr']=df2['gnip:klout_score']/ df2['actor:followersCount']
df2.head()
# Out:
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0              35.0                 178.0               129.0
# 1              32.0                 144.0               215.0
# 2              18.0                  37.0                54.0
# 3              50.0                 438.0               174.0
# 4              21.0                  12.0                 6.0
#
#    actor:listedCount    fol/fr
# 0                0.0  0.196629
# 1                0.0  0.222222
# 2                0.0  0.486486
# 3                1.0  0.114155
# 4                0.0  1.750000

# %%
df1.head()
# Out:
#                                                id                postedTime  \
# 0  tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1  tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 2  tag:search.twitter.com,2005:351835317747191808  2013-07-01T22:50:51.000Z
# 3  tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 4  tag:search.twitter.com,2005:351835317755592705  2013-07-01T22:50:51.000Z
#
#                                                 body  \
# 0                         kavga edelim ama konuşalım
# 1                              @shane_joersz wooooow
# 2                           お前との肌のふれあいなんぞ求めてない。自重しろ。
# 3  @Gabo_navoficial yo tambien creo en ti mi char...
# 4  только ты об этом не знаешь... http://t.co/MOH...
#
#   ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 0                          None     None                         ['tr']
# 1                          None     None                         ['en']
# 2                          None     None                         ['ja']
# 3                          None     None                         ['en']
# 4                          None     None                         ['ru']
#
#   gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 0                  en           tr                            None     None
# 1                  en           es     [47.29088246, -101.0379045]    Point
# 2                  en           ja     [35.70675048, 139.84273005]    Point
# 3                  en           es                            None     None
# 4                  en           ru                            None     None
#
#                                               None.1   None.2         None.3  \
# 0  ['[25.663883, 35.817497]', '[25.663883, 42.109...  Polygon        Türkiye
# 1  ['[-101.043785, 47.275933]', '[-101.043785, 47...  Polygon   Washburn, ND
# 2  ['[139.8332175, 35.6345694444444]', '[139.8332...  Polygon      江戸川区, 東京都
# 3  ['[-80.248663, 25.986366]', '[-80.248663, 26.0...  Polygon  Hollywood, FL
# 4  ['[23.179216999999998, 51.2626423]', '[23.1792...  Polygon        Belarus
#
#   None.4 actor:utcOffset             None.5 None.6 None.7 None.8 None.9  \
# 0     TR            7200               None   None   None   None   None
# 1     US          -21600         sevenohone   None   None   None   None
# 2     JP          -36000                 ちば   None   None   None   None
# 3     US          -14400  hollywood florida   None   None   None   None
# 4     BY            None               None   None   None   None   None
#
#   None.10 None.11 None.12 None.13 actor:displayName actor:preferredUsername  \
# 0    None    None    None    None   Rümeysa Özdemir           uykugibisiyok
# 1    None    None    None    None        cori▲alex.                 CoBerg_
# 2    None    None    None    None              黒い恋人          yamasyoyamasyo
# 3    None    None    None    None             MARIA            maria_e_pena
# 4    None    None    None    None         Элька Алб                 ElkaAlb
#
#      actor:id gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0   248312738               35                   178                 129
# 1    48025164               32                   144                 215
# 2   217987801               18                    37                  54
# 3   461188787               50                   438                 174
# 4  1433828712               21                    12                   6
#
#    actor:listedCount  actor:statusesCount  Tweet  \
# 0                  0                 2028  Tweet
# 1                  0                 4071  Reply
# 2                  0                 3505  Tweet
# 3                  1                17636  Reply
# 4                  0                  145  Tweet
#
#                                              None.14 None.15 None.16
# 0                                               None    None    None
# 1  http://twitter.com/shane_joersz/statuses/35182...    None    None
# 2                                               None    None    None
# 3  http://twitter.com/Gabo_navoficial/statuses/35...    None    None
# 4                                               None    None    None

# %%
pop_df=df1[df1["actor:followersCount"]>=100]
pop_df['gnip:klout_score']=pop_df['gnip:klout_score'].map(floatify)
pop_df.groupby("twitter_lang").size()
pop_df.groupby("twitter_lang").sum()
pop_df.groupby("twitter_lang").mean()
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                   actor:id  gnip:klout_score  actor:followersCount  \
# twitter_lang
# ar            1.438926e+09         40.000000            458.000000
# en            3.745757e+08         39.117647           1796.147059
# es            4.486037e+08         39.500000           1359.285714
# fr            1.270876e+09         40.000000            116.000000
# he            1.318589e+09         37.000000            151.000000
# id            5.297386e+08         43.250000            387.000000
# it            5.581492e+08         49.500000           3541.500000
# ja            8.132785e+07         28.000000            152.000000
# ko            1.016681e+09         39.000000            170.000000
# lv            3.234407e+08         41.000000            297.000000
# pl            1.041817e+09         48.000000           2037.000000
# pt            3.794723e+08         39.900000            442.100000
# tr            3.280897e+08         32.000000            289.800000
# und           4.366732e+08         44.000000            703.500000
# vi            2.693234e+08         44.000000            767.000000
#
#               actor:friendsCount  actor:listedCount  actor:statusesCount
# twitter_lang
# ar                    413.000000           0.000000          1061.000000
# en                    582.735294          16.764706         16364.352941
# es                    441.142857           6.357143          8953.357143
# fr                    122.000000           0.000000          3174.000000
# he                    284.000000           0.000000           641.000000
# id                    245.500000           0.000000          8503.500000
# it                   2047.500000          19.000000         45199.500000
# ja                    335.000000           3.000000          2151.000000
# ko                    120.000000           0.000000          1094.000000
# lv                    237.000000           0.000000          5221.000000
# pl                   1984.000000           1.000000         23240.000000
# pt                    382.000000           0.100000         12694.400000
# tr                    220.800000           0.200000          7929.000000
# und                   406.500000           4.000000         22356.000000
# vi                    486.000000           0.000000         17549.000000

# %%
lang_gb=pop_df[['twitter_lang',\
               'gnip:klout_score',\
               'actor:followersCount',\
               'actor:friendsCount',\
               'actor:statusesCount']].groupby('twitter_lang')
lang_gb.head(2)
# Out:
#    twitter_lang  gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0            tr              35.0                   178                 129
# 1            es              32.0                   144                 215
# 3            es              50.0                   438                 174
# 5            tr              41.0                   226                 346
# 6            pt              42.0                   247                  64
# 8            en              38.0                   380                 860
# 9            en              41.0                   160                 135
# 16          und              53.0                  1179                 628
# 18           he              37.0                   151                 284
# 20           it              46.0                  1999                 293
# 21           pt              43.0                   137                  89
# 22           id              43.0                   258                 302
# 24           pl              48.0                  2037                1984
# 29           id              33.0                   404                 378
# 33           ko              39.0                   170                 120
# 38          und              35.0                   228                 185
# 42           ar              40.0                   458                 413
# 43           fr              40.0                   116                 122
# 64           ja              28.0                   152                 335
# 79           lv              41.0                   297                 237
# 88           vi              44.0                   767                 486
# 90           it              53.0                  5084                3802
#
#     actor:statusesCount
# 0                  2028
# 1                  4071
# 3                 17636
# 5                  7759
# 6                  2438
# 8                  3116
# 9                  4170
# 16                20141
# 18                  641
# 20                60236
# 21                 4047
# 22                 2732
# 24                23240
# 29                 9181
# 33                 1094
# 38                24571
# 42                 1061
# 43                 3174
# 64                 2151
# 79                 5221
# 88                17549
# 90                30163

# %%
lang_gb_mean=lang_gb.aggregate(np.mean)
lang_gb_mean.head()
# Out:
#               gnip:klout_score  actor:followersCount  actor:friendsCount  \
# twitter_lang
# ar                   40.000000            458.000000          413.000000
# en                   39.117647           1796.147059          582.735294
# es                   39.500000           1359.285714          441.142857
# fr                   40.000000            116.000000          122.000000
# he                   37.000000            151.000000          284.000000
#
#               actor:statusesCount
# twitter_lang
# ar                    1061.000000
# en                   16364.352941
# es                    8953.357143
# fr                    3174.000000
# he                     641.000000

# %%
lang_gb_mean['actor:followersCount'].plot(kind='bar',color='r')

# %%
plt.scatter(x=lang_gb_mean['actor:followersCount'],\
           y=lang_gb_mean['actor:friendsCount'],\
           alpha=0.5,\
           s=50,\
           color='blue',\
           marker='o')

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(lang_gb_mean, alpha=0.5, figsize=(12,12),diagonal='kde',s=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f32c978f690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32c96b8b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32c963ec10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32c9df7c90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f32c95f5390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32c95d1d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32c9552e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32c94c6890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f32c944bd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32c948c510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32c9344950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32c92cb7d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f32c923d4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32c91c5450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32c9129bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32c90b0c10>]], dtype=object)

# %%
df=pd.DataFrame(np.random.randn(1000,4),index=pd.date_range('1/1/2001',periods=1000),columns=list('efgh'))
df=df.cumsum()
df.head()
# Out:
#                    e         f         g         h
# 2001-01-01  1.078728  1.143386 -1.350411 -0.859749
# 2001-01-02  1.615480 -0.720806 -1.068370 -0.497890
# 2001-01-03 -0.521893 -0.310691 -2.351596 -0.601681
# 2001-01-04  1.998055 -1.254166 -1.924195 -1.636723
# 2001-01-05  1.634924 -1.355803 -2.116772 -1.877349

# %%
df.plot()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f32b634f610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32b63f9050>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f32b62fa550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32b6292990>]], dtype=object)

# %%
import prettyplotlib
df.plot()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f32b641da50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32b652b890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f32c9a07450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32b5f3a390>]], dtype=object)

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats,integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "distributions")))

# %%
x = np.random.normal(size=100)
sns.distplot(x)

# %%
sns.distplot(x,kde=False,rug=True);

# %%
sns.distplot(x,bins=19,kde=False,rug=True);

# %%
sns.distplot(x,hist=False,rug=True);

# %%
x=np.random.normal(0,2,size=12)
bandwidth=2*x.std()*x.size**(-1/10.)
support=np.linspace(-4,2,150)
kernels=[]
for x_i in x:
    kernel=stats.norm(x_i,bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support,kernel,color="r")
    sns.rugplot(x,color=".2",linewidth=2);

# %%
density=np.sum(kernels,axis=0)
density/=integrate.trapz(density,support)
plt.plot(support,density);

# %%
sns.kdeplot(x,shade=True);

# %%
sns.kdeplot(x)
sns.kdeplot(x,bw=.2,label="bw:0.2")
sns.kdeplot(x,bw=2,label="bw:2")
plt.legend();

# %%
sns.kdeplot(x,shade=True,cut=0)
sns.rugplot(x);

# %%
x=np.random.gamma(8,size=300)
sns.distplot(x,kde=False,fit=stats.gamma);

# %%
mean,cov=[0,1],[(1,.5),(.5,1)]
data=np.random.multivariate_normal(mean,cov,200)
df=pd.DataFrame(data,columns=["x","y"])

# %%
sns.jointplot(x="x",y="y",data=df);

# %%
x,y=np.random.multivariate_normal(mean,cov,1000).T
with sns.axes_style("white"):
    sns.jointplot(x=x,y=y,kind="hex",color="k");

# %%
sns.jointplot(x="x",y="y",data=df,kind="kde");

# %%
f,ax=plt.subplots(figsize=(6,6))
sns.kdeplot(df.x,df.y,ax=ax)
sns.rugplot(df.x,color="g",ax=ax)
sns.rugplot(df.y,vertical=True,ax=ax);

# %%
f,ax=plt.subplots(figsize=(6,6))
cmap=sns.cubehelix_palette(as_cmap=True,dark=0,light=1,reverse=True)
sns.kdeplot(df.x,df.y,cmap=cmap,n_levels=60,shade=True)

# %%
g=sns.jointplot(x="x",y="y",data=df,kind="kde",color="m")
g.plot_joint(plt.scatter,c="w",s=30,linewidth=1,marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$","$Y$");

# %%
iris=sns.load_dataset("iris")
sns.pairplot(iris);

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot,cmap="Blues_d",n_levels=6);
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord,"regression")))

# %%
tips=sns.load_dataset("tips")

# %%
sns.regplot(x="total_bill",y="tip",data=tips);

# %%
sns.lmplot(x="total_bill",y="tip",data=tips);

# %%
sns.lmplot(x="size",y="tip",data=tips);

# %%
sns.lmplot(x="size",y="tip",data=tips,x_jitter=.05);

# %%
sns.lmplot(x="size",y="tip",data=tips,x_estimator=np.mean);

# %%
anscombe=sns.load_dataset("anscombe")

# %%
sns.lmplot(x="x",y="y",data=anscombe.query("dataset=='I'"),
          ci=None,scatter_kws={"s":80});

# %%
sns.lmplot(x="x",y="y", data=anscombe.query("dataset=='II'"),
          ci=None,scatter_kws={"s":80});

# %%
sns.lmplot(x="x",y="y",data=anscombe.query("dataset=='II'"),
        order=2,ci=None,scatter_kws={"s":80});

# %%
sns.lmplot(x="x",y="y",data=anscombe.query("dataset=='III'"),
          ci=None,scatter_kws={"s":80});

# %%
sns.lmplot(x="x",y="y",data=anscombe.query("dataset=='III'"),
          robust=True,ci=None,scatter_kws={"s":80});

# %%
tips["big_tip"]=(tips.tip/tips.total_bill)>.15
sns.lmplot(x="total_bill",y="big_tip",data=tips,
          y_jitter=.03);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips,
           lowess=True);

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'I'"),
              scatter_kws={"s": 80});

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(style="whitegrid",color_codes=True)

# %%
np.random.seed(sum(map(ord,"categorical")))

# %%
titanic=sns.load_dataset("titanic")
tips=sns.load_dataset("tips")
iris=sns.load_dataset("iris")

# %%
sns.stripplot(x="day",y="total_bill",data=tips);

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True);

# %%
sns.swarmplot(x="day", y="total_bill", data=tips);

# %%
sns.swarmplot(x="size", y="total_bill", data=tips);

# %%
sns.swarmplot(x="total_bill", y="day", hue="time", data=tips);

# %%
sns.boxplot(x="day", y="total_bill", hue="time", data=tips);

# %%
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
sns.boxplot(x="day", y="total_bill", hue="weekend", data=tips, dodge=False);

# %%
sns.violinplot(x="total_bill", y="day", hue="time", data=tips);

# %%
sns.violinplot(x="total_bill", y="day", hue="time", data=tips,
               bw=.1, scale="count", scale_hue=False);

# %%
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
sns.boxplot(x="day", y="total_bill", hue="weekend", data=tips, dodge=False);

# %%
sns.violinplot(x="total_bill", y="day", hue="time", data=tips);

# %%
sns.violinplot(x="total_bill", y="day", hue="time", data=tips,
               bw=.1, scale="count", scale_hue=False);

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips,
               split=True, inner="stick", palette="Set3");

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
sns.swarmplot(x="day", y="total_bill", data=tips, color="w", alpha=.5);

# %%
sns.pointplot(x="sex", y="survived", hue="class", data=titanic);

# %%
sns.pointplot(x="class", y="survived", hue="sex", data=titanic,
              palette={"male": "g", "female": "m"},
              markers=["^", "o"], linestyles=["-", "--"]);

# %%
sns.boxplot(data=iris, orient="h");

# %%
sns.violinplot(x=iris.species, y=iris.sepal_length);

# %%
sns.factorplot(x="day", y="total_bill", hue="smoker",
               col="time", data=tips, kind="swarm");

# %%
g = sns.PairGrid(tips,
                 x_vars=["smoker", "time", "sex"],
                 y_vars=["total_bill", "tip"],
                 aspect=.75, size=3.5)
g.map(sns.violinplot, palette="pastel");
