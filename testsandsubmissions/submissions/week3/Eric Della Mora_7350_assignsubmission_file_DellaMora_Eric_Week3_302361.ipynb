# %%
# %matplotlib inline
# import naming conventions
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s1 = pd.Series([23,55,66,np.nan,99])
s1
# Out:
# 0    23.0
# 1    55.0
# 2    66.0
# 3     NaN
# 4    99.0
# dtype: float64

# %%
s2, s3 = pd.Series(np.random.randn(5)), pd.Series(np.random.randn(5))
df_2 = pd.DataFrame({'Me': s1, 'Myself': s2, 'I':s3})
df_2
# Out:
#           I    Me    Myself
# 0 -0.061959  23.0 -0.587394
# 1 -0.657478  55.0 -1.097992
# 2 -1.559976  66.0 -0.240317
# 3  0.905014   NaN  0.330610
# 4  0.088545  99.0 -1.302431

# %%
s4 = pd.Series(np.random.randn(9))
ayy = pd.DataFrame({'E': s1,'F': s2,'G': s3,'H': s4})
ayy
# Out:
#       E         F         G         H
# 0  23.0 -0.587394 -0.061959 -0.854419
# 1  55.0 -1.097992 -0.657478  1.702194
# 2  66.0 -0.240317 -1.559976  1.217717
# 3   NaN  0.330610  0.905014 -1.374371
# 4  99.0 -1.302431  0.088545 -1.626161
# 5   NaN       NaN       NaN -0.686438
# 6   NaN       NaN       NaN  0.486554
# 7   NaN       NaN       NaN  0.081596
# 8   NaN       NaN       NaN  0.008609

# %%
ayy2 = pd.DataFrame(np.random.randn(6,4))
print ayy2
# Out:
#           0         1         2         3
# 0  1.203630  1.155156  1.098137  0.449886
# 1 -0.518176 -0.103610  1.076197  0.022379
# 2  0.511320  0.140561  1.479237 -1.261603
# 3 -0.229999  0.638885 -0.545584  0.772017
# 4 -0.026742 -1.150731 -1.716224  0.157861
# 5  1.384729  1.601306  0.104004  0.961692

# %%
ayy2.tail(2)
# Out:
#           0         1         2         3
# 4 -0.026742 -1.150731 -1.716224  0.157861
# 5  1.384729  1.601306  0.104004  0.961692

# %%
ayy2.head(3)
# Out:
#           e         r         i         c
# 0  1.203630  1.155156  1.098137  0.449886
# 1 -0.518176 -0.103610  1.076197  0.022379
# 2  0.511320  0.140561  1.479237 -1.261603

# %%
cols = ['e','r','i','c']
ayy2.columns = cols
dates = pd.date_range(start='2011-08-29 13:33:33', freq='W', periods= 6)
ayy2.index = dates

ayy2
# Out:
#                             e         r         i         c
# 2011-09-04 13:33:33  1.203630  1.155156  1.098137  0.449886
# 2011-09-11 13:33:33 -0.518176 -0.103610  1.076197  0.022379
# 2011-09-18 13:33:33  0.511320  0.140561  1.479237 -1.261603
# 2011-09-25 13:33:33 -0.229999  0.638885 -0.545584  0.772017
# 2011-10-02 13:33:33 -0.026742 -1.150731 -1.716224  0.157861
# 2011-10-09 13:33:33  1.384729  1.601306  0.104004  0.961692

# %%
print 'what is a date_range object?\n\n', dates
# Out:
# what is a date_range object?
#
# DatetimeIndex(['2011-09-04 13:33:33', '2011-09-11 13:33:33',
#                '2011-09-18 13:33:33', '2011-09-25 13:33:33',
#                '2011-10-02 13:33:33', '2011-10-09 13:33:33'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
ayy2.loc['2011-09-18 13:33:33', 'r']
# Out:
# 0.14056146413656023

# %%
ayy2 = pd.DataFrame(np.random.randn(5,4), index=list('erico'), columns=list('DUDE'))
ayy2
# Out:
#           D         U         D         E
# e -0.118365 -0.208447 -0.215432  0.444267
# r -1.388940  0.861294  2.047009  0.424426
# i  0.710592  1.026804  1.345878  0.327568
# c  0.529866 -1.582421  0.919719 -1.225222
# o -0.248084  0.264623  0.895506  0.923112

# %%
ayy2.loc[['c','o'],'U':'E']
# Out:
#           U         D         E
# c  0.677712 -0.030389 -0.284005
# o  1.099361 -0.293933 -0.620652

# %%
gnacs_x = "id|postedTime|body|None|['twitter_entiteis:urls:url']|['None']|['actor:languages_list-items']|gnip:language:value|twitter_lang|[u'geo:coordinates_list-items']|geo:type|None|None|None|None|actor:utcOffset|None|None|None|None|None|None|None|None|None|actor:displayName|actor:preferredUsername|actor:id|gnip:klout_score|actor:followersCount|actor:friendsCount|actor:listedCount|actor:statusesCount|Tweet|None|None|None"
colnames = gnacs_x.split('|')

# %%
pd.set_option("display.max_columns", None)

ayy2 = pd.read_csv('./twitter_sample.csv', sep='|', names=colnames)

ayy2.tail(5)
# Out:
#                                                 id                postedTime  \
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# 92  O matheus André ta me falando aqui , tem quase...  None
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...  None
# 94                                           😕 Hmm...  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# ...

# %%
print ayy2.columns
print ayy2.drop( [u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10',
       u'None.11', u'None.12', u'None.13'],axis=1).columns
# Out:
# Index([u'id', u'postedTime', u'body', u'None',
#        u'['twitter_entiteis:urls:url']', u'['None']',
#        u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
#        u'None.1', u'None.2', u'None.3', u'None.4', u'actor:utcOffset',
#        u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10',
#        u'None.11', u'None.12', u'None.13', u'actor:displayName',
#        u'actor:preferredUsername', u'actor:id', u'gnip:klout_score',
#        u'actor:followersCount', u'actor:friendsCount', u'actor:listedCount',
#        u'actor:statusesCount', u'Tweet', u'None.14', u'None.15', u'None.16'],
#       dtype='object')
# Index([u'id', u'postedTime', u'body', u'None',
#        u'['twitter_entiteis:urls:url']', u'['None']',
#        u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
# ...

# %%
ayy2.tail(5)
# Out:
#                                                 id                postedTime  \
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# 92  O matheus André ta me falando aqui , tem quase...  None
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...  None
# 94                                           😕 Hmm...  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# ...

# %%
ayy2[ayy2.twitter_lang == 'fr'].head()
# Out:
#                                                 id                postedTime  \
# 43  tag:search.twitter.com,2005:351835318732857344  2013-07-01T22:50:51.000Z
# 56  tag:search.twitter.com,2005:351835319945019393  2013-07-01T22:50:51.000Z
# 84  tag:search.twitter.com,2005:351835320645459968  2013-07-01T22:50:51.000Z
#
#                                                  body  None  \
# 43  @MaevaRmz Dakkor Moi jvai pas oublier j'espère...  None
# 56      J'vais pas faire comme Yass un montage de dép  None
# 84    @JADEMEIMOUN1 mdrrrr ohh nan sa serai dommageee  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 43                          None     None                         ['fr']
# 56                          None     None                         ['fr']
# 84                          None     None                         ['fr']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# ...

# %%
ayy3 = ayy2[["gnip:klout_score","actor:followersCount", "actor:friendsCount", "actor:listedCount"]]
ayy3.head()
# Out:
#   gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0               35                   178                 129
# 1               32                   144                 215
# 2               18                    37                  54
# 3               50                   438                 174
# 4               21                    12                   6
#
#    actor:listedCount
# 0                  0
# 1                  0
# 2                  0
# 3                  1
# 4                  0

# %%
ayy3.dtypes
# Out:
# gnip:klout_score        object
# actor:followersCount     int64
# actor:friendsCount       int64
# actor:listedCount        int64
# dtype: object

# %%
def floatify(val):
    if val == None or val == 'None':
        return 0.0
    else:
        return float(val)

# %%
ayy3['gnip:klout_score'] = ayy3['gnip:klout_score'].map(floatify)
ayy3.dtypes
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# gnip:klout_score        float64
# actor:followersCount      int64
# actor:friendsCount        int64
# actor:listedCount         int64
# dtype: object

# %%
ayy3 = ayy3.astype(float)
ayy3.dtypes
# Out:
# gnip:klout_score        float64
# actor:followersCount    float64
# actor:friendsCount      float64
# actor:listedCount       float64
# dtype: object

# %%
ayy3['fol/fr'] = ayy3['gnip:klout_score'] / ayy3['actor:followersCount']
ayy3.head()
# Out:
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0              35.0                 178.0               129.0
# 1              32.0                 144.0               215.0
# 2              18.0                  37.0                54.0
# 3              50.0                 438.0               174.0
# 4              21.0                  12.0                 6.0
#
#    actor:listedCount    fol/fr
# 0                0.0  0.196629
# 1                0.0  0.222222
# 2                0.0  0.486486
# 3                1.0  0.114155
# 4                0.0  1.750000

# %%
ayy3.head()
# Out:
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0              35.0                 178.0               129.0
# 1              32.0                 144.0               215.0
# 2              18.0                  37.0                54.0
# 3              50.0                 438.0               174.0
# 4              21.0                  12.0                 6.0
#
#    actor:listedCount    fol/fr
# 0                0.0  0.196629
# 1                0.0  0.222222
# 2                0.0  0.486486
# 3                1.0  0.114155
# 4                0.0  1.750000

# %%
pop_df = ayy2[ayy2["actor:followersCount"] >= 100]

# %%
lang_gb = pop_df[['twitter_lang',\
             'gnip:klout_score',\
             'actor:followersCount',\
             'actor:friendsCount',\
             'actor:statusesCount']].groupby('twitter_lang')

lang_gb.head(2)
# Out:
#    twitter_lang gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0            tr               35                   178                 129
# 1            es               32                   144                 215
# 3            es               50                   438                 174
# 5            tr               41                   226                 346
# 6            pt               42                   247                  64
# 8            en               38                   380                 860
# 9            en               41                   160                 135
# 16          und               53                  1179                 628
# 18           he               37                   151                 284
# 20           it               46                  1999                 293
# 21           pt               43                   137                  89
# ...

# %%
lang_gb_mean = lang_gb.aggregate(np.mean)
lang_gb_mean.head()
# Out:
#               actor:followersCount  actor:friendsCount  actor:statusesCount
# twitter_lang
# ar                      458.000000          413.000000          1061.000000
# en                     1796.147059          582.735294         16364.352941
# es                     1359.285714          441.142857          8953.357143
# fr                      116.000000          122.000000          3174.000000
# he                      151.000000          284.000000           641.000000

# %%
lang_gb_mean['actor:followersCount'].plot(kind='bar', color='b')

# %%
plt.scatter(x=lang_gb_mean['actor:followersCount'],\
            y=lang_gb_mean['actor:friendsCount'],\
            alpha=0.5,\
            s=50,\
            color='purple',\
            marker='*')

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(lang_gb_mean, alpha=0.5, figsize=(12,12), diagonal='kde', s=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f72f64b7990>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f72f61eaf90>]], dtype=object)

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=pd.date_range('1/1/2000', periods=1000), columns=list('ERIC'))
df = df.cumsum()
df.head()
# Out:
#                    E         R         I         C
# 2000-01-01  0.046673  0.004015  1.680096  1.259950
# 2000-01-02 -0.194349  0.127152  3.067620  0.852597
# 2000-01-03 -0.115474 -0.197557  2.915532 -2.212886
# 2000-01-04  0.287674 -1.224152  3.044703 -1.942927
# 2000-01-05  1.332300 -1.399537  4.002654 -1.913761

# %%
df.plot()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f72ede01510>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f72edc9d410>]], dtype=object)

# %%
import prettyplotlib
df.plot()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f72ed9f3fd0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f72ed90ffd0>]], dtype=object)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))

# %%
x = np.random.normal(size=86)
sns.distplot(x);

# %%
sns.distplot(x, kde=False, rug=True);
sns.distplot(x, hist=False, rug=True);

# %%
x = np.random.normal(0, 1, size=20)
bandwidth = 1.06 * x.std() * x.size ** (-1 / 5.)
support = np.linspace(-4, 4, 200)

kernels = []
for x_i in x:

    kernel = stats.norm(x_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel, color="r")

sns.rugplot(x, color=".2", linewidth=2);

# %%
density = np.sum(kernels, axis=0)
density /= integrate.trapz(density, support)
plt.plot(support, density);

# %%
sns.kdeplot(x, shade=True);

# %%
sns.kdeplot(x)
sns.kdeplot(x, bw=.2,label="bw: 0.2")
sns.kdeplot(x, bw=2, label="bw: 2")
plt.legend();

# %%
sns.kdeplot(x, shade=True, cut=0)
sns.rugplot(x);

# %%
x = np.random.gamma(5, size=180)
sns.distplot(x, kde=False, fit=stats.gamma);

# %%
mean, cov = [0, 3], [(1, .5), (.5, 2)]
data = np.random.multivariate_normal(mean, cov, 180)
df = pd.DataFrame(data, columns=["x", "y"])

# %%
sns.jointplot(x="x", y="y", data=df);

# %%
x, y = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style("white"):
    sns.jointplot(x=x, y=y, kind="hex", color="g");

# %%
sns.jointplot(x="x", y="y", data=df, kind="kde");

# %%
f, ax = plt.subplots(figsize=(4, 5))
sns.kdeplot(df.x, df.y, ax=ax)
sns.rugplot(df.x, color="b", ax=ax)
sns.rugplot(df.y, vertical=True, ax=ax);

# %%
f, ax = plt.subplots(figsize=(4, 5))
cmap = sns.cubehelix_palette(as_cmap=True, dark=1, light=0, reverse=True)
sns.kdeplot(df.x, df.y, cmap=cmap, n_levels=60, shade=True);

# %%
g = sns.jointplot(x="x", y="y", data=df, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$");

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris);

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, cmap="Blues_d", n_levels=6);

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))
tips = sns.load_dataset("tips")
sns.regplot(x="total_bill", y="tip", data=tips);
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips, x_jitter=1);

# %%
sns.lmplot(x="size", y="tip", data=tips, x_estimator=np.mean);

# %%
anscombe = sns.load_dataset("anscombe")
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'I'"),
           ci=None, scatter_kws={"s": 100});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"),
           order=2, ci=None, scatter_kws={"s": 80});

# %%
tips["big_tip"] = (tips.tip / tips.total_bill) > .15
sns.lmplot(x="total_bill", y="big_tip", data=tips,
           y_jitter=.03);
sns.lmplot(x="total_bill", y="big_tip", data=tips,
           logistic=True, y_jitter=.03);

# %%
f, ax = plt.subplots(figsize=(5, 6))
sns.regplot(x="total_bill", y="tip", data=tips, ax=ax);

# %%
sns.lmplot(x="total_bill", y="tip", col="day", data=tips,
           col_wrap=3, size=5);

# %%
sns.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"],
             size=7, aspect=.6, kind="reg");

# %%
sns.pairplot(tips, x_vars=["size", "total_bill"], y_vars=["tip"],
             hue="smoker", size=4, aspect=.6, kind="reg");

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)
np.random.seed(sum(map(ord, "categorical")))
titanic = sns.load_dataset("titanic")
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %%
sns.stripplot(x="day", y="total_bill", data=tips);

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True);

# %%
sns.swarmplot(x="day", y="total_bill", hue="smoker", data=tips);

# %%
sns.swarmplot(x="total_bill", y="day", hue="sex", data=tips);

# %%
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips);

# %%
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
sns.boxplot(x="day", y="total_bill", hue="day", data=tips, dodge=False);

# %%
sns.violinplot(x="total_bill", y="day", hue="sex", data=tips,
               bw=.1, scale="count", scale_hue=True);

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips,
               split=True, inner="stick", palette="Set2");

# %%
sns.barplot(x="sex", y="survived", hue="age", data=titanic);

# %%
sns.barplot(x="sex", y="survived", hue="class", data=titanic);

# %%
sns.countplot(y="deck", hue="sex", data=titanic, palette="Greens_d");

# %%
sns.pointplot(x="class", y="survived", hue="sex", data=titanic);

# %%
sns.pointplot(x="survived", y="class", hue="sex", data=titanic,
              palette={"male": "b", "female": "m"},
              markers=["^", "*"], linestyles=["--", "--"]);

# %%
sns.boxplot(data=iris, orient="v");

# %%
f, ax = plt.subplots(figsize=(4, 5))
sns.countplot(y="class", data=titanic, color="m");

# %%
sns.factorplot(x="day", y="total_bill", hue="sex", data=tips);

# %%
sns.factorplot(x="day", y="total_bill", hue="sex", data=tips, kind="bar");

# %%
sns.factorplot(x="sex", y="total_bill", hue="smoker",
               col="time", data=tips, kind="swarm");

# %%
sns.factorplot(x="sex", y="total_bill", hue="time",
               col="day", data=tips, kind="box", size=4, aspect=.5);

# %%
g = sns.PairGrid(tips,
                 x_vars=["day", "time", "sex"],
                 y_vars=["total_bill", "tip"],
                 aspect=.75, size=3)
g.map(sns.violinplot, palette="pastel");
