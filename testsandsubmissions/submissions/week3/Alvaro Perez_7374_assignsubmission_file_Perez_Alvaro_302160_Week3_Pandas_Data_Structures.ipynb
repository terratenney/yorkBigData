# %%
# %matplotlib inline
# import naming conventions
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# (further reading on mpl imports: http://bit.ly/197aGoq)

# %% [markdown]
# # Notas de Clase
#
# Pandas cuenta cos dos estructuras principales, y 3 mas
# 1. Series. Rango de una varialbe
# 2. DataFrame. Estructura bidimensional (2 variables)
# 3. TimeSeries (DateTimes)
# 4. 3Dimensiones
# 5. 4Dimensiones

# %% [markdown]
# ## Caso 1. Unidimensional
# Cualquier tipo de data y su tabulacion se denomina como un index

# %% [markdown]
# # Ejemplo:

# %%
s1 = pd.Series([1,9.5,11,np.nan,-6,188])
s1
# Out:
# 0      1.0
# 1      9.5
# 2     11.0
# 3      NaN
# 4     -6.0
# 5    188.0
# dtype: float64

# %%
# llamo a caulquier numero de la serie, cuando adiciono los []
s1[0]
# Out:
# 1.0

# %% [markdown]
# # Caso 2. (Bidimensional 2D)
# Dos columnas

# %% [markdown]
# # Ejemplo:

# %%
# Creando series adicionales
s2, s3, s4 = pd.Series(np.random.randn(6)), pd.Series(np.random.randn(6)), pd.Series(np.random.randn(9))

# %%
s1, s2, s3, s4
# Out:
# (0      1.0
#  1      9.5
#  2     11.0
#  3      NaN
#  4     -6.0
#  5    188.0
#  dtype: float64, 0   -2.797055
#  1   -1.640973
#  2    1.103637
#  3   -0.091260
#  4    0.442610
#  5   -0.002628
#  dtype: float64, 0    0.761485
#  1    1.014768
#  2   -0.444531
#  3    1.489874
#  4    0.517656
#  5   -0.610406
#  dtype: float64, 0   -1.766176
#  1    1.317217
#  2   -1.830587
#  3    1.265558
#  4   -2.291685
#  5    1.595041
#  6    0.580665
#  7   -1.582138
#  8    0.377758
#  dtype: float64)

# %% [markdown]
# El mismo ejemplo agregando formato de marco

# %%
arreglo_cuadrangular_1 = pd.DataFrame({'Dia1': s1, 'Dia2': s2, 'Dia3': s3, 'Dia4': s4})
arreglo_cuadrangular_1
# Out:
#     Dia1      Dia2      Dia3      Dia4
# 0    1.0 -2.797055  0.761485 -1.766176
# 1    9.5 -1.640973  1.014768  1.317217
# 2   11.0  1.103637 -0.444531 -1.830587
# 3    NaN -0.091260  1.489874  1.265558
# 4   -6.0  0.442610  0.517656 -2.291685
# 5  188.0 -0.002628 -0.610406  1.595041
# 6    NaN       NaN       NaN  0.580665
# 7    NaN       NaN       NaN -1.582138
# 8    NaN       NaN       NaN  0.377758

# %% [markdown]
# Mismo ejemplo restringiendo la longitud de la tabla

# %%
arreglo_cuadrangular_2 = (np.random.randn(3,3))
arreglo_cuadrangular_2
# Out:
# array([[-1.24119751,  1.06854538,  1.51919035],
#        [ 0.44050881,  0.22442057,  1.04949309],
#        [ 1.21941076,  0.29340167, -1.82267883]])

# %%
arreglo_cuadrangular_2 = pd.DataFrame(np.random.randn(4,4))
arreglo_cuadrangular_2
# Out:
#           0         1         2         3
# 0 -0.653579  0.045454  0.164704 -3.000254
# 1 -0.797055 -0.006384  0.277256  0.196316
# 2 -2.094713  1.054953  1.636419  0.299382
# 3 -0.522113  0.911665  1.693281 -0.367996

# %%
arreglo_cuadrangular_2.head(4)
# Out:
#           0         1         2         3
# 0 -0.653579  0.045454  0.164704 -3.000254
# 1 -0.797055 -0.006384  0.277256  0.196316
# 2 -2.094713  1.054953  1.636419  0.299382
# 3 -0.522113  0.911665  1.693281 -0.367996

# %%
cols = ['Apple', 'HP', 'Dell', 'Nestle']
arreglo_cuadrangular_2.columns = cols
dates = pd.date_range(start='2013-11-24 13:45:27', freq='W', periods=4)
arreglo_cuadrangular_2.index = dates
arreglo_cuadrangular_2
# Out:
#                         Apple        HP      Dell    Nestle
# 2013-11-24 13:45:27 -0.653579  0.045454  0.164704 -3.000254
# 2013-12-01 13:45:27 -0.797055 -0.006384  0.277256  0.196316
# 2013-12-08 13:45:27 -2.094713  1.054953  1.636419  0.299382
# 2013-12-15 13:45:27 -0.522113  0.911665  1.693281 -0.367996

# %% [markdown]
# # Part 2. Pandas

# %%
gnacs_x = "id|postedTime|body|None|['twitter_entiteis:urls:url']|['None']|['actor:languages_list-items']|gnip:language:value|twitter_lang|[u'geo:coordinates_list-items']|geo:type|None|None|None|None|actor:utcOffset|None|None|None|None|None|None|None|None|None|actor:displayName|actor:preferredUsername|actor:id|gnip:klout_score|actor:followersCount|actor:friendsCount|actor:listedCount|actor:statusesCount|Tweet|None|None|None"
colnames = gnacs_x.split('|')

# %%
# prevent the automatic compression of wide dataframes (add scroll bar)
pd.set_option("display.max_columns", None)

# get some data, inspect
df1 = pd.read_csv('../Data/twitter_sample.csv', sep='|', names=colnames)

df1.tail(7)
# Out:
#                                                 id                postedTime  \
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 88                             @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# ...

# %%
# create new dataframe from numerical columns
df2 = df1[["gnip:klout_score","actor:followersCount", "actor:friendsCount", "actor:statusesCount"]]

df2.head()
# Out:
#   gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0               35                   178                 129
# 1               32                   144                 215
# 2               18                    37                  54
# 3               50                   438                 174
# 4               21                    12                   6
#
#    actor:statusesCount
# 0                 2028
# 1                 4071
# 2                 3505
# 3                17636
# 4                  145

# %%
# Eliminando los campos con None

# %%
# n.b.: this is an *in-place* delete -- unusual for a pandas structure
print df1.columns
print df1.drop( [u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10',
       u'None.11', u'None.12', u'None.13'],axis=1).columns
# Out:
# Index([u'id', u'postedTime', u'body', u'None',
#        u'['twitter_entiteis:urls:url']', u'['None']',
#        u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
#        u'None.1', u'None.2', u'None.3', u'None.4', u'actor:utcOffset',
#        u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10',
#        u'None.11', u'None.12', u'None.13', u'actor:displayName',
#        u'actor:preferredUsername', u'actor:id', u'gnip:klout_score',
#        u'actor:followersCount', u'actor:friendsCount', u'actor:listedCount',
#        u'actor:statusesCount', u'Tweet', u'None.14', u'None.15', u'None.16'],
#       dtype='object')
# Index([u'id', u'postedTime', u'body', u'None',
#        u'['twitter_entiteis:urls:url']', u'['None']',
#        u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
# ...

# %%
# Extrctando un conjunto de datos (8)
df1.tail(8)
# Out:
#                                                 id                postedTime  \
# 87  tag:search.twitter.com,2005:351835321056509952  2013-07-01T22:50:51.000Z
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 87  And I'm the one that always gets hit on. OKAAAAY.  None
# 88                             @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# ...

# %% [markdown]
# # Slicing & Combining

# %%
# Extractando las filas de mensajes twiitter que utilizaron el idioma frances 'fr' (scroll the right to see)
df1[df1.twitter_lang == 'fr'].head()

# the colons in the column name below won't allow dot-access to the column, so we can quote them and still filter.
#df1[df1["gnip:language:value"] == 'en'].head()
# Out:
#                                                 id                postedTime  \
# 43  tag:search.twitter.com,2005:351835318732857344  2013-07-01T22:50:51.000Z
# 56  tag:search.twitter.com,2005:351835319945019393  2013-07-01T22:50:51.000Z
# 84  tag:search.twitter.com,2005:351835320645459968  2013-07-01T22:50:51.000Z
#
#                                                  body  None  \
# 43  @MaevaRmz Dakkor Moi jvai pas oublier j'espère...  None
# 56      J'vais pas faire comme Yass un montage de dép  None
# 84    @JADEMEIMOUN1 mdrrrr ohh nan sa serai dommageee  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 43                          None     None                         ['fr']
# 56                          None     None                         ['fr']
# 84                          None     None                         ['fr']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# ...

# %%
# create new dataframe from numerical columns
df2 = df1[["gnip:klout_score","actor:followersCount", "actor:friendsCount", "actor:listedCount"]]

df2.head()
# Out:
#   gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0               35                   178                 129
# 1               32                   144                 215
# 2               18                    37                  54
# 3               50                   438                 174
# 4               21                    12                   6
#
#    actor:listedCount
# 0                  0
# 1                  0
# 2                  0
# 3                  1
# 4                  0

# %%
# Resumen de los tipos de campo para las columnas
df2.dtypes
# Out:
# gnip:klout_score        object
# actor:followersCount     int64
# actor:friendsCount       int64
# actor:listedCount        int64
# dtype: object

# %%
# Adicionanado una columna al final que incluye ratios
# Permanent error I could not decode
# look at some activity ratios - add col to df
df2['fol/fr'] = df2['gnip:klout_score'] / df2['actor:followersCount']
df2.head()
# can also use the built-in describe() method to get quick descriptive stats on the dataframe
#df2.describe()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-224-cbc967da76b2> in <module>()
#       2 # Permanent error I could not decode
#       3 # look at some activity ratios - add col to df
# ----> 4 df2['fol/fr'] = df2['gnip:klout_score'] / df2['actor:followersCount']
#       5 df2.head()
#       6 # can also use the built-in describe() method to get quick descriptive stats on the dataframe
#
# /bda/app/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     719                 lvalues = lvalues.values
#     720
# --> 721         result = wrap_results(safe_na_op(lvalues, rvalues))
#     722         return construct_result(
#     723             left,
#
# /bda/app/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in safe_na_op(lvalues, rvalues)
#     690                 if is_object_dtype(lvalues):
#     691                     return libalgos.arrmap_object(lvalues,
# ...

# %% [markdown]
# # Grouping

# %%
# Base de datos original pero eliminando los campos con "None"
df1.head()

# %%
# Crenado un subconjunto de datos (sub database) aplicando ciertas condiciones. En mi ejemplo sera cuentas con un numero de seguidores mayores a 500
# subset df, create new df with only 'popular' accounts -- those matching the filter condition given
pop_df = df1[df1["actor:followersCount"] >= 500]

# fix the klout scores again
#pop_df['gnip:klout_score'] = pop_df['gnip:klout_score'].map(floatify)

# in case you need to remind yourself of the dataframe
#pop_df.head()

# use GroupBy methods for stats on each group:
#pop_df.groupby("twitter_lang").size()      # number of elements per group
#pop_df.groupby("twitter_lang").sum()       # sum of elements in each group (obviously doesn't make sense for some cols) 
#pop_df.groupby("twitter_lang").mean()      # algebraic mean of elements per group

# %%
# though this looks like a normal dataframe, the DataFrameGroupBy object has a heirarchical index
#  this means it may not act as you might expect.
lang_gb = pop_df[['twitter_lang',\
             'gnip:klout_score',\
             'actor:followersCount',\
             'actor:friendsCount',\
             'actor:statusesCount']].groupby('twitter_lang')


# note the new index 'twitter_lang' -- in this case, .head(n) returns <= n elements for each index
lang_gb.head(2)  

# see that they type is DataFrameGroupBy object
#lang_gb

# %%
# to get a DataFrame object that responds more like I'm used to, create a new one using the 
#   aggregate method, which results in a single-index DataFrame
lang_gb_mean = lang_gb.aggregate(np.mean)  

lang_gb_mean.head()

# verify the single index
#lang_gb_mean.index

# %% [markdown]
# # Part 3. Plotting

# %%
# .plot() is a pandas wrapper for matplotlib's plt.plot() 
lang_gb_mean['actor:followersCount'].plot(kind='bar', color='r')

# %%
# more base matplotlib 
plt.scatter(x=lang_gb_mean['actor:followersCount'],\
            y=lang_gb_mean['actor:friendsCount'],\
            alpha=0.2,\
            s=280,\
            color='g',\
            marker='o')

# %%
# now read the docs and copypasta a neat-looking plot
from pandas.plotting import scatter_matrix

scatter_matrix(lang_gb_mean, alpha=0.5, figsize=(15,15), diagonal='kde', s=200)

# %%
# make up some data with large-scale patterns and a datetime index
df = pd.DataFrame(np.random.randn(1000, 8), index=pd.date_range('1/1/2013', periods=1000), columns=list('ABCDUXYZ'))
df = df.cumsum()
df.head()

# %%
df.plot()
df.hist()

# %%
import prettyplotlib

df.plot()
df.hist()

# %% [markdown]
# # Visualizing the Distribution of a Dataset

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "distributions")))

# %% [markdown]
# ## Grafico Variable Unidimensional

# %% [markdown]
# The most convenient way to take a quick look at a univariate distribution in seaborn is the *distplot function. By default, this will draw a histogram <https://en.wikipedia.org/wiki/Histogram>_ and fit a kernel density estimate <https://en.wikipedia.org/wiki/Kernel_density_estimation>_ (KDE).

# %%
x = np.random.normal(size=10000)
sns.distplot(x);

# %% [markdown]
# ### Histrograma de Frecuencia

# %%
sns.distplot(x, kde=False, rug=True);

# %%
sns.distplot(x, bins=50, kde=False, rug=True);

# %% [markdown]
# ### Funcion de Densidad: Estimacion via Kernel

# %%
sns.distplot(x, hist=False, rug=True);

# %%
x = np.random.normal(0, 1, size=30)
bandwidth = 1.06 * x.std() * x.size ** (-1 / 5.)
support = np.linspace(-10, 10, 200)

kernels = []
for x_i in x:

    kernel = stats.norm(x_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel, color="blue")

sns.rugplot(x, color=".2", linewidth=10);

# %%
density = np.sum(kernels, axis=0)
density /= integrate.trapz(density, support)
plt.plot(support, density);

# %%
sns.kdeplot(x)
sns.kdeplot(x, bw=.2, label="bw: 0.2")
sns.kdeplot(x, bw=2, label="bw: 2")
plt.legend();

# %%
sns.kdeplot(x, shade=True, cut=0)
sns.rugplot(x);

# %% [markdown]
# #### Parametric Distribution

# %%
x = np.random.gamma(6, size=200)
sns.distplot(x, kde=False, fit=stats.gamma);

# %% [markdown]
# ## Grafico Variable Bidimensional

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

# %% [markdown]
# ### Scatterplots

# %%
sns.jointplot(x="x", y="y", data=df);

# %% [markdown]
# ### Hexbin Plots

# %%
x, y = np.random.multivariate_normal(mean, cov, 100).T
with sns.axes_style("white"):
    sns.jointplot(x=x, y=y, kind="hex", color="k");

# %% [markdown]
# ### Funcion de Densidad via Kernel

# %%
sns.jointplot(x="x", y="y", data=df, kind="kde");

# %%
f, ax = plt.subplots(figsize=(4, 4))
cmap = sns.cubehelix_palette(as_cmap=True, dark=1, light=0, reverse=True)
sns.kdeplot(df.x, df.y, cmap=cmap, n_levels=60, shade=True);

# %% [markdown]
# ### Visualizing pairwise relationships in a dataset

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris);

# %% [markdown]
# ### Visualizing Linear Relationships

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "regression")))

# %%
tips = sns.load_dataset("tips")

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips,
           markers=["o", "x"], palette="Set1");

# %% [markdown]
# ### Plotting with Categorical Data

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
np.random.seed(sum(map(ord, "categorical")))

# %%
titanic = sns.load_dataset("titanic")
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %%
sns.stripplot(x="day", y="total_bill", data=tips);

# %%
sns.swarmplot(x="time", y="total_bill", hue="sex", data=tips);

# %%
sns.boxplot(x="time", y="total_bill", hue="sex", data=tips);

# %%
sns.violinplot(x="total_bill", y="day", hue="sex", data=tips);

# %%
sns.violinplot(x="sex", y="total_bill", data=tips, inner=None)
sns.swarmplot(x="sex", y="total_bill", data=tips, color="w", alpha=.5);
