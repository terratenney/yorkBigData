# %%
# 1 Import the following libraries to your notebook (you can use alias' if you want) in the cell below:
# pandas, seaborn, os, matplotlib.pyplot
# And add the following flag: %matplotlib inline

import pandas as pd
import seaborn as sp
import os as os
import matplotlib.pyplot as plt
# %matplotlib inline

print pd
print sp
print os
print plt
# Out:
# <module 'pandas' from '/bda/app/anaconda2/lib/python2.7/site-packages/pandas/__init__.pyc'>
# <module 'seaborn' from '/bda/app/anaconda2/lib/python2.7/site-packages/seaborn/__init__.pyc'>
# <module 'os' from '/bda/app/anaconda2/lib/python2.7/os.pyc'>
# <module 'matplotlib.pyplot' from '/bda/app/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>

# %%
#2 Index a list in Python
#Run the code below, it will give a result of 4. If we want to get ONLY the number 8 from the list of lists below, 
#how would you alter the code? Alter the code directly and run to print the desired output

question2 = [[1,2],[3,4],[5,6],[7,[8,9]]]
print question2[3][1][0]
# Out:
# 8

# %%
#3 Define a variable called bigdata, to be a list in python with the following elements and print only the 
# last two elements of the list:
# 1, "Big Data Class", 2, "Is Really Fun",3, "I Love Python"

bigdata=[1, "Big Data Class", 2, "Is Really Fun",3, "I Love Python"]
print bigdata[4:6]
# Out:
# [3, 'I Love Python']

# %%
#4 Cast the following list to be a string in Python: 
# Define the list [1,2,4,3,'k'] and cast it to a string where you print out '1243k'. Insert your code below.

list = [1,2,4,3,'k'] 

''.join(map(str, list))
# Out:
# '1243k'

# %%
#5 Test whether the two lists are equal too each other and if not what elements are shared between the two lists.
# list1 = ['1',2,'3',4,5] list2 = [1,2,3,4,'5',6]

list1 = ['1',2,'3',4,5]
list2 = [1,2,3,4,'5',6]

for i in list1:
    if i in list2:
        print i
# Out:
# 2
# 4

# %% [markdown]
# #6
#
# Repeat of #5

# %% [markdown]
# #7
#
# Velocity, Volume, Value, Variety, and Veracity

# %% [markdown]
# #8
#
# All models are wrong. Some are more useful than others.

# %%
#9 If a variable dogs = 103x23/2 and a variable cats = 10x12x4, Use python to determing if dogs are 
# greater than cats.

dogs=103*23/2
cats=10*12*4

dogs>cats
# Out:
# True

# %% [markdown]
# #10
#
# Mode is the most common value in a dataset.
# Mean is the sum of the elements of a dataset divided by the number of abservations.
# Median is the middle value of in a dataset sorted in ascending or descending order.

# %%
#11 Calculate the descriptive statistice for each of the above central measures in Python on 
# this list of numbers and print out the values:

# [12,44,23,2,1,66,7,85,3,34,23,6,34,23,7,21,14,34,23,88] 
# (Hint: it might be easier to import a function from some other library)

import numpy as np
from scipy import stats
thislist = [12,44,23,2,1,66,7,85,3,34,23,6,34,23,7,21,14,34,23,88] 
print np.mean(thislist)
print np.median(thislist)
print stats.mode(thislist)
# Out:
# 27.5
# 23.0
# ModeResult(mode=array([23]), count=array([4]))

# %%
#12

# %%
#13 Create a list, called mylist, containing a sequential list of numbers that starts with 2 and stops
# at 1000, counting by 2's in Python

mylist = pd.Series(range(2,1001,2))
print mylist
# Out:
# 0         2
# 1         4
# 2         6
# 3         8
# 4        10
# 5        12
# 6        14
# 7        16
# 8        18
# 9        20
# 10       22
# 11       24
# 12       26
# 13       28
# 14       30
# 15       32
# 16       34
# 17       36
# 18       38
# 19       40
# 20       42
# 21       44
# 22       46
# 23       48
# 24       50
# 25       52
# 26       54
# 27       56
# 28       58
# 29       60
#        ...
# 470     942
# 471     944
# 472     946
# 473     948
# 474     950
# 475     952
# 476     954
# 477     956
# 478     958
# 479     960
# 480     962
# 481     964
# 482     966
# 483     968
# 484     970
# 485     972
# 486     974
# 487     976
# 488     978
# 489     980
# 490     982
# 491     984
# 492     986
# 493     988
# 494     990
# 495     992
# 496     994
# 497     996
# 498     998
# 499    1000
# Length: 500, dtype: int64

# %%
#14 Is the sum of the first 50 elements in "mylist" greater than the last element of "mylist"?
# Use Python below to print out the answer. (mylist is defined in question 13).

#print(sum(mylist)) - summing a series

# sum of first 50 elements
print sum(mylist[:50])

#last element of mylist(500)
print mylist[499]

#comparison
sum(mylist[:50])>mylist[499]
# Out:
# 2550
# 1000
# True

# %%
#15 What is the length of "mylist"?

len(mylist) # same as mylist.size
# Out:
# 500

# %%
#16 Create another list, called my2ndlist, containing a list of numbers starting at 1002 and stops at 1052,
# counting by 3's in Python. THEN concatenate my2ndlist with mylist into a new list called theMegaList.
# Print theMegaList below.

my2ndlist =pd.Series(range(1002,1053,3))

theMegaList=pd.concat([mylist, my2ndlist])

print theMegaList
# Out:
# 0         2
# 1         4
# 2         6
# 3         8
# 4        10
# 5        12
# 6        14
# 7        16
# 8        18
# 9        20
# 10       22
# 11       24
# 12       26
# 13       28
# 14       30
# 15       32
# 16       34
# 17       36
# 18       38
# 19       40
# 20       42
# 21       44
# 22       46
# 23       48
# 24       50
# 25       52
# 26       54
# 27       56
# 28       58
# 29       60
#        ...
# 487     976
# 488     978
# 489     980
# 490     982
# 491     984
# 492     986
# 493     988
# 494     990
# 495     992
# 496     994
# 497     996
# 498     998
# 499    1000
# 0      1002
# 1      1005
# 2      1008
# 3      1011
# 4      1014
# 5      1017
# 6      1020
# 7      1023
# 8      1026
# 9      1029
# 10     1032
# 11     1035
# 12     1038
# 13     1041
# 14     1044
# 15     1047
# 16     1050
# Length: 517, dtype: int64

# %%
#17 What is the index for the value 822 in theMegaList?

# %%
#18 Write a for loop that will test if an element in theMegaList is an even or odd number and keeps a 
# count of how many of each there are in the list. 18) Write a for loop that will test if an element 
# in theMegaList is an even or odd number and keeps a count of how many of each there are in the list.
# Print out the total number of even and odd numbers found in theMegalist below.

count_odd = 0
count_even = 0
for x in theMegaList:
        if not x % 2:
             count_even+=1
        else:
             count_odd+=1
print ("Number of even numbers :",count_even)
print ("Number of odd numbers :",count_odd)
# Out:
# ('Number of even numbers :', 509)
# ('Number of odd numbers :', 8)

# %% [markdown]
# #19 Write a brief definition of what Data Latency and the difference between "real-time" and "near-time" data.
#
#
# Data latency is the time between data creation and the time at which the same data is available to end users.
#
# Rea-time has little or zero latency meaning the data is available as it is created.
#
# Near-time data is updated at regular time intervals.

# %%
# 20) Suppose you have the following loop:

things = [1,2,3,5,6,7,8,9,10]
previous_thing = 0
for thing in things:
    new_thing = thing * previous_thing
    x = 3+previous_thing
    previous_thing = thing
    
     
# What does new_thing equal?
print new_thing
# Out:
# 90

# %%
# What does x equal?
print x
# Out:
# 12

# %% [markdown]
# #21 What's the difference between Zero and None or Null?
#
# Zero stands for a value corresponding to zero on a given scale
# None means there is nothing satisfying a given criteria
# Null means a field is empty. No value has been assigned to the field.

# %% [markdown]
# #22 In the following loop:
#
# x = 1
# sure_thing = True
# while sure_thing:
#
#     x = x +100
#     if x < 20001:
#
#         x = x-1
#         else:
#         sure_thing = False
#
# # What does x equal to make our sure_thing False?
#
# x equals 20001

# %%
from pandas import Series, DataFrame
import pandas as pd
raw_data = {'first_name': ['Jason', 'Jason', 'Tina', 'Jake', 'Amy'],
        'last_name': ['Miller', 'Miller', 'Ali', 'Milner', 'Milner'],
        'age': [42, 42, 36, 24, 73],
        'preTest': [4, 4, 31, 2, 3],
        'postTest': [25, 25, 57, 62, 70]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'preTest', 'postTest'])
df1 = df

print df
print df1
# Out:
#   first_name last_name  age  preTest  postTest
# 0      Jason    Miller   42        4        25
# 1      Jason    Miller   42        4        25
# 2       Tina       Ali   36       31        57
# 3       Jake    Milner   24        2        62
# 4        Amy    Milner   73        3        70
#   first_name last_name  age  preTest  postTest
# 0      Jason    Miller   42        4        25
# 1      Jason    Miller   42        4        25
# 2       Tina       Ali   36       31        57
# 3       Jake    Milner   24        2        62
# 4        Amy    Milner   73        3        70

# %%
#23 What are the column names in df1?print the result

list(df.columns.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-577bfac5e618> in <module>()
#       1 #23 What are the column names in df1?print the result
#       2
# ----> 3 list(df.columns.values)
#
# TypeError: 'list' object is not callable

# %%
#24 Average (mean) of the preTest and postTest scores

print df[["preTest"]].mean()
print df[["postTest"]].mean()
# Out:
# preTest    8.8
# dtype: float64
# postTest    47.8
# dtype: float64

# %%
#25 Remove duplicated rows in df based on last_name only. 


df.drop_duplicates(subset=["last_name"])
# Out:
#   first_name last_name  age  preTest  postTest
# 0      Jason    Miller   42        4        25
# 2       Tina       Ali   36       31        57
# 3       Jake    Milner   24        2        62

# %%
#26 Remove duplicated rows in df based on last_name only.
#Instead of keeping the first value, now keep the last of the duplicated values.

df.drop_duplicates(subset=["last_name"],keep="last")
# Out:
#   first_name last_name  age  preTest  postTest
# 1      Jason    Miller   42        4        25
# 2       Tina       Ali   36       31        57
# 4        Amy    Milner   73        3        70

# %%
from pandas import Series, DataFrame
import pandas as pd
from numpy.random import randn
import numpy as np
np.random.seed(42)
randomdata = DataFrame(np.random.randn(400, 4))
print randomdata
# %matplotlib inline
# Out:
#             0         1         2         3
# 0    0.496714 -0.138264  0.647689  1.523030
# 1   -0.234153 -0.234137  1.579213  0.767435
# 2   -0.469474  0.542560 -0.463418 -0.465730
# 3    0.241962 -1.913280 -1.724918 -0.562288
# 4   -1.012831  0.314247 -0.908024 -1.412304
# 5    1.465649 -0.225776  0.067528 -1.424748
# 6   -0.544383  0.110923 -1.150994  0.375698
# 7   -0.600639 -0.291694 -0.601707  1.852278
# 8   -0.013497 -1.057711  0.822545 -1.220844
# 9    0.208864 -1.959670 -1.328186  0.196861
# 10   0.738467  0.171368 -0.115648 -0.301104
# 11  -1.478522 -0.719844 -0.460639  1.057122
# 12   0.343618 -1.763040  0.324084 -0.385082
# 13  -0.676922  0.611676  1.031000  0.931280
# 14  -0.839218 -0.309212  0.331263  0.975545
# 15  -0.479174 -0.185659 -1.106335 -1.196207
# 16   0.812526  1.356240 -0.072010  1.003533
# 17   0.361636 -0.645120  0.361396  1.538037
# 18  -0.035826  1.564644 -2.619745  0.821903
# 19   0.087047 -0.299007  0.091761 -1.987569
# ...

# %%
#27 Use the "describe" function to summarize the randomdata created above.

randomdata.describe()
# Out:
#                 0           1           2           3
# count  400.000000  400.000000  400.000000  400.000000
# mean     0.035296    0.041202    0.046713    0.035939
# std      0.924153    1.028034    0.997816    1.024632
# min     -2.650970   -2.896255   -3.241267   -2.921350
# 25%     -0.612942   -0.651856   -0.602684   -0.683766
# 50%      0.052292    0.037928    0.036043    0.047190
# 75%      0.634986    0.676014    0.652834    0.744011
# max      2.526932    3.852731    3.078881    2.720169

# %%
#28 Identify the rows which contains at least one item with absolute value greater than 1

randomdata[randomdata[randomdata.abs() > 1].any(1)]
# Out:
#             0         1         2         3
# 0    0.496714 -0.138264  0.647689  1.523030
# 1   -0.234153 -0.234137  1.579213  0.767435
# 3    0.241962 -1.913280 -1.724918 -0.562288
# 4   -1.012831  0.314247 -0.908024 -1.412304
# 5    1.465649 -0.225776  0.067528 -1.424748
# 6   -0.544383  0.110923 -1.150994  0.375698
# 7   -0.600639 -0.291694 -0.601707  1.852278
# 8   -0.013497 -1.057711  0.822545 -1.220844
# 9    0.208864 -1.959670 -1.328186  0.196861
# 11  -1.478522 -0.719844 -0.460639  1.057122
# 12   0.343618 -1.763040  0.324084 -0.385082
# 13  -0.676922  0.611676  1.031000  0.931280
# 15  -0.479174 -0.185659 -1.106335 -1.196207
# 16   0.812526  1.356240 -0.072010  1.003533
# 17   0.361636 -0.645120  0.361396  1.538037
# 18  -0.035826  1.564644 -2.619745  0.821903
# 19   0.087047 -0.299007  0.091761 -1.987569
# 20  -0.219672  0.357113  1.477894 -0.518270
# 23  -0.702053 -0.327662 -0.392108 -1.463515
# 25  -1.415371 -0.420645 -0.342715 -0.802277
# ...

# %%
#29 Set the values greater than 3 to 3, and the values less than -3 to -3. 
#Rerun the 'describe' function to summarize the randomdata dataset.

randomdata[randomdata>3]=3
randomdata[randomdata<-3]=-3
randomdata.describe()
# Out:
#                 0           1           2           3
# count  400.000000  400.000000  400.000000  400.000000
# mean     0.035296    0.039070    0.047119    0.035939
# std      0.924153    1.020970    0.995301    1.024632
# min     -2.650970   -2.896255   -3.000000   -2.921350
# 25%     -0.612942   -0.651856   -0.602684   -0.683766
# 50%      0.052292    0.037928    0.036043    0.047190
# 75%      0.634986    0.676014    0.652834    0.744011
# max      2.526932    3.000000    3.000000    2.720169

# %%
df2 = pd.DataFrame(np.random.randn(59,4))
cols = ['GrossIn', 'GrossOut', 'NetIn', 'NetOut']
df2.columns = cols
dates = pd.date_range(start='2015-11-29', freq='W', periods=59)
df2.index = dates
df2
# Out:
#              GrossIn  GrossOut     NetIn    NetOut
# 2015-11-29 -0.182896  1.374876 -0.645964 -0.799192
# 2015-12-06 -0.482744 -0.953329  0.122670  1.624678
# 2015-12-13  0.323079 -0.252354 -0.291811 -1.563191
# 2015-12-20  0.883110 -0.077837 -0.180480  3.193108
# 2015-12-27  0.298753 -0.751791 -0.426358  1.148446
# 2016-01-03  0.113270 -1.438278  0.919229 -0.668144
# 2016-01-10  1.873298  1.080048 -0.447322  1.281016
# 2016-01-17  0.067856  0.852774  0.484733 -0.846357
# 2016-01-24 -0.643550  1.029961 -0.334775 -0.403648
# 2016-01-31 -0.955123  0.423599  2.062525 -1.067533
# 2016-02-07  0.024219  1.412221 -0.079641  0.452372
# 2016-02-14 -1.062394  0.428307 -0.187144  0.985730
# 2016-02-21  1.187386  2.589564  0.579633  0.325796
# 2016-02-28  0.194384 -0.353166  0.338484 -0.295401
# 2016-03-06  0.168461  1.317598 -1.006543  1.139879
# 2016-03-13  1.317115 -0.118069 -2.121855 -0.607822
# 2016-03-20  1.296995 -0.022868 -0.999302 -0.504775
# ...

# %%
#30 Print all the data from 2016-06-19 to 2016-10-20 in df2 above.

df2.ix['2016-06-19':'2016-10-20']
# Out:
#              GrossIn  GrossOut     NetIn    NetOut
# 2016-06-19  0.331980  0.190500  0.709452 -0.435486
# 2016-06-26  0.513106 -0.259547  0.738810  0.615367
# 2016-07-03 -0.935439  1.085982 -0.535963  0.808058
# 2016-07-10  0.367287  1.838184 -0.223466 -0.349317
# 2016-07-17 -0.019420 -0.303180  0.799942 -1.616311
# 2016-07-24 -1.053682 -1.067803  0.950308  1.710613
# 2016-07-31 -0.104449 -0.168822  0.070052  1.161878
# 2016-08-07 -0.927353  0.238369  0.975198  0.501094
# 2016-08-14  0.189582  1.001046 -2.703232  0.677875
# 2016-08-21 -0.654076 -1.830633  0.511203  1.373659
# 2016-08-28 -0.137449  0.952875  1.612278  1.314914
# 2016-09-04  1.639965  0.742127  0.075434 -1.601966
# 2016-09-11 -0.246062 -0.843247  2.170943 -0.175886
# 2016-09-18  0.123205  0.551485  0.043602  1.695051
# 2016-09-25 -0.622649  0.194607 -0.742471 -1.320023
# 2016-10-02 -0.611769 -0.037037 -0.429302 -0.692421
# 2016-10-09 -1.406317 -0.083106 -1.504720  0.760056
# ...

# %%
#32 Sum all the GrossOut and NetOut for the month of March 2016 in df2. Print the results.

df2.ix['2016-03',['GrossOut','NetOut']].sum()
# Out:
# GrossOut    1.723395
# NetOut     -0.339543
# dtype: float64

# %%
#33 Find all the days GrossOut was greater than GrossIn in df2. Print the results.

df2.ix[df2.GrossOut>df2.GrossIn]
# Out:
#              GrossIn  GrossOut     NetIn    NetOut
# 2015-11-29 -0.182896  1.374876 -0.645964 -0.799192
# 2016-01-17  0.067856  0.852774  0.484733 -0.846357
# 2016-01-24 -0.643550  1.029961 -0.334775 -0.403648
# 2016-01-31 -0.955123  0.423599  2.062525 -1.067533
# 2016-02-07  0.024219  1.412221 -0.079641  0.452372
# 2016-02-14 -1.062394  0.428307 -0.187144  0.985730
# 2016-02-21  1.187386  2.589564  0.579633  0.325796
# 2016-03-06  0.168461  1.317598 -1.006543  1.139879
# 2016-04-10  1.217159  1.521316  0.998311 -0.431620
# 2016-04-24 -1.179040  1.187679 -0.464617  0.201160
# 2016-05-15 -1.000331 -0.677745  0.513908  0.179582
# 2016-05-22  0.350630  0.489187  0.634721  1.109700
# 2016-06-12 -2.172670  0.847422 -0.535328 -0.090533
# 2016-07-03 -0.935439  1.085982 -0.535963  0.808058
# 2016-07-10  0.367287  1.838184 -0.223466 -0.349317
# 2016-08-07 -0.927353  0.238369  0.975198  0.501094
# 2016-08-14  0.189582  1.001046 -2.703232  0.677875
# ...

# %%
#34 What percentage was the total NetOut of the total NetIn in the year 2016 from df2 above?

SumOut=df2.ix['2016','NetOut'].sum()
SumIn=df2.ix['2016','NetIn'].sum()
print SumOut
print SumIn
#df2.ix['2016',['NetIn','NetOut']].sum()

"{:.1%}".format(SumIn/SumOut)
# Out:
# 4.72187203243
# 2.22411676835
# '47.1%'

# %%
"{:.1%}".format(0.471024363447)
# Out:
# '47.1%'

# %%
#35 Plot values for 2016 on a line graph for the GrossOut and GrossIn in df2:

df2.ix['2016',['GrossOut','GrossIn']].plot()

# %%
#36 Plot 4 different HISTOGRAMS of df2.GrossIn each having 5,10,15,20 bins.

#Hint: use the following code to plot the histograms on different subplots. 
import matplotlib.pyplot as plt
fig, ax = plt.subplots(nrows=2, ncols=2)
df2['GrossIn'].hist(ax=ax[0,0], bins=5)# this is just an example of how to plot on a top right subplot (2x2)
df2['GrossIn'].hist(ax=ax[0,1], bins=10)
df2['GrossIn'].hist(ax=ax[1,0], bins=15)
df2['GrossIn'].hist(ax=ax[1,1], bins=20)

# %% [markdown]
# #37 What is your favorite pizza topping? None is not a valid answer. I don't care if you are off gluten.
#
# Chicken

# %%
#38 Import pandas libary with the alias pd

import pandas as pd

pd
# Out:
# <module 'pandas' from '/bda/app/anaconda2/lib/python2.7/site-packages/pandas/__init__.pyc'>

# %%
#39 ou are given the Medicare spending dataset. Read it into a pandas dataframe. Then remove the 2 
# unused columns 'Measure Start Date' and 'Measure End Date' from the #DataFrame all in the following cell.

Medicare=pd.ExcelFile('URL=https://github.com/terratenney/yorkBigData/blob/master/tests%20and%20submissions/tests/Medicare_Hospital_Spending_by_Claim.csv')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-128-0302a25a7761> in <module>()
#       2 # unused columns 'Measure Start Date' and 'Measure End Date' from the #DataFrame all in the following cell.
#       3
# ----> 4 Medicare=pd.ExcelFile('URL=https://github.com/terratenney/yorkBigData/blob/master/tests%20and%20submissions/tests/Medicare_Hospital_Spending_by_Claim.csv')
#
# /bda/app/anaconda2/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, io, **kwds)
#     255             self.book = xlrd.open_workbook(file_contents=data)
#     256         elif isinstance(io, compat.string_types):
# --> 257             self.book = xlrd.open_workbook(io)
#     258         else:
#     259             raise ValueError('Must explicitly set engine if not passing in'
#
# ...

# %%
#40 Replace columns names...replace the original long column names in the dataframe above (Q - 39) 
#   with shorter ones provided below in "newColumns". Provide your code and the resulting new column names as the answer.

# %%
#41 Find the statistics of average (mean) and percentage spending for different states, claim types, and hospitals.
#   In the cell below using the same dataframe used in 39 and 40. Place your code and print your results in the cell below

# %%
#42 Continuing with data from above, convert the dataframe content to be the right "data type" (i.e., int, float, 
#   etc) in order to perform statistical calculations for the DataFrame. Provide your code and the resulting new 
#   print out as the answer. Hint convert the columns with % and $

# %%
#43  Continuing with the dataframe above, extract only the TX state claims into a new dataframe. Provide your 
#    code and print the new dataframe (with only TX claims) below as the answer.

# %%
#44 Using the dataframe from above (Q 42), find the average spending for each different TX hospitals 
#  groupedby each kind of different claim types. Provide your code and the resulting new print out as the answer.

# %%
#45 Continuing from above (Q 43), what is the mean and max percentage spending of different TX hospitals 
#   for each different claim types. Provide your code and print out the answer.

# %%
#46 Using the whole dataset from the Medicare_Hospital_Spending_by_Claim.csv table (i.e., Q 39-41), sort the
#   dataframe descending order by average spending and print out what the rank of TX is in terms of average 
#   spending when compared to other state averages.

# %% [markdown]
# #47 Give a very general and short definition of what an Analytical Model is or is supposed to do?
#
# Analytical models are representations of reality based on simplifications and assuptions.

# %% [markdown]
# #48 Briefly describe the differences between "supervised" and "unsupervised" learning.
#
# Supervised learning is when you are training your machine learning task for every input with corresponding target.
# You have input variables (x) and an output variable (Y) and you use an algorithm to learn the mapping function
# from the input to the output.
# Y = f(X)
# The goal is to approximate the mapping function so well that when you have new input data (x) that you can predict
# the output variables (Y) for that data.
#
# Unsupervised learning is when you are training your machine learning task only with a set of inputs. In other words,
# you only have input data (X) and no corresponding output variables. The goal for unsupervised learning is to model
# the underlying structure or distribution in the data in order to learn more about the data.

# %% [markdown]
# #49 Briefly describe the differences between "classification" and "clustering".
#
# Classification is the result of supervised learning which means that there is a known label that you
# want the system to generate. For example, if you built a fruit classifier, it would say this is an orange,
# this is an apple, based on you showing it examples of apples and oranges.
#
# Clustering is the result of unsupervised learning which means that you have seen lots of examples, but dont
# have labels. In this case, the clustering might return with probable groupings based on simply feeding
# lots of data to the system.

# %% [markdown]
# #50 Name 3 different "kinds" of Analytical Models and provide a brief definition of each.
#
# Algorithm:
# Uses a set of carefully defined instructions that take a set of inputs, manipulate them, and produce some output.
#
# Rules:
# Uses a set of rules that indirectly specifies a mathematical model.
#
# Deterministic Equation
# Outcomes are precisely determined through known relationships among states and events, without any room for random variation. Assumes that it's outcome is certain if the input to the model is fixed.

# %% [markdown]
# #51 Why is Ordinary Least Squares Regression, called Ordinary Least Squares?

# %% [markdown]
# #52 What makes "big data" different from "small data"? (Be brief - 1 to 2 paragaphs MAX)
#
# Small data is considered well packaged data easy of consumption. It comprises of small, definite
# and specific attributes of datasets which are capable on impacting present decisions.
#
# Big data, on the other hand, is a combination of structured and unstructured data often
# characterized by volume and the variety of the data and the velocity at which it is processed.
# Information or insights gleaned from big data can be useful in business decision making.

# %% [markdown]
# #53 What are WMD's according to Cathy O'Neil?
#
# Weapons of Math Destruction are models or algorithms embedded with prejudice, misunderstandings and bias that are increasingly managing people's lives.

# %% [markdown]
# #54 Why do vicious feedback loops matter in data analytics?

# %% [markdown]
# #55 What are the 10 simple rules Zook et. al. Suggest to follow when doing big data analytics?
#
# 1. Acknowledge that data are people and can do harm
# 2. Recognize that privacy is more than a binary value
# 3. Guard against the reidentification of your data
# 4. Practice ethical data sharing
# 5. Consider the strengths and limitations of your data; big does not automatically mean better
# 6. Debate the tough, ethical choices
# 7. Develop a code of conduct for your organization, research community, or industry
# 8. Design your data and systems for auditability
# 9. Engage with the broader consequences of data and analysis practices
# 10. Know when to break these rules
