# %%
# %matplotlib inline
# import naming conventions 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s1 = pd.Series([1,2,3,np.nan,4,5,6,])
s1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# 6    6.0
# dtype: float64

# %%
s1[4]
# Out:
# 4.0

# %%
s2, s3 = pd.Series(np.random.randn(7)), pd.Series(np.random.randn(7))

# %%
df_1 = pd.DataFrame({'L':s1, 'S':s2, 'D':s3})
df_1
# Out:
#           D    L         S
# 0  0.389645  1.0 -1.275130
# 1 -0.539700  2.0  0.354141
# 2 -2.207726  3.0  1.126386
# 3  0.153528  NaN  1.578892
# 4  0.410665  4.0 -1.103243
# 5 -0.289062  5.0  0.171781
# 6  1.081917  6.0 -0.462850

# %%
s4 = pd.Series(np.random.randn(8))
s4
df_2 = pd.DataFrame({'L':s1, 'S':s2, 'D':s3, 'I':s4})
df_2
# Out:
#           D         I    L         S
# 0  0.389645 -0.913547  1.0 -1.275130
# 1 -0.539700 -0.347036  2.0  0.354141
# 2 -2.207726 -1.464044  3.0  1.126386
# 3  0.153528  0.879223  NaN  1.578892
# 4  0.410665  0.492547  4.0 -1.103243
# 5 -0.289062 -0.370511  5.0  0.171781
# 6  1.081917  1.115706  6.0 -0.462850
# 7       NaN -0.365602  NaN       NaN

# %%
df1 = pd.DataFrame(np.random.randn(6,4))
df1
# Out:
#           0         1         2         3
# 0 -0.687556  0.044698 -0.658094 -1.184573
# 1 -0.366806 -0.209819  0.357502  0.386458
# 2 -2.622100 -0.962617  0.481618  0.000996
# 3  1.338379  1.916035  0.627795 -1.154134
# 4  0.437066 -0.213666  1.332349 -1.698361
# 5 -0.551033  0.394594 -1.298349  0.392193

# %%
df1.head(2)
# Out:
#           0         1         2         3
# 0 -0.687556  0.044698 -0.658094 -1.184573
# 1 -0.366806 -0.209819  0.357502  0.386458

# %%
cols = ['n', 'a', 'm', 'e']
df1.columns = cols
dates = pd.date_range(start='2017-11-21', freq='w', periods=6)
df1.index = dates
df1
# Out:
#                    n         a         m         e
# 2017-11-26 -0.687556  0.044698 -0.658094 -1.184573
# 2017-12-03 -0.366806 -0.209819  0.357502  0.386458
# 2017-12-10 -2.622100 -0.962617  0.481618  0.000996
# 2017-12-17  1.338379  1.916035  0.627795 -1.154134
# 2017-12-24  0.437066 -0.213666  1.332349 -1.698361
# 2017-12-31 -0.551033  0.394594 -1.298349  0.392193

# %%
dates
# Out:
# DatetimeIndex(['2017-11-26', '2017-12-03', '2017-12-10', '2017-12-17',
#                '2017-12-24', '2017-12-31'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
df1.loc['2017-12-17']
# Out:
# n    1.338379
# a    1.916035
# m    0.627795
# e   -1.154134
# Name: 2017-12-17 00:00:00, dtype: float64

# %%
df1.loc['2017-12-17', 'm']
# Out:
# 0.62779508303210796

# %%
gnacs_x = "id|postedTime|body|None|['twitter_entiteis:urls:url']|['None']|['actor:languages_list-items']|gnip:language:value|twitter_lang|[u'geo:coordinates_list-items']|geo:type|None|None|None|None|actor:utcOffset|None|None|None|None|None|None|None|None|None|actor:displayName|actor:preferredUsername|actor:id|gnip:klout_score|actor:followersCount|actor:friendsCount|actor:listedCount|actor:statusesCount|Tweet|None|None|None"
colnames = gnacs_x.split('|')

# %%
pd.set_option("display.max_columns", None)
df1 = pd.read_csv('../data/twitter_sample.csv', sep='|', names=colnames)
df1.head()
# Out:
#                                                id                postedTime  \
# 0  tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1  tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 2  tag:search.twitter.com,2005:351835317747191808  2013-07-01T22:50:51.000Z
# 3  tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 4  tag:search.twitter.com,2005:351835317755592705  2013-07-01T22:50:51.000Z
#
#                                                 body  \
# 0                         kavga edelim ama konuşalım
# 1                              @shane_joersz wooooow
# 2                           お前との肌のふれあいなんぞ求めてない。自重しろ。
# 3  @Gabo_navoficial yo tambien creo en ti mi char...
# 4  только ты об этом не знаешь... http://t.co/MOH...
#
#                                                 None  \
# 0                                               None
# 1                                               None
# ...

# %%
del df1['None']
df1.head()
# Out:
#                                                id                postedTime  \
# 0  tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1  tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 2  tag:search.twitter.com,2005:351835317747191808  2013-07-01T22:50:51.000Z
# 3  tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 4  tag:search.twitter.com,2005:351835317755592705  2013-07-01T22:50:51.000Z
#
#                                                 body  \
# 0                         kavga edelim ama konuşalım
# 1                              @shane_joersz wooooow
# 2                           お前との肌のふれあいなんぞ求めてない。自重しろ。
# 3  @Gabo_navoficial yo tambien creo en ti mi char...
# 4  только ты об этом не знаешь... http://t.co/MOH...
#
#   ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 0                          None     None                         ['tr']
# ...

# %%
df1[df1.twitter_lang == 'en'].head()
# Out:
#                                                 id                postedTime  \
# 8   tag:search.twitter.com,2005:351835318028222465  2013-07-01T22:50:51.000Z
# 9   tag:search.twitter.com,2005:351835318346981377  2013-07-01T22:50:51.000Z
# 11  tag:search.twitter.com,2005:351835318024028161  2013-07-01T22:50:51.000Z
# 12  tag:search.twitter.com,2005:351835318497980416  2013-07-01T22:50:51.000Z
# 15  tag:search.twitter.com,2005:351835318724468737  2013-07-01T22:50:51.000Z
#
#                                                  body  \
# 8                                @pafcdan Aww good! X
# 9   Newest hobby: sending videos back and forth of...
# 11                              ~FINALLY OFF OF WORK~
# 12  Rubbing/massaging my feet is like giving me he...
# 15         @Hayley_Brownn Same!!!! Very sad times😞😞😞😞
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 8                           None     None                         ['en']
# ...

# %%
df4 = df1[["actor:preferredUsername","gnip:klout_score","actor:followersCount","actor:friendsCount","actor:statusesCount"]]
df4.head()
# Out:
#   actor:preferredUsername gnip:klout_score  actor:followersCount  \
# 0           uykugibisiyok               35                   178
# 1                 CoBerg_               32                   144
# 2          yamasyoyamasyo               18                    37
# 3            maria_e_pena               50                   438
# 4                 ElkaAlb               21                    12
#
#    actor:friendsCount  actor:statusesCount
# 0                 129                 2028
# 1                 215                 4071
# 2                  54                 3505
# 3                 174                17636
# 4                   6                  145

# %%
df2 = df1[["gnip:klout_score","actor:followersCount","actor:friendsCount","actor:statusesCount"]]
df2.head()
# Out:
#   gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0               35                   178                 129
# 1               32                   144                 215
# 2               18                    37                  54
# 3               50                   438                 174
# 4               21                    12                   6
#
#    actor:statusesCount
# 0                 2028
# 1                 4071
# 2                 3505
# 3                17636
# 4                  145

# %%
df2.dtypes
# Out:
# gnip:klout_score        object
# actor:followersCount     int64
# actor:friendsCount       int64
# actor:statusesCount      int64
# dtype: object

# %%
def floatify(val):
    if val == None or val == 'None':
        return 0.0
    else:
        return float(val)

# %%
df2['gnip:klout_score'] = df2['gnip:klout_score'].map(floatify)
df2.dtypes
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# gnip:klout_score        float64
# actor:followersCount      int64
# actor:friendsCount        int64
# actor:statusesCount       int64
# dtype: object

# %%
df2['fol/fr'] = df2['gnip:klout_score'] / df2['actor:followersCount']
df2.head()
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0              35.0                   178                 129
# 1              32.0                   144                 215
# 2              18.0                    37                  54
# 3              50.0                   438                 174
# 4              21.0                    12                   6
#
#    actor:statusesCount    fol/fr
# 0                 2028  0.196629
# 1                 4071  0.222222
# 2                 3505  0.486486
# 3                17636  0.114155
# ...

# %%
df1.head()
# Out:
#                                                id                postedTime  \
# 0  tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1  tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 2  tag:search.twitter.com,2005:351835317747191808  2013-07-01T22:50:51.000Z
# 3  tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 4  tag:search.twitter.com,2005:351835317755592705  2013-07-01T22:50:51.000Z
#
#                                                 body  \
# 0                         kavga edelim ama konuşalım
# 1                              @shane_joersz wooooow
# 2                           お前との肌のふれあいなんぞ求めてない。自重しろ。
# 3  @Gabo_navoficial yo tambien creo en ti mi char...
# 4  только ты об этом не знаешь... http://t.co/MOH...
#
#   ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 0                          None     None                         ['tr']
# ...

# %%
df1.set_index('actor:followersCount').head()
# Out:
#                                                                   id  \
# actor:followersCount
# 178                   tag:search.twitter.com,2005:351835317671690241
# 144                   tag:search.twitter.com,2005:351835317604593666
# 37                    tag:search.twitter.com,2005:351835317747191808
# 438                   tag:search.twitter.com,2005:351835317608792064
# 12                    tag:search.twitter.com,2005:351835317755592705
#
#                                     postedTime  \
# actor:followersCount
# 178                   2013-07-01T22:50:51.000Z
# 144                   2013-07-01T22:50:51.000Z
# 37                    2013-07-01T22:50:51.000Z
# 438                   2013-07-01T22:50:51.000Z
# 12                    2013-07-01T22:50:51.000Z
#
#                                                                    body  \
# actor:followersCount
# 178                                          kavga edelim ama konuşalım
# ...

# %%
pop_df = df1[df1["actor:followersCount"] >= 100]
pop_df
# Out:
#                                                 id                postedTime  \
# 0   tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1   tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 3   tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 5   tag:search.twitter.com,2005:351835317801730048  2013-07-01T22:50:51.000Z
# 6   tag:search.twitter.com,2005:351835317554257920  2013-07-01T22:50:51.000Z
# 7   tag:search.twitter.com,2005:351835318552506369  2013-07-01T22:50:51.000Z
# 8   tag:search.twitter.com,2005:351835318028222465  2013-07-01T22:50:51.000Z
# 9   tag:search.twitter.com,2005:351835318346981377  2013-07-01T22:50:51.000Z
# 10  tag:search.twitter.com,2005:351835318044983298  2013-07-01T22:50:51.000Z
# 11  tag:search.twitter.com,2005:351835318024028161  2013-07-01T22:50:51.000Z
# 12  tag:search.twitter.com,2005:351835318497980416  2013-07-01T22:50:51.000Z
# ...

# %%
pop_df['gnip:klout_score'] = pop_df['gnip:klout_score'].map(floatify)
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pop_df.groupby("twitter_lang").size()
# Out:
# twitter_lang
# ar      1
# en     34
# es     14
# fr      1
# he      1
# id      4
# it      2
# ja      1
# ko      1
# lv      1
# pl      1
# pt     10
# tr      5
# und     2
# vi      1
# dtype: int64

# %%
lang_gb = pop_df[['twitter_lang',\
             'gnip:klout_score',\
             'actor:followersCount',\
             'actor:friendsCount',\
             'actor:statusesCount']].groupby('twitter_lang')
lang_gb

# %%
lang_gb.head()
# Out:
#    twitter_lang  gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0            tr              35.0                   178                 129
# 1            es              32.0                   144                 215
# 3            es              50.0                   438                 174
# 5            tr              41.0                   226                 346
# 6            pt              42.0                   247                  64
# 7            tr              40.0                   304                 233
# 8            en              38.0                   380                 860
# 9            en              41.0                   160                 135
# 10           es              62.0                 11873                  69
# 11           en              18.0                   290                 683
# 12           en              64.0                 40543                 116
# ...

# %%
lang_gb_mean = lang_gb.aggregate(np.mean)
lang_gb_mean.head()
# Out:
#               gnip:klout_score  actor:followersCount  actor:friendsCount  \
# twitter_lang
# ar                   40.000000            458.000000          413.000000
# en                   39.117647           1796.147059          582.735294
# es                   39.500000           1359.285714          441.142857
# fr                   40.000000            116.000000          122.000000
# he                   37.000000            151.000000          284.000000
#
#               actor:statusesCount
# twitter_lang
# ar                    1061.000000
# en                   16364.352941
# es                    8953.357143
# fr                    3174.000000
# he                     641.000000

# %%
lang_gb_mean['actor:followersCount'].plot(kind='bar')

# %%
plt.scatter(x=lang_gb_mean['actor:followersCount'],\
            y=lang_gb_mean['actor:friendsCount'],\
            alpha=0.5,\
            s=50,\
            color='violet',\
            marker='x')

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(lang_gb_mean, alpha=0.6, figsize=(6,6), diagonal='kde', s=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0381377c90>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0380c4c150>]], dtype=object)

# %%
df = pd.DataFrame(np.random.randn(50,4), index=pd.date_range('22/11/2017', periods=50), columns=list('ABCD'))
df = df.cumsum()
df.head()
# Out:
#                    A         B         C         D
# 2017-11-22  0.504051  0.654679 -0.462360  0.790246
# 2017-11-23 -0.640870 -2.083004 -1.006884  1.700764
# 2017-11-24  0.592502 -1.353608 -0.129412  1.747908
# 2017-11-25 -0.158127  0.744855  0.901424  2.731407
# 2017-11-26  0.750923  1.582929  1.093655  3.485069

# %%
df.plot()

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0380816c10>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0381120dd0>]], dtype=object)

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "distributions")))

# %%
x = np.random.normal(size=500)
sns.distplot(x)

# %%
x = np.random.normal(0, 1, size=40)
bandwidth = 1 * x.std() * x.size ** (-2 / 10.)
support = np.linspace(-6, 6, 200)

kernels = []
for x_i in x:

    kernel = stats.norm(x_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel, color="r")

sns.rugplot(x, color=".2", linewidth=3);

# %%
density = np.sum(kernels, axis=0)
density /= integrate.trapz(density, support)
plt.plot(support, density);

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

# %%
sns.jointplot(x="x", y="y", data=df);

# %%
x, y = np.random.multivariate_normal(mean, cov, 500).T
with sns.axes_style("ticks"):
    sns.jointplot(x=x, y=y, kind="hex", color="k");

# %%
sns.jointplot(x="x", y="y", data=df, kind="kde");

# %%
f, ax = plt.subplots(figsize=(4, 4))
sns.kdeplot(df.x, df.y, ax=ax)
sns.rugplot(df.x, color="g", ax=ax)
sns.rugplot(df.y, vertical=True, ax=ax);

# %%
f, ax = plt.subplots(figsize=(6, 6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(df.x, df.y, cmap=cmap, n_levels=60, shade=True);

# %%
g = sns.jointplot(x="x", y="y", data=df, kind="kde", color="c")
g.plot_joint(plt.scatter, c="w", s=25, linewidth=1, marker="o")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$");

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "regression")))

# %%
tips = sns.load_dataset("tips")

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="size", data=tips, x_jitter=.1);

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns.jointplot(x="size", y="tip", data=tips, kind="reg");

# %%
sns.pairplot(tips, x_vars=["total_bill", "tip"], y_vars=["size"],
             size=4, aspect=.6, kind="reg");

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
np.random.seed(sum(map(ord, "categorical")))

# %%
titanic = sns.load_dataset("titanic")
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %%
sns.stripplot(x="tip", y="day", data=tips);

# %%
sns.swarmplot(x="day", y="tip", hue="sex", data=tips);

# %%
sns.swarmplot(x="total_bill", y="tip", hue="sex", data=tips);

# %%
sns.boxplot(x="day", y="tip", hue="time", data=tips);

# %%
sns.violinplot(x="day", y="tip", hue="time", data=tips);

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips,
               split=True, inner="stick", palette="Set3");

# %%
sns.barplot(x="class", y="survived", hue="sex", data=titanic);

# %%
sns.countplot(y="deck", hue="sex", data=titanic);

# %%
sns.factorplot(x="day", y="tip", hue="smoker", data=tips);

# %%
sns.factorplot(x="day", y="total_bill", hue="smoker", data=tips, kind="bar");

# %%
sns.factorplot(x="tip", y="sex", hue="smoker",
               col="time", data=tips, kind="swarm");

# %%
g = sns.PairGrid(tips,
                 x_vars=["sex", "smoker", "time"],
                 y_vars=["total_bill", "tip"],
                 aspect=.75, size=3.5)
g.map(sns.violinplot, palette="pastel");
