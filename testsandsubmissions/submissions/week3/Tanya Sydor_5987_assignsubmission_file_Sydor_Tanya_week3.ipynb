# %%
# %matplotlib inline
# import naming conventions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pit

# %%
t2= pd.Series ([2,4,6,np.nan,7,9])
t2
# Out:
# 0    2.0
# 1    4.0
# 2    6.0
# 3    NaN
# 4    7.0
# 5    9.0
# dtype: float64

# %%
t2[4]
# Out:
# 7.0

# %%
t3, t4 = pd.Series(np.random.randn(6)), pd.Series(np.random.randn(6))
df_1= pd.DataFrame({'B':t2, 'C': t3, 'D': t4})

df_1
# Out:
#      B         C         D
# 0  2.0  0.978196  0.246055
# 1  4.0 -0.385436 -1.010749
# 2  6.0  0.701938 -0.175948
# 3  NaN  0.798343  1.329151
# 4  7.0  0.745079 -1.360710
# 5  9.0 -0.136678 -0.513812

# %%
t5= pd.Series(np.random.randn(9))
df1=pd.DataFrame({'B':t2, 'C': t3, 'D': t4, 'E': t5})
df1
# Out:
#      B         C         D         E
# 0  2.0  0.978196  0.246055  0.710307
# 1  4.0 -0.385436 -1.010749 -0.573443
# 2  6.0  0.701938 -0.175948 -1.879773
# 3  NaN  0.798343  1.329151  2.071119
# 4  7.0  0.745079 -1.360710 -0.021081
# 5  9.0 -0.136678 -0.513812 -0.138304
# 6  NaN       NaN       NaN  0.680894
# 7  NaN       NaN       NaN -0.760686
# 8  NaN       NaN       NaN -0.868289

# %%
df2=pd.DataFrame(np.random.randn(7,5))
df2

#print df2
#print df1
# Out:
#           0         1         2         3         4
# 0 -1.124229  0.886518  0.308125  0.772058  0.433351
# 1 -1.745745  0.459536  0.487846  0.073201 -0.373902
# 2  0.649341 -1.919932 -0.480962  1.390719  0.236460
# 3 -0.949608 -0.300028  0.295168  0.528118 -0.833133
# 4  1.512217 -0.900439 -0.446413  1.989078  1.911465
# 5  0.600581 -0.236864  0.342969  0.394662 -0.734292
# 6  0.233417  1.100094  0.242797  1.742114 -0.189130

# %%
df2.head(3)
# Out:
#           0         1         2         3         4
# 0 -1.124229  0.886518  0.308125  0.772058  0.433351
# 1 -1.745745  0.459536  0.487846  0.073201 -0.373902
# 2  0.649341 -1.919932 -0.480962  1.390719  0.236460

# %%
cols=['A', 'B', 'C', 'D', 'E']

df2.columns=cols

dates=pd.date_range(start='2012-10-14 14:50:26', freq="W", periods=7)
df2.index=dates

df2
# Out:
#                             A         B         C         D         E
# 2012-10-14 14:50:26 -1.124229  0.886518  0.308125  0.772058  0.433351
# 2012-10-21 14:50:26 -1.745745  0.459536  0.487846  0.073201 -0.373902
# 2012-10-28 14:50:26  0.649341 -1.919932 -0.480962  1.390719  0.236460
# 2012-11-04 14:50:26 -0.949608 -0.300028  0.295168  0.528118 -0.833133
# 2012-11-11 14:50:26  1.512217 -0.900439 -0.446413  1.989078  1.911465
# 2012-11-18 14:50:26  0.600581 -0.236864  0.342969  0.394662 -0.734292
# 2012-11-25 14:50:26  0.233417  1.100094  0.242797  1.742114 -0.189130

# %%
print 'what is date_range object?\n\n', dates
# Out:
# what is date_range object?
#
# DatetimeIndex(['2012-10-14 14:50:26', '2012-10-21 14:50:26',
#                '2012-10-28 14:50:26', '2012-11-04 14:50:26',
#                '2012-11-11 14:50:26', '2012-11-18 14:50:26',
#                '2012-11-25 14:50:26'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
df2.loc['2012-10-28 14:50:26']
# Out:
# A    0.649341
# B   -1.919932
# C   -0.480962
# D    1.390719
# E    0.236460
# Name: 2012-10-28 14:50:26, dtype: float64

# %%
df2.loc['2012-11-11 14:50:26','D']
# Out:
# 1.9890778643547258

# %%
df1 = pd.DataFrame(np.random.randn(7,5), index=list('abcdefg'),columns=list('ABCDE'))
df1
# Out:
#           A         B         C         D         E
# a  0.820299 -0.880621 -0.648478 -0.571280 -0.272722
# b -1.327494  1.777837 -0.199130  0.809300  0.299679
# c  0.437217 -0.458778 -0.350443  0.119292  0.215994
# d -0.131138  0.115467  0.662423 -0.080802  0.044405
# e  0.263552 -1.803940  0.502456 -1.981234 -0.185633
# f  1.646410  2.350973 -0.563439  0.039956 -1.459549
# g -0.512932 -0.426132 -0.590210  0.588430  0.163326

# %%
df1.loc[['e','g'], 'B':'D']
# Out:
#           B         C         D
# e -1.803940  0.502456 -1.981234
# g -0.426132 -0.590210  0.588430

# %%
gnacs_x = "id|postedTime|body|None|['twitter_entiteis:urls:url']|['None']|['actor:languages_list-items']|gnip:language:value|twitter_lang|[u'geo:coordinates_list-items']|geo:type|None|None|None|None|actor:utcOffset|None|None|None|None|None|None|None|None|None|actor:displayName|actor:preferredUsername|actor:id|gnip:klout_score|actor:followersCount|actor:friendsCount|actor:listedCount|actor:statusesCount|Tweet|None|None|None"
colnames = gnacs_x.split('|')

# %%
pd.set_option("display.max_columns", None)

df1= pd.read_csv('/home/id302252/Documents/twitter_sample.csv', sep='|', names=colnames)
df1.tail(8)
# Out:
#                                                 id                postedTime  \
# 87  tag:search.twitter.com,2005:351835321056509952  2013-07-01T22:50:51.000Z
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 87  And I'm the one that always gets hit on. OKAAAAY.  None
# 88                             @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# 92  O matheus André ta me falando aqui , tem quase...  None
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...  None
# 94                                           😕 Hmm...  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 87                          None     None                         ['en']
# 88                          None     None                         ['en']
# 89                          None     None                         ['it']
# 90                          None     None                         ['it']
# 91                          None     None                         ['pt']
# 92                          None     None                         ['pt']
# 93                          None     None                         ['en']
# 94                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 87                  en           en    [34.09956425, -117.40411515]    Point
# 88                  en           vi      [53.28722009, -3.21569687]    Point
# 89                  it           it                            None     None
# 90                  it           it          [41.73604, 12.2890263]    Point
# 91                  pt           pt                            None     None
# 92                  pt           pt    [-22.72046574, -43.57919689]    Point
# 93                  en           en       [52.21599153, 6.88528201]    Point
# 94                None           en     [42.21746118, -78.03367083]    Point
#
#                                                None.1   None.2  \
# 87  ['[-117.436711, 34.023746]', '[-117.436711, 34...  Polygon
# 88  ['[-3.400604, 53.072143999999994]', '[-3.40060...  Polygon
# 89  ['[14.1332005, 40.7920697]', '[14.1332005, 40....  Polygon
# 90  ['[12.2344266, 41.6558738]', '[12.2344266, 42....  Polygon
# 91  ['[-50.899727999999996, -21.454719]', '[-50.89...  Polygon
# 92  ['[-43.645123999999996, -22.783967999999998]',...  Polygon
# 93  ['[6.7559955, 52.1611799]', '[6.7559955, 52.28...  Polygon
# 94  ['[-78.045887, 42.212985]', '[-78.045887, 42.2...  Polygon
#
#                        None.3 None.4 actor:utcOffset  \
# 87                 Rialto, CA     US          -28800
# 88     Flintshire, Flintshire     GB               0
# 89             Napoli, Napoli     IT            None
# 90                 Roma, Roma     IT            7200
# 91       Araçatuba, São Paulo     BR          -10800
# 92  Queimados, Rio de Janeiro     BR          -10800
# 93                   Enschede     NL            3600
# 94                Belmont, NY     US            None
#
#                            None.5 None.6 None.7 None.8 None.9 None.10 None.11  \
# 87                   Arizona-Cali   None   None   None   None    None    None
# 88  Leeds- UK / Greenfield- Wales   None   None   None   None    None    None
# 89         #bagdr @limitdemibagdr   None   None   None   None    None    None
# 90                  Big Ben's tip   None   None   None   None    None    None
# 91             na cama do mari :p   None   None   None   None    None    None
# 92                 Rio de Janeiro   None   None   None   None    None    None
# 93           Netherlands\Enschede   None   None   None   None    None    None
# 94                           None   None   None   None   None    None    None
#
#    None.12 None.13    actor:displayName actor:preferredUsername    actor:id  \
# 87    None    None               Cilli♡            Cilli_021112   382278854
# 88    None    None              marshaa            marshaleighm   269323425
# 89    None    None                demi.               demibagdr  1542203100
# 90    None    None     She's my Louis ❤            xliamsdreams   562092674
# 91    None    None         lorena uai ∞            Fc_GritaAmor   397609113
# 92    None    None              Shelyda             ShelydaDays    70959019
# 93    None    None                    L                Karkooba  1252736376
# 94    None    None  Lindsey Chamberlain             Linnyy_Kayy   466042520
#
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 87               30                   557                 440
# 88               44                   767                 486
# 89               44                    64                  58
# 90               53                  5084                3802
# 91               44                  1248                1962
# 92               40                   128                  76
# 93               30                    48                  88
# 94               41                   198                 188
#
#     actor:listedCount  actor:statusesCount  Tweet  \
# 87                  1                18434  Tweet
# 88                  0                17549  Reply
# 89                  0                 1872  Reply
# 90                 11                30163  Reply
# 91                  0                11161  Tweet
# 92                  0                 1419  Tweet
# 93                  0                  957  Reply
# 94                  0                 1897  Tweet
#
#                                               None.14 None.15 None.16
# 87                                               None    None    None
# 88  http://twitter.com/CheniseFowlisX/statuses/351...    None    None
# 89  http://twitter.com/justinbagdr/statuses/351833...    None    None
# 90  http://twitter.com/xhazzasdimples/statuses/351...    None    None
# 91                                               None    None    None
# 92                                               None    None    None
# 93  http://twitter.com/Mulayhim/statuses/351817617...    None    None
# 94                                               None    None    None

# %%
del df1['None']

# %%
df1.tail(7)
# Out:
#                                                 id                postedTime  \
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  \
# 88                             @CheniseFowlisX yeah 😂
# 89           @justinbagdr no, non mi far star meglio.
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...
# 91  Mandei a foto do Piqué e o fc n respondeu até ...
# 92  O matheus André ta me falando aqui , tem quase...
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...
# 94                                           😕 Hmm...
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 88                          None     None                         ['en']
# 89                          None     None                         ['it']
# 90                          None     None                         ['it']
# 91                          None     None                         ['pt']
# 92                          None     None                         ['pt']
# 93                          None     None                         ['en']
# 94                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 88                  en           vi      [53.28722009, -3.21569687]    Point
# 89                  it           it                            None     None
# 90                  it           it          [41.73604, 12.2890263]    Point
# 91                  pt           pt                            None     None
# 92                  pt           pt    [-22.72046574, -43.57919689]    Point
# 93                  en           en       [52.21599153, 6.88528201]    Point
# 94                None           en     [42.21746118, -78.03367083]    Point
#
#                                                None.1   None.2  \
# 88  ['[-3.400604, 53.072143999999994]', '[-3.40060...  Polygon
# 89  ['[14.1332005, 40.7920697]', '[14.1332005, 40....  Polygon
# 90  ['[12.2344266, 41.6558738]', '[12.2344266, 42....  Polygon
# 91  ['[-50.899727999999996, -21.454719]', '[-50.89...  Polygon
# 92  ['[-43.645123999999996, -22.783967999999998]',...  Polygon
# 93  ['[6.7559955, 52.1611799]', '[6.7559955, 52.28...  Polygon
# 94  ['[-78.045887, 42.212985]', '[-78.045887, 42.2...  Polygon
#
#                        None.3 None.4 actor:utcOffset  \
# 88     Flintshire, Flintshire     GB               0
# 89             Napoli, Napoli     IT            None
# 90                 Roma, Roma     IT            7200
# 91       Araçatuba, São Paulo     BR          -10800
# 92  Queimados, Rio de Janeiro     BR          -10800
# 93                   Enschede     NL            3600
# 94                Belmont, NY     US            None
#
#                            None.5 None.6 None.7 None.8 None.9 None.10 None.11  \
# 88  Leeds- UK / Greenfield- Wales   None   None   None   None    None    None
# 89         #bagdr @limitdemibagdr   None   None   None   None    None    None
# 90                  Big Ben's tip   None   None   None   None    None    None
# 91             na cama do mari :p   None   None   None   None    None    None
# 92                 Rio de Janeiro   None   None   None   None    None    None
# 93           Netherlands\Enschede   None   None   None   None    None    None
# 94                           None   None   None   None   None    None    None
#
#    None.12 None.13    actor:displayName actor:preferredUsername    actor:id  \
# 88    None    None              marshaa            marshaleighm   269323425
# 89    None    None                demi.               demibagdr  1542203100
# 90    None    None     She's my Louis ❤            xliamsdreams   562092674
# 91    None    None         lorena uai ∞            Fc_GritaAmor   397609113
# 92    None    None              Shelyda             ShelydaDays    70959019
# 93    None    None                    L                Karkooba  1252736376
# 94    None    None  Lindsey Chamberlain             Linnyy_Kayy   466042520
#
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 88               44                   767                 486
# 89               44                    64                  58
# 90               53                  5084                3802
# 91               44                  1248                1962
# 92               40                   128                  76
# 93               30                    48                  88
# 94               41                   198                 188
#
#     actor:listedCount  actor:statusesCount  Tweet  \
# 88                  0                17549  Reply
# 89                  0                 1872  Reply
# 90                 11                30163  Reply
# 91                  0                11161  Tweet
# 92                  0                 1419  Tweet
# 93                  0                  957  Reply
# 94                  0                 1897  Tweet
#
#                                               None.14 None.15 None.16
# 88  http://twitter.com/CheniseFowlisX/statuses/351...    None    None
# 89  http://twitter.com/justinbagdr/statuses/351833...    None    None
# 90  http://twitter.com/xhazzasdimples/statuses/351...    None    None
# 91                                               None    None    None
# 92                                               None    None    None
# 93  http://twitter.com/Mulayhim/statuses/351817617...    None    None
# 94                                               None    None    None

# %%
df1[df1.twitter_lang=='en'].head()
#df1[df1["gnip:language:value"]=='en'].head()
# Out:
#                                                 id                postedTime  \
# 8   tag:search.twitter.com,2005:351835318028222465  2013-07-01T22:50:51.000Z
# 9   tag:search.twitter.com,2005:351835318346981377  2013-07-01T22:50:51.000Z
# 11  tag:search.twitter.com,2005:351835318024028161  2013-07-01T22:50:51.000Z
# 12  tag:search.twitter.com,2005:351835318497980416  2013-07-01T22:50:51.000Z
# 15  tag:search.twitter.com,2005:351835318724468737  2013-07-01T22:50:51.000Z
#
#                                                  body  \
# 8                                @pafcdan Aww good! X
# 9   Newest hobby: sending videos back and forth of...
# 11                              ~FINALLY OFF OF WORK~
# 12  Rubbing/massaging my feet is like giving me he...
# 15         @Hayley_Brownn Same!!!! Very sad times😞😞😞😞
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 8                           None     None                         ['en']
# 9                           None     None                         ['en']
# 11                          None     None                         ['en']
# 12                          None     None                         ['en']
# 15                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 8                   en           en        [50.3582949, -4.0930973]    Point
# 9                   en           en     [29.54588264, -95.10669141]    Point
# 11                  en           en           [32.86107, -83.72062]    Point
# 12                  en           en     [33.68890281, -84.27369741]    Point
# 15                  en           en       [54.6884467, -3.51776393]    Point
#
#                                                None.1   None.2  \
# 8   ['[-4.209496, 50.3320883]', '[-4.209496, 50.44...  Polygon
# 9   ['[-95.145152, 29.506973]', '[-95.145152, 29.5...  Polygon
# 11  ['[-83.739741, 32.765651]', '[-83.739741, 32.8...  Polygon
# 12  ['[-85.605165, 30.355756999999997]', '[-85.605...  Polygon
# 15  ['[-3.580063, 54.454108]', '[-3.580063, 54.964...  Polygon
#
#                 None.3 None.4 actor:utcOffset          None.5 None.6 None.7  \
# 8   Plymouth, Plymouth     GB               0        Plymouth   None   None
# 9          Webster, TX     US            None  Houston, Texas   None   None
# 11           Macon, GA     US            None            None   None   None
# 12         Georgia, US     US          -18000          Atl...   None   None
# 15  Allerdale, Cumbria     GB          -36000            None   None   None
#
#    None.8 None.9 None.10 None.11 None.12 None.13 actor:displayName  \
# 8    None   None    None    None    None    None           Becky ❤
# 9    None   None    None    None    None    None       lil beyoncé
# 11   None   None    None    None    None    None    Tomeisha Cross
# 12   None   None    None    None    None    None          Poison †
# 15   None   None    None    None    None    None         Karl Hine
#
#    actor:preferredUsername   actor:id gnip:klout_score  actor:followersCount  \
# 8              BeckyLou90x   26568635               38                   380
# 9               beezlebrat  541953037               41                   160
# 11           MISSMEISHA223  242505369               18                   290
# 12              shanbonita   29619102               64                 40543
# 15                KarlHine  402334657               42                   417
#
#     actor:friendsCount  actor:listedCount  actor:statusesCount  Tweet  \
# 8                  860                  0                 3116  Reply
# 9                  135                  0                 4170  Tweet
# 11                 683                  0                  540  Tweet
# 12                 116                486                60465  Tweet
# 15                 259                  1                 5242  Reply
#
#                                               None.14 None.15 None.16
# 8   http://twitter.com/pafcdan/statuses/3518344574...    None    None
# 9                                                None    None    None
# 11                                               None    None    None
# 12                                               None    None    None
# 15  http://twitter.com/Hayley_Brownn/statuses/3518...    None    None

# %%
df2 = df1[["gnip:klout_score","actor:followersCount", "actor:friendsCount", "actor:listedCount"]]

df2.head()
# Out:
#   gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0               35                   178                 129
# 1               32                   144                 215
# 2               18                    37                  54
# 3               50                   438                 174
# 4               21                    12                   6
#
#    actor:listedCount
# 0                  0
# 1                  0
# 2                  0
# 3                  1
# 4                  0

# %%
df2.dtypes
# Out:
# gnip:klout_score        object
# actor:followersCount     int64
# actor:friendsCount       int64
# actor:listedCount        int64
# dtype: object

# %%
def floatify(val):
    if val == None or val == 'None':
        return 0.0
    else: 
        return float(val)

# %%
df2['gnip:klout_score']=df2['gnip:klout_score'].map(floatify)
df2.dtypes
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# gnip:klout_score        float64
# actor:followersCount      int64
# actor:friendsCount        int64
# actor:listedCount         int64
# dtype: object

# %%
df2=df2.astype(float)
df2.dtypes
# Out:
# gnip:klout_score        float64
# actor:followersCount    float64
# actor:friendsCount      float64
# actor:listedCount       float64
# dtype: object

# %%
df2['fol/fr'] = df2['gnip:klout_score'] / df2['actor:followersCount']

df2.head()
# Out:
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0              35.0                 178.0               129.0
# 1              32.0                 144.0               215.0
# 2              18.0                  37.0                54.0
# 3              50.0                 438.0               174.0
# 4              21.0                  12.0                 6.0
#
#    actor:listedCount    fol/fr
# 0                0.0  0.196629
# 1                0.0  0.222222
# 2                0.0  0.486486
# 3                1.0  0.114155
# 4                0.0  1.750000

# %%
df1.head()
# Out:
#                                                id                postedTime  \
# 0  tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1  tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 2  tag:search.twitter.com,2005:351835317747191808  2013-07-01T22:50:51.000Z
# 3  tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 4  tag:search.twitter.com,2005:351835317755592705  2013-07-01T22:50:51.000Z
#
#                                                 body  \
# 0                         kavga edelim ama konuşalım
# 1                              @shane_joersz wooooow
# 2                           お前との肌のふれあいなんぞ求めてない。自重しろ。
# 3  @Gabo_navoficial yo tambien creo en ti mi char...
# 4  только ты об этом не знаешь... http://t.co/MOH...
#
#   ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 0                          None     None                         ['tr']
# 1                          None     None                         ['en']
# 2                          None     None                         ['ja']
# 3                          None     None                         ['en']
# 4                          None     None                         ['ru']
#
#   gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 0                  en           tr                            None     None
# 1                  en           es     [47.29088246, -101.0379045]    Point
# 2                  en           ja     [35.70675048, 139.84273005]    Point
# 3                  en           es                            None     None
# 4                  en           ru                            None     None
#
#                                               None.1   None.2         None.3  \
# 0  ['[25.663883, 35.817497]', '[25.663883, 42.109...  Polygon        Türkiye
# 1  ['[-101.043785, 47.275933]', '[-101.043785, 47...  Polygon   Washburn, ND
# 2  ['[139.8332175, 35.6345694444444]', '[139.8332...  Polygon      江戸川区, 東京都
# 3  ['[-80.248663, 25.986366]', '[-80.248663, 26.0...  Polygon  Hollywood, FL
# 4  ['[23.179216999999998, 51.2626423]', '[23.1792...  Polygon        Belarus
#
#   None.4 actor:utcOffset             None.5 None.6 None.7 None.8 None.9  \
# 0     TR            7200               None   None   None   None   None
# 1     US          -21600         sevenohone   None   None   None   None
# 2     JP          -36000                 ちば   None   None   None   None
# 3     US          -14400  hollywood florida   None   None   None   None
# 4     BY            None               None   None   None   None   None
#
#   None.10 None.11 None.12 None.13 actor:displayName actor:preferredUsername  \
# 0    None    None    None    None   Rümeysa Özdemir           uykugibisiyok
# 1    None    None    None    None        cori▲alex.                 CoBerg_
# 2    None    None    None    None              黒い恋人          yamasyoyamasyo
# 3    None    None    None    None             MARIA            maria_e_pena
# 4    None    None    None    None         Элька Алб                 ElkaAlb
#
#      actor:id gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0   248312738               35                   178                 129
# 1    48025164               32                   144                 215
# 2   217987801               18                    37                  54
# 3   461188787               50                   438                 174
# 4  1433828712               21                    12                   6
#
#    actor:listedCount  actor:statusesCount  Tweet  \
# 0                  0                 2028  Tweet
# 1                  0                 4071  Reply
# 2                  0                 3505  Tweet
# 3                  1                17636  Reply
# 4                  0                  145  Tweet
#
#                                              None.14 None.15 None.16
# 0                                               None    None    None
# 1  http://twitter.com/shane_joersz/statuses/35182...    None    None
# 2                                               None    None    None
# 3  http://twitter.com/Gabo_navoficial/statuses/35...    None    None
# 4                                               None    None    None

# %%
pop_df=df1[df1["actor:followersCount"]>=100]

#pop_df['gnip:klout_score'] = pop_df['gnip:klout_score'].map(floatify)

#pop_df.head()

#pop_df.groupby("twitter_lang").size()      # number of elements per group
#pop_df.groupby("twitter_lang").sum()       # sum of elements in each group (obviously doesn't make sense for some cols) 
#pop_df.groupby("twitter_lang").mean()

# %%
lang_gb = pop_df[['twitter_lang',\
             'gnip:klout_score',\
             'actor:followersCount',\
             'actor:friendsCount',\
             'actor:statusesCount']].groupby('twitter_lang')

lang_gb.head(3)  

#lang_gb
# Out:
#    twitter_lang gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0            tr               35                   178                 129
# 1            es               32                   144                 215
# 3            es               50                   438                 174
# 5            tr               41                   226                 346
# 6            pt               42                   247                  64
# 7            tr               40                   304                 233
# 8            en               38                   380                 860
# 9            en               41                   160                 135
# 10           es               62                 11873                  69
# 11           en               18                   290                 683
# 16          und               53                  1179                 628
# 18           he               37                   151                 284
# 20           it               46                  1999                 293
# 21           pt               43                   137                  89
# 22           id               43                   258                 302
# 24           pl               48                  2037                1984
# 27           pt               38                   231                 352
# 29           id               33                   404                 378
# 33           ko               39                   170                 120
# 38          und               35                   228                 185
# 42           ar               40                   458                 413
# 43           fr               40                   116                 122
# 57           id               48                   727                 157
# 64           ja               28                   152                 335
# 79           lv               41                   297                 237
# 88           vi               44                   767                 486
# 90           it               53                  5084                3802
#
#     actor:statusesCount
# 0                  2028
# 1                  4071
# 3                 17636
# 5                  7759
# 6                  2438
# 7                  3558
# 8                  3116
# 9                  4170
# 10                 1991
# 11                  540
# 16                20141
# 18                  641
# 20                60236
# 21                 4047
# 22                 2732
# 24                23240
# 27                15233
# 29                 9181
# 33                 1094
# 38                24571
# 42                 1061
# 43                 3174
# 57                13176
# 64                 2151
# 79                 5221
# 88                17549
# 90                30163

# %%
lang_gb_mean=lang_gb.aggregate(np.mean)

lang_gb_mean.head()

#lang_gb_mean.index
# Out:
#               actor:followersCount  actor:friendsCount  actor:statusesCount
# twitter_lang
# ar                      458.000000          413.000000          1061.000000
# en                     1796.147059          582.735294         16364.352941
# es                     1359.285714          441.142857          8953.357143
# fr                      116.000000          122.000000          3174.000000
# he                      151.000000          284.000000           641.000000

# %%
lang_gb_mean['actor:followersCount'].plot(kind='bar',color='g')

# %%
lang_gb_mean['actor:friendsCount'].plot(kind='bar', color='g')

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=lang_gb_mean['actor:followersCount'],\
            y=lang_gb_mean['actor:friendsCount'],\
            alpha=1,\
            s=100,\
            color='blue',\
            marker='o')

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(lang_gb_mean, alpha=0.5, figsize= (10,10), diagonal='kde', s=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe0b630d1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe0b6209a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe0b618eb50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe0b6101410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe0b6087510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe0b5fecd90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe0b5f81090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe0b5f67850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe0b5e6bbd0>]], dtype=object)

# %%
df=pd.DataFrame(np.random.randn(1000,4), index=pd.date_range('2/1/2001', periods=1000), columns=list('ABCD'))
df = df.cumsum()
df.head()
# Out:
#                    A         B         C         D
# 2001-02-01 -1.184097 -1.022059 -0.187782 -1.468652
# 2001-02-02 -1.249144  1.564559  0.889094 -0.916807
# 2001-02-03  0.199263  1.467132 -0.304762 -1.039061
# 2001-02-04 -1.031437  0.075415 -1.908129 -2.331702
# 2001-02-05 -0.751329 -0.371256 -2.299911 -4.417789

# %%
df.plot()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe0adac65d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe0ad98ebd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe0ad914c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe0ad906650>]], dtype=object)

# %%
import prettyplotlib

df.plot()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe0ad784b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe0ad675090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe0ad5e7f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe0ad5580d0>]], dtype=object)

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate 
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord,"distributions")))

# %%
y=np.random.normal(size=200)
sns.distplot(y)

# %%
sns.distplot(y, kde=False,rug=True)

# %%
sns.distplot(y, bins=40, kde=False, rug=True)

# %%
sns.distplot(y, hist=False, rug=True)

# %%
y=np.random.normal(0, 1, size=40)
bandwidth= 1.06 * y.std() * y.size ** (-1/5.)
support= np.linspace(-4,4,200)
                     
kernels= []
for y_i in y:
    kernel=stats.norm(y_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel, color="g")
    
sns.rugplot(y, color=".2", linewidth=3);

# %%
density=np.sum(kernels, axis=0)
density /=integrate.trapz(density, support)
plt.plot(support, density);

# %%
sns.kdeplot(y, shade=True)

# %%
sns.kdeplot(y)
sns.kdeplot(y, bw=.2, label= "bw:0.2")
sns.kdeplot(y, bw=2, label="bw:2")
plt.legend();

# %%
sns.kdeplot(y, shade=True, cut=0)
sns.kdeplot(y)

# %%
sns.kdeplot(y, shade=True, cut=0)
sns.rugplot(y)

# %%
sns.kdeplot(y)
sns.kdeplot(y, bw=.2, label= "bw:0.2")
sns.kdeplot(y, bw=2, label="bw:2")
plt.legend();

# %%
sns.kdeplot(y, shade=True, cut=0)
sns.rugplot(y)

# %%
y=np.random.gamma(7, size=100)
sns.distplot(y, kde=False, fit=stats.gamma);

# %%
mean, cov= [0,1], [(1,.5), (.5,1)]
data= np.random.multivariate_normal(mean, cov, 100)
df=pd.DataFrame(data, columns=["x","y"])

# %%
sns.jointplot(x="x", y="y", data=df);

# %%
x,y= np.random.multivariate_normal(mean, cov, 1000).T
with sns. axes_style("white"):
    sns.jointplot(x=x, y=y, kind="hex")

# %%
x,y= np.random.multivariate_normal(mean, cov, 1000).T
with sns. axes_style("dark"):
    sns.jointplot(x=x, y=y, kind="hex")

# %%
f, ax=plt.subplots(figsize=(8,8))
sns.kdeplot(df.x, df.y, ax=ax)
sns.rugplot(df.x, color="r", ax=ax)
sns.rugplot(df.y, vertical=True, ax=ax)

# %%
f, ax=plt.subplots(figsize=(8,8))
cmap=sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(df.x, df.y, cmap=cmap, n_levels=60, shade=True)

# %%
g=sns.jointplot(x="x", y="y", data=df, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$");

# %%
iris=sns.load_dataset("iris")
sns.pairplot(iris);

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, cmp="Blues_d", n_levels=6);
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord,"regression")))

# %%
tips= sns.load_dataset("tips")

# %%
sns.regplot(x="total_bill", y="tip", data=tips)

# %%
sns. lmplot(x="total_bill", y="tip", data=tips)

# %%
sns.lmplot(x="size", y="tip", data=tips)

# %%
sns.lmplot (x="size", y="tip", data=tips, x_jitter=.05)

# %%
sns.lmplot(x="size", y="tip", data=tips, x_estimator=np.mean);

# %%
anscombe=sns.load_dataset("anscombe")

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset=='I'"),
            ci=None, scatter_kws={"s" : 80})

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset=='II'"), 
           order=2, ci=None, scatter_kws={"s":80})

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset=='III'"),
          ci=None, scatter_kws={"s": 80});

# %%
tips["big_tip"]=(tips.tip/tips.total_bill)>.15
sns.lmplot(x="total_bill", y="big_tip", data=tips, 
          y_jitter=.03)

# %%
sns.lmplot(x="total_bill", y="big_tip", data=tips,
          logistic=True, y_jitter=.03)

# %%
sns.lmplot(x="total_bill", y="tip", data=tips,
          lowess=True);

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset=='I'"),
             scatter_kws={"s": 80});

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips,
          markers=["o", "x"], palette="Set1")

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", 
          col="time", row="sex", data=tips);

# %%
f, ax=plt.subplots(figsize=(5,6))
sns.regplot(x="total_bill", y="tip", data=tips, ax=ax);

# %%
sns.lmplot(x="total_bill", y="tip", col="day", data=tips, 
          col_wrap=2, size=3)

# %%
sns.lmplot(x="total_bill", y="tip", col="day", data=tips,
            aspect=.5)

# %%
sns.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"], 
          size=5, aspect=.6, kind='reg')

# %%
sns.pairplot(tips,x_vars=["total_bill","size"], y_vars=["tip"], 
            hue="smoker", size=5, aspect=.8, kind="reg")

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
np.random.seed(sum(map(ord, "categorical")))

# %%
titanic=sns.load_dataset("titanic")
tips=sns.load_dataset("tips")
iris=sns.load_dataset("iris")

# %%
sns.stripplot(x="day", y="total_bill", data=tips)

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)

# %%
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips)

# %%
sns.swarmplot(x="total_bill", y="day", hue="time", data=tips)

# %%
sns.boxplot(x="day", y="total_bill", hue="time", data=tips)

# %%
tips["weekend"]=tips["day"].isin(["Sat", "Sun"])
sns.boxplot(x="day", y="total_bill", hue="weekend", data=tips, dodge=False)

# %%
sns.violinplot(x="total_bill", y="day", hue="time", data=tips)

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True)

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
sns.swarmplot(x="day", y="total_bill", data=tips, color="w", alpha=.5)

# %%
sns.barplot(x="sex", y="survived", hue="class", data=titanic)

# %%
sns.countplot(x="deck", data=titanic, palette="Greens_d")

# %%
sns.countplot(y="deck", hue="class", data=titanic, palette="Greens_d")

# %%
sns.pointplot(x="sex", y="survived", hue="class", data=titanic)

# %%
sns.pointplot(x="class", y="survived", hue="sex", data=titanic, 
             palette={"male":"g", "female":"m"},
             markers=["^", "o"], linestyles=["-", "--"])

# %%
sns.boxplot(data=iris, orient="h")

# %%
sns.violinplot(x=iris.species, y=iris.sepal_length)

# %%
f, ax=plt.subplots(figsize=(7,3))
sns.countplot(y="deck", data=titanic, color="c")

# %%
sns.factorplot(x="day", y="total_bill", hue="smoker", data=tips)

# %%
sns.factorplot(x="day", y="total_bill", hue="smoker", data=tips, kind="bar")

# %%
sns.factorplot(x="day", y="total_bill", hue="smoker", 
              col="time", data=tips, kind="swarm")

# %%
sns.factorplot(x="time", y="total_bill", hue="smoker",
              col="day", data=tips, kind="box", size=4, aspect=.5)

# %%
g=sns.PairGrid(tips,
              x_vars=["smoker", "time", "sex"],
              y_vars=["total_bill", "tip"],
              aspect=.75, size=3.5)
g.map(sns.violinplot, palette="pastel")
