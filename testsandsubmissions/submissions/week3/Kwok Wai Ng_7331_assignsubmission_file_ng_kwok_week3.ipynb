# %%
# %matplotlib inline
# import naming conventions 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
L1 = pd.Series([1,3,6,np.nan,10,16])
L1
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    10.0
# 5    16.0
# dtype: float64

# %%
L1[4]
# Out:
# 10.0

# %%
L2, L3 = pd.Series(np.random.randn(6)), pd.Series(np.random.randn(6))

# %%
# combine multiple Series into a DataFrame with column labels
daf_1 = pd.DataFrame({'A': L1, 'B': L2, 'C': L3})

daf_1
# Out:
#       A         B         C
# 0   1.0  1.411395 -1.430966
# 1   3.0  0.319981  1.624373
# 2   6.0 -0.533273  1.166442
# 3   NaN  2.452998 -0.399212
# 4  10.0 -0.841647 -0.816339
# 5  16.0  1.078655 -0.857704

# %%
L4 = pd.Series(np.random.randn(8))  # whoaaaaaa this Series has extra entries!

daf1 = pd.DataFrame({'A': L1, 'B': L2, 'C': L3, 'D': L4})

daf1
# Out:
#       A         B         C         D
# 0   1.0  1.411395 -1.430966 -0.167217
# 1   3.0  0.319981  1.624373 -1.498705
# 2   6.0 -0.533273  1.166442  0.050227
# 3   NaN  2.452998 -0.399212  0.700211
# 4  10.0 -0.841647 -0.816339  1.778387
# 5  16.0  1.078655 -0.857704  1.852053
# 6   NaN       NaN       NaN -1.042679
# 7   NaN       NaN       NaN  0.383739

# %%
# create a DataFrame from numpy array
daf2 = pd.DataFrame(np.random.randn(6,4))

daf2             # can only have one 'pretty' output per cell (if it's the last command)

#print df2       # otherwise, can print arb number of results w/o pretty format
#print df1       # (uncomment both of these print statements)
# Out:
#           0         1         2         3
# 0 -0.405996  0.191085  0.333358  0.189211
# 1 -3.124266 -1.035098  0.669494 -0.496070
# 2 -0.814801 -0.379128  0.060220  0.391888
# 3  0.059404  0.602859 -1.007943 -0.957961
# 4 -0.760525 -0.483526 -0.044330  0.191964
# 5 -0.423623  1.719239 -0.863272 -0.872752

# %%
daf2.head(2)
# Out:
#           0         1         2         3
# 0 -0.405996  0.191085  0.333358  0.189211
# 1 -3.124266 -1.035098  0.669494 -0.496070

# %%
cols = ['a', 'b', 'c', 'd']

# assign columns attribute (names) 
daf2.columns = cols

# create an index:
#  generate a sequence of dates with pandas' data_range() method,
#  then assign the index attribute
dates = pd.date_range(start='2013-10-24 13:45:27', freq='W', periods=6)
daf2.index = dates

daf2
# Out:
#                             a         b         c         d
# 2013-10-27 13:45:27 -0.405996  0.191085  0.333358  0.189211
# 2013-11-03 13:45:27 -3.124266 -1.035098  0.669494 -0.496070
# 2013-11-10 13:45:27 -0.814801 -0.379128  0.060220  0.391888
# 2013-11-17 13:45:27  0.059404  0.602859 -1.007943 -0.957961
# 2013-11-24 13:45:27 -0.760525 -0.483526 -0.044330  0.191964
# 2013-12-01 13:45:27 -0.423623  1.719239 -0.863272 -0.872752

# %%
print ('what is a date_range object?\n\n'), dates
# Out:
# what is a date_range object?
# (None, DatetimeIndex(['2013-10-27 13:45:27', '2013-11-03 13:45:27',
#                 '2013-11-10 13:45:27', '2013-11-17 13:45:27',
#                 '2013-11-24 13:45:27', '2013-12-01 13:45:27'],
#                dtype='datetime64[ns]', freq='W-SUN'))

# %%
# select a row by index label by using .loc 
daf2.loc['2013-11-10 13:45:27']
# Out:
# a   -0.814801
# b   -0.379128
# c    0.060220
# d    0.391888
# Name: 2013-11-10 13:45:27, dtype: float64

# %%
daf2.loc['2013-11-10 13:45:27','c']
# Out:
# 0.060220196611549558

# %%
daf1 = pd.DataFrame(np.random.randn(6,4), index=list('abcdef'),columns=list('ABCD'))

daf1
# Out:
#           A         B         C         D
# a  0.269220 -0.415551 -0.372148 -1.239702
# b  0.784407 -0.843605 -0.511486  0.634939
# c  0.188703 -0.302214 -2.213803 -1.490913
# d  1.571364  1.336163 -1.060520 -1.117826
# e -0.582928 -0.650069 -0.912475 -0.164057
# f -0.015232  1.416679  0.491950  1.320699

# %%
daf1.loc[['d','f'],'A':'C']
# Out:
#           A         B        C
# d  1.571364  1.336163 -1.06052
# f -0.015232  1.416679  0.49195

# %%
gnacs_x = "id|postedTime|body|None|['twitter_entiteis:urls:url']|['None']|['actor:languages_list-items']|gnip:language:value|twitter_lang|[u'geo:coordinates_list-items']|geo:type|None|None|None|None|actor:utcOffset|None|None|None|None|None|None|None|None|None|actor:displayName|actor:preferredUsername|actor:id|gnip:klout_score|actor:followersCount|actor:friendsCount|actor:listedCount|actor:statusesCount|Tweet|None|None|None"
colnames = gnacs_x.split('|')

# %%
# prevent the automatic compression of wide dataframes (add scroll bar)
pd.set_option("display.max_columns", None)

# get some data, inspect
daf1 = pd.read_csv('../data/twitter_sample.csv', sep='|', names=colnames)

daf1.tail(7)
# Out:
#                                                 id                postedTime  \
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 88                             @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# ...

# %%
print (daf1.columns)
print (daf1.drop( [u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10',
       u'None.11', u'None.12', u'None.13'],axis=1).columns)
# Out:
# Index(['id', 'postedTime', 'body', 'None', '['twitter_entiteis:urls:url']',
#        '['None']', '['actor:languages_list-items']', 'gnip:language:value',
#        'twitter_lang', '[u'geo:coordinates_list-items']', 'geo:type', 'None.1',
#        'None.2', 'None.3', 'None.4', 'actor:utcOffset', 'None.5', 'None.6',
#        'None.7', 'None.8', 'None.9', 'None.10', 'None.11', 'None.12',
#        'None.13', 'actor:displayName', 'actor:preferredUsername', 'actor:id',
#        'gnip:klout_score', 'actor:followersCount', 'actor:friendsCount',
#        'actor:listedCount', 'actor:statusesCount', 'Tweet', 'None.14',
#        'None.15', 'None.16'],
#       dtype='object')
# Index(['id', 'postedTime', 'body', 'None', '['twitter_entiteis:urls:url']',
#        '['None']', '['actor:languages_list-items']', 'gnip:language:value',
#        'twitter_lang', '[u'geo:coordinates_list-items']', 'geo:type', 'None.1',
#        'None.2', 'None.3', 'None.4', 'actor:utcOffset', 'actor:displayName',
# ...

# %%
daf1.tail(6)
# Out:
#                                                 id                postedTime  \
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# 92  O matheus André ta me falando aqui , tem quase...  None
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...  None
# 94                                           😕 Hmm...  None
#
# ...

# %%
# inspect those rows with twitter-classified lang 'en' (scroll the right to see)
daf1[daf1.twitter_lang == 'en'].head()

# the colons in the column name below won't allow dot-access to the column, so we can quote them and still filter.
#df1[df1["gnip:language:value"] == 'en'].head()
# Out:
#                                                 id                postedTime  \
# 8   tag:search.twitter.com,2005:351835318028222465  2013-07-01T22:50:51.000Z
# 9   tag:search.twitter.com,2005:351835318346981377  2013-07-01T22:50:51.000Z
# 11  tag:search.twitter.com,2005:351835318024028161  2013-07-01T22:50:51.000Z
# 12  tag:search.twitter.com,2005:351835318497980416  2013-07-01T22:50:51.000Z
# 15  tag:search.twitter.com,2005:351835318724468737  2013-07-01T22:50:51.000Z
#
#                                                  body  None  \
# 8                                @pafcdan Aww good! X  None
# 9   Newest hobby: sending videos back and forth of...  None
# 11                              ~FINALLY OFF OF WORK~  None
# 12  Rubbing/massaging my feet is like giving me he...  None
# 15         @Hayley_Brownn Same!!!! Very sad times😞😞😞😞  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# ...

# %%
# create new dataframe from numerical columns
daf2 = daf1[["gnip:klout_score","actor:followersCount", "actor:friendsCount", "actor:listedCount"]]

daf2.head()
# Out:
#   gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0               35                   178                 129
# 1               32                   144                 215
# 2               18                    37                  54
# 3               50                   438                 174
# 4               21                    12                   6
#
#    actor:listedCount
# 0                  0
# 1                  0
# 2                  0
# 3                  1
# 4                  0

# %%
# because I happen to know the answer, let's check data types of the columns...
daf2.dtypes
# Out:
# gnip:klout_score        object
# actor:followersCount     int64
# actor:friendsCount       int64
# actor:listedCount        int64
# dtype: object

# %%
# convert ints / strings to floats, give up on anything else (call it 0.0)
def floatify(val):
    if val == None or val == 'None':
        return 0.0
    else:
        return float(val)

# %%
# assigning to an existing column overwrites that column 
daf2['gnip:klout_score'] = daf2['gnip:klout_score'].map(floatify)

# check again
daf2.dtypes
# Out:
# C:\Users\k\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# gnip:klout_score        float64
# actor:followersCount      int64
# actor:friendsCount        int64
# actor:listedCount         int64
# dtype: object

# %%
# use all floats just for fun. 
#  this only works if the elements can all be converted to floats (e.g. ints or something python can handle) 
daf2 = daf2.astype(float)

daf2.dtypes
# Out:
# gnip:klout_score        float64
# actor:followersCount    float64
# actor:friendsCount      float64
# actor:listedCount       float64
# dtype: object

# %%
# look at some activity ratios - add col to df
daf2['fol/fr'] = daf2['gnip:klout_score'] / daf2['actor:followersCount']

daf2.head()
# Out:
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0              35.0                 178.0               129.0
# 1              32.0                 144.0               215.0
# 2              18.0                  37.0                54.0
# 3              50.0                 438.0               174.0
# 4              21.0                  12.0                 6.0
#
#    actor:listedCount    fol/fr
# 0                0.0  0.196629
# 1                0.0  0.222222
# 2                0.0  0.486486
# 3                1.0  0.114155
# 4                0.0  1.750000

# %%
# back to bigger df, without 'None' cols
daf1.head()
# Out:
#                                                id                postedTime  \
# 0  tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1  tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 2  tag:search.twitter.com,2005:351835317747191808  2013-07-01T22:50:51.000Z
# 3  tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 4  tag:search.twitter.com,2005:351835317755592705  2013-07-01T22:50:51.000Z
#
#                                                 body  \
# 0                         kavga edelim ama konuşalım
# 1                              @shane_joersz wooooow
# 2                           お前との肌のふれあいなんぞ求めてない。自重しろ。
# 3  @Gabo_navoficial yo tambien creo en ti mi char...
# 4  только ты об этом не знаешь... http://t.co/MOH...
#
#                                                 None  \
# 0                                               None
# 1                                               None
# ...

# %%
# subset df, create new df with only 'popular' accounts -- those matching the filter condition given
pop_daf = daf1[daf1["actor:followersCount"] >= 100]

# %%
# though this looks like a normal dataframe, the DataFrameGroupBy object has a heirarchical index
#  this means it may not act as you might expect.
lang_gb = pop_daf[['twitter_lang',\
             'gnip:klout_score',\
             'actor:followersCount',\
             'actor:friendsCount',\
             'actor:statusesCount']].groupby('twitter_lang')


# note the new index 'twitter_lang' -- in this case, .head(n) returns <= n elements for each index
lang_gb.head(2)
# Out:
#    twitter_lang gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0            tr               35                   178                 129
# 1            es               32                   144                 215
# 3            es               50                   438                 174
# 5            tr               41                   226                 346
# 6            pt               42                   247                  64
# 8            en               38                   380                 860
# 9            en               41                   160                 135
# 16          und               53                  1179                 628
# 18           he               37                   151                 284
# 20           it               46                  1999                 293
# 21           pt               43                   137                  89
# ...

# %%
# to get a DataFrame object that responds more like I'm used to, create a new one using the 
#   aggregate method, which results in a single-index DataFrame
lang_gab_mean = lang_gb.aggregate(np.mean)  

lang_gab_mean.head()
# Out:
#               actor:followersCount  actor:friendsCount  actor:statusesCount
# twitter_lang
# ar                      458.000000          413.000000          1061.000000
# en                     1796.147059          582.735294         16364.352941
# es                     1359.285714          441.142857          8953.357143
# fr                      116.000000          122.000000          3174.000000
# he                      151.000000          284.000000           641.000000

# %%
# .plot() is a pandas wrapper for matplotlib's plt.plot() 
lang_gab_mean['actor:followersCount'].plot(kind='bar', color='g')

# %%
# more base matplotlib 
plt.scatter(x=lang_gab_mean['actor:followersCount'],\
            y=lang_gab_mean['actor:friendsCount'],\
            alpha=0.9,\
            s=50,\
            color='blue',\
            marker='o')

# %%
# now read the docs and copypasta a neat-looking plot
from pandas.plotting import scatter_matrix

scatter_matrix(lang_gab_mean, alpha=0.5, figsize=(20,20), diagonal='kde', s=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002088259E780>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020882BDD6D8>]], dtype=object)

# %%
# make up some data with large-scale patterns and a datetime index
daf = pd.DataFrame(np.random.randn(1000, 4), index=pd.date_range('1/1/2000', periods=1000), columns=list('ABCD'))
daf = daf.cumsum()
daf.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.419261 -1.247671  1.432531 -1.862842
# 2000-01-02  1.666777 -0.987606  0.458056 -0.487439
# 2000-01-03  0.938695 -1.806593 -1.154485 -0.541875
# 2000-01-04  3.165430 -1.409904 -0.976821 -1.743430
# 2000-01-05  3.980289 -1.865207 -0.604535 -1.211585

# %%
daf.plot()
daf.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000208845B67F0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002088478B128>]], dtype=object)

# %%
import prettyplotlib

daf.plot()
daf.hist()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-48-e4a13dd75f1f> in <module>()
# ----> 1 import prettyplotlib
#       2
#       3 daf.plot()
#       4 daf.hist()
#
# ModuleNotFoundError: No module named 'prettyplotlib'

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "distributions")))

# %%
y = np.random.normal(size=100)
sns.distplot(y);

# %%
sns.distplot(y, kde=False, rug=True);

# %%
sns.distplot(y, bins=20, kde=False, rug=True);

# %%
sns.distplot(y, hist=False, rug=True);

# %%
y = np.random.normal(0, 1, size=30)
bandwidth = 1.06 * y.std() * y.size ** (-1 / 5.)
support = np.linspace(-4, 4, 200)

kernels = []
for y_i in y:

    kernel = stats.norm(y_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel, color="r")

sns.rugplot(y, color=".2", linewidth=3);

# %%
density1 = np.sum(kernels, axis=0)
density1 /= integrate.trapz(density1, support)
plt.plot(support, density1);

# %%
sns.kdeplot(y, shade=True);

# %%
sns.kdeplot(y)
sns.kdeplot(y, bw=.2, label="bw: 0.2")
sns.kdeplot(y, bw=2, label="bw: 2")
plt.legend();

# %%
sns.kdeplot(y, shade=True, cut=0)
sns.rugplot(y);

# %%
x = np.random.gamma(6, size=200)
sns.distplot(x, kde=False, fit=stats.gamma);

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data1 = np.random.multivariate_normal(mean, cov, 200)
daf = pd.DataFrame(data1, columns=["x", "y"])

# %%
sns.jointplot(x="x", y="y", data1=daf);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-a81632609de6> in <module>()
# ----> 1 sns.jointplot(x="x", y="y", data1=daf);
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2217     grid = JointGrid(x, y, data, dropna=dropna,
#    2218                      size=size, ratio=ratio, space=space,
# -> 2219                      xlim=xlim, ylim=ylim)
#    2220
#    2221     # Plot the data using the grid
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, x, y, data, size, ratio, space, dropna, xlim, ylim)
#    1664             if isinstance(var, string_types):
#    1665                 err = "Could not interpret input '{}'".format(var)
# -> 1666                 raise ValueError(err)
#    1667
# ...

# %%
x1, y1 = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style("white"):
    sns.jointplot(x=x1, y=y1, kind="hex", color="k");

# %%
sns.jointplot(x="x", y="y", data=daf, kind="kde");

# %%
f1, ax1 = plt.subplots(figsize=(6, 6))
sns.kdeplot(daf.x, daf.y, ax=ax1)
sns.rugplot(daf.x, color="g", ax=ax1)
sns.rugplot(daf.y, vertical=True, ax=ax1);

# %%
f1, ax1 = plt.subplots(figsize=(6, 6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(daf.x, daf.y, cmap=cmap, n_levels=60, shade=True);

# %%
g = sns.jointplot(x="x", y="y", data=daf, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$");

# %%
iris1 = sns.load_dataset("iris")
sns.pairplot(iris1);

# %%
g1 = sns.PairGrid(iris1)
g1.map_diag(sns.kdeplot)
g1.map_offdiag(sns.kdeplot, cmap="Blues_d", n_levels=6);
# Out:
# C:\Users\k\Anaconda3\lib\site-packages\matplotlib\contour.py:967: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns1
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "regression")))

# %%
tips = sns1.load_dataset("tips")

# %%
sns1.regplot(x="total_bill", y="tip", data=tips);

# %%
sns1.lmplot(x="total_bill", y="tip", data=tips);

# %%
sns1.lmplot(x="size", y="tip", data=tips);

# %%
sns1.lmplot(x="size", y="tip", data=tips, x_jitter=.05);

# %%
sns1.lmplot(x="size", y="tip", data=tips, x_estimator=np.mean);

# %%
anscombe1 = sns1.load_dataset("anscombe")

# %%
sns1.lmplot(x="x", y="y", data=anscombe1.query("dataset == 'I'"),
           ci=None, scatter_kws={"s": 80});

# %%
sns1.lmplot(x="x", y="y", data=anscombe1.query("dataset == 'II'"),
           ci=None, scatter_kws={"s": 80});

# %%
sns1.lmplot(x="x", y="y", data=anscombe1.query("dataset == 'II'"),
           order=2, ci=None, scatter_kws={"s": 80});

# %%
sns1.lmplot(x="x", y="y", data=anscombe1.query("dataset == 'III'"),
           ci=None, scatter_kws={"s": 80});

# %%
sns1.lmplot(x="x", y="y", data=anscombe1.query("dataset == 'III'"),
           robust=True, ci=None, scatter_kws={"s": 80});

# %%
tips["big_tip"] = (tips.tip / tips.total_bill) > .15
sns1.lmplot(x="total_bill", y="big_tip", data=tips,
           y_jitter=.03);

# %%
sns1.lmplot(x="total_bill", y="big_tip", data=tips,
           logistic=True, y_jitter=.03);

# %%
sns1.lmplot(x="total_bill", y="tip", data=tips,
           lowess=True);

# %%
sns1.residplot(x="x", y="y", data=anscombe1.query("dataset == 'I'"),
              scatter_kws={"s": 80});

# %%
sns1.residplot(x="x", y="y", data=anscombe1.query("dataset == 'II'"),
              scatter_kws={"s": 80});

# %%
sns1.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns1.lmplot(x="total_bill", y="tip", hue="smoker", data=tips,
           markers=["o", "x"], palette="Set1");

# %%
sns1.lmplot(x="total_bill", y="tip", hue="smoker", col="time", data=tips);

# %%
sns1.lmplot(x="total_bill", y="tip", hue="smoker",
           col="time", row="sex", data=tips);

# %%
f1, ax1 = plt.subplots(figsize=(5, 6))
sns1.regplot(x="total_bill", y="tip", data=tips, ax=ax1);

# %%
sns1.lmplot(x="total_bill", y="tip", col="day", data=tips,
           col_wrap=2, size=3);

# %%
sns1.lmplot(x="total_bill", y="tip", col="day", data=tips,
           aspect=.5);

# %%
sns1.jointplot(x="total_bill", y="tip", data=tips, kind="reg");

# %%
sns1.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"],
             size=5, aspect=.8, kind="reg");

# %%
sns1.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"],
             hue="smoker", size=5, aspect=.8, kind="reg");

# %%
# %matplotlib inline

# %%
import numpy as np1
import pandas as pd1
import matplotlib as mpl1
import matplotlib.pyplot as plt1

# %%
import seaborn as sns1
sns1.set(style="whitegrid", color_codes=True)

# %%
np1.random.seed(sum(map(ord, "categorical")))

# %%
titanic1 = sns1.load_dataset("titanic")
tips1 = sns1.load_dataset("tips")
iris1 = sns1.load_dataset("iris")

# %%
sns1.stripplot(x="day", y="total_bill", data=tips);

# %%
sns1.stripplot(x="day", y="total_bill", data=tips, jitter=True);

# %%
sns1.swarmplot(x="day", y="total_bill", data=tips);

# %%
sns1.swarmplot(x="day", y="total_bill", hue="sex", data=tips);

# %%
sns1.swarmplot(x="size", y="total_bill", data=tips);

# %%
sns1.swarmplot(x="total_bill", y="day", hue="time", data=tips);

# %%
sns1.boxplot(x="day", y="total_bill", hue="time", data=tips);

# %%
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
sns1.boxplot(x="day", y="total_bill", hue="weekend", data=tips, dodge=False);

# %%
sns1.violinplot(x="total_bill", y="day", hue="time", data=tips);

# %%
sns1.violinplot(x="total_bill", y="day", hue="time", data=tips,
               bw=.1, scale="count", scale_hue=False);

# %%
sns1.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True);

# %%
sns1.violinplot(x="day", y="total_bill", hue="sex", data=tips,
               split=True, inner="stick", palette="Set3");

# %%
sns1.violinplot(x="day", y="total_bill", data=tips, inner=None)
sns1.swarmplot(x="day", y="total_bill", data=tips, color="w", alpha=.5);

# %%
sns1.barplot(x="sex", y="survived", hue="class", data=titanic1);

# %%
sns1.countplot(x="deck", data=titanic1, palette="Greens_d");

# %%
sns1.countplot(y="deck", hue="class", data=titanic1, palette="Greens_d");

# %%
sns1.pointplot(x="sex", y="survived", hue="class", data=titanic1);

# %%
sns1.pointplot(x="class", y="survived", hue="sex", data=titanic1,
              palette={"male": "g", "female": "m"},
              markers=["^", "o"], linestyles=["-", "--"]);

# %%
sns1.boxplot(data=iris1, orient="h");

# %%
sns1.violinplot(x=iris1.species, y=iris1.sepal_length);

# %%
f1, a1x = plt.subplots(figsize=(7, 3))
sns1.countplot(y="deck", data=titanic1, color="c");

# %%
sns1.factorplot(x="day", y="total_bill", hue="smoker", data=tips1);

# %%
sns1.factorplot(x="day", y="total_bill", hue="smoker", data=tips1, kind="bar");

# %%
sns1.factorplot(x="day", y="total_bill", hue="smoker",
               col="time", data=tips1, kind="swarm");

# %%
sns1.factorplot(x="time", y="total_bill", hue="smoker",
               col="day", data=tips1, kind="box", size=4, aspect=.5);

# %%
g1 = sns1.PairGrid(tips1,
                 x_vars=["smoker", "time", "sex"],
                 y_vars=["total_bill", "tip"],
                 aspect=.75, size=3.5)
g1.map(sns1.violinplot, palette="pastel");
