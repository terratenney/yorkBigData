# %%
import pandas as pd
import textblob as tb

# %%
student_comments = pd.read_excel("C:/Users/hermitus/Documents/york_class/NOV17_CSDA1000_Formative Feedback_8DEC17.xlsx")

# %%
student_comments.columns = ['responses','well_struc','engaging','relevant_in','relevant_on','workload','imporve','keep','stop','other']

# %%
student_comments
# Out:
#     responses         well_struc        engaging     relevant_in  \
# 0           1              Agree           Agree  Strongly Agree
# 1           2              Agree           Agree           Agree
# 2           3              Agree        Disagree           Agree
# 3           4            Neutral           Agree  Strongly Agree
# 4           5              Agree           Agree         Neutral
# 5           6              Agree           Agree           Agree
# 6           7              Agree           Agree  Strongly Agree
# 7           8  Strongly Disagree         Neutral         Neutral
# 8           9     Strongly Agree           Agree  Strongly Agree
# 9          10              Agree           Agree        Disagree
# 10         11     Strongly Agree  Strongly Agree  Strongly Agree
# 11         12              Agree  Strongly Agree           Agree
# 12         13            Neutral           Agree           Agree
# ...

# %%
print "Well Structured: \n", student_comments.well_struc.value_counts()
print
print "Engaging: \n",student_comments.engaging.value_counts()
print
print "Inclass Relevant: \n",student_comments.relevant_in.value_counts()
print
print "Online Relevant: \n",student_comments.relevant_on.value_counts()
print
print "Worload Reasonable: \n",student_comments.workload.value_counts()
# Out:
# Well Structured:
# Agree                15
# Neutral               6
# Strongly Agree        3
# Strongly Disagree     2
# Disagree              2
# Name: well_struc, dtype: int64
#
# Engaging:
# Agree             18
# Strongly Agree     7
# Disagree           2
# Neutral            1
# Name: engaging, dtype: int64
#
# Inclass Relevant:
# Agree             12
# Strongly Agree     9
# Neutral            5
# Disagree           2
# Name: relevant_in, dtype: int64
#
# Online Relevant:
# Agree                12
# Strongly Agree        8
# Neutral               5
# Disagree              2
# Strongly Disagree     1
# Name: relevant_on, dtype: int64
#
# Worload Reasonable:
# Agree                15
# Strongly Agree        5
# Strongly Disagree     3
# Neutral               3
# Disagree              2
# Name: workload, dtype: int64
