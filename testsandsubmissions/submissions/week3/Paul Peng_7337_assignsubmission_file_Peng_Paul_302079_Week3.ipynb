# %% [markdown]
# # Part 1: Data Structures

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s1 = pd.Series([176,653,655,np.nan,666,758])
s1
# Out:
# 0    176.0
# 1    653.0
# 2    655.0
# 3      NaN
# 4    666.0
# 5    758.0
# dtype: float64

# %%
s1[2]
# Out:
# 655.0

# %%
s2, s3 = pd.Series(np.random.randn(15)), pd.Series(np.random.randn(15))

# %%
df_1 = pd.DataFrame({'A': s1, 'B': s2, 'C': s3})

df_1
# Out:
#         A         B         C
# 0   176.0  0.093061 -0.654261
# 1   653.0  0.036031  1.615504
# 2   655.0  0.665981 -0.258857
# 3     NaN -0.779096 -0.118549
# 4   666.0 -1.351203  0.259563
# 5   758.0  1.250542 -1.118294
# 6     NaN -0.072467 -0.080148
# 7     NaN -0.429688  0.453723
# 8     NaN  0.730809  0.995399
# 9     NaN -2.025313 -0.422291
# 10    NaN  3.448891  0.861974
# 11    NaN  1.068112 -1.878073
# 12    NaN  1.531467 -0.096703
# 13    NaN  0.122666 -0.213944
# 14    NaN  0.501556 -0.420180

# %%
# when Series are different lengths, DataFrame fills in gaps with NaN
s4 = pd.Series(np.random.randn(20))  # whoaaaaaa this Series has extra entries!

df1 = pd.DataFrame({'A': s1, 'B': s2, 'C': s3, 'D': s4})

df1
# Out:
#         A         B         C         D
# 0   176.0  0.093061 -0.654261 -2.319976
# 1   653.0  0.036031  1.615504 -0.973026
# 2   655.0  0.665981 -0.258857  0.533149
# 3     NaN -0.779096 -0.118549 -0.431736
# 4   666.0 -1.351203  0.259563  0.601315
# 5   758.0  1.250542 -1.118294  0.389936
# 6     NaN -0.072467 -0.080148 -0.483036
# 7     NaN -0.429688  0.453723  1.794723
# 8     NaN  0.730809  0.995399 -0.943933
# 9     NaN -2.025313 -0.422291  0.109516
# 10    NaN  3.448891  0.861974 -1.159906
# 11    NaN  1.068112 -1.878073  2.086531
# 12    NaN  1.531467 -0.096703 -0.112889
# 13    NaN  0.122666 -0.213944  0.534813
# 14    NaN  0.501556 -0.420180  0.475342
# 15    NaN       NaN       NaN -2.036298
# 16    NaN       NaN       NaN -0.398111
# 17    NaN       NaN       NaN  0.488569
# 18    NaN       NaN       NaN  0.033457
# 19    NaN       NaN       NaN -0.500234

# %%
# create a DataFrame from numpy array
df2 = pd.DataFrame(np.random.randn(10,7))

df2             # can only have one 'pretty' output per cell (if it's the last command)

#print df2       # otherwise, can print arb number of results w/o pretty format
#print df1       # (uncomment both of these print statements)
# Out:
#           0         1         2         3         4         5         6
# 0 -0.857590 -1.811853  0.824819  0.913699 -0.030957  0.111893 -1.362370
# 1  0.204554 -0.182581  0.542265  0.516928  0.204107 -1.379763  2.153197
# 2  0.671755 -0.000277  0.148187 -1.471678 -0.310467 -0.320758 -0.502578
# 3  0.739868  0.893813  1.981377  0.236416 -0.177063  1.220373  0.415429
# 4  1.399461 -0.724410  0.868625  0.594773  1.066892  1.203541  0.461977
# 5  0.126288  0.420132 -0.516766 -1.813736  0.470383  1.115783 -1.220096
# 6 -0.087725  0.086587  0.486407 -0.484896 -1.815492  0.014223 -0.504005
# 7  0.842889 -1.143274  1.222315 -2.256913  1.731464 -0.067823 -0.886136
# 8 -1.140866 -0.338469  1.917042 -0.570230 -1.496650 -0.407434 -1.195390
# 9  1.750260 -0.627178 -1.201213  0.193603 -1.238074  1.085078  0.879064

# %%
df2.head(5)
# Out:
#           0         1         2         3         4         5         6
# 0 -0.857590 -1.811853  0.824819  0.913699 -0.030957  0.111893 -1.362370
# 1  0.204554 -0.182581  0.542265  0.516928  0.204107 -1.379763  2.153197
# 2  0.671755 -0.000277  0.148187 -1.471678 -0.310467 -0.320758 -0.502578
# 3  0.739868  0.893813  1.981377  0.236416 -0.177063  1.220373  0.415429
# 4  1.399461 -0.724410  0.868625  0.594773  1.066892  1.203541  0.461977

# %%
cols = ['a', 'b', 'c', 'd','e','f','g']

# assign columns attribute (names) 
df2.columns = cols

# create an index:
#  generate a sequence of dates with pandas' data_range() method,
#  then assign the index attribute
dates = pd.date_range(start='2015-1-24 10:52:55', freq='W', periods=10)
df2.index = dates

df2
# Out:
#                             a         b         c         d         e  \
# 2015-01-25 10:52:55 -0.857590 -1.811853  0.824819  0.913699 -0.030957
# 2015-02-01 10:52:55  0.204554 -0.182581  0.542265  0.516928  0.204107
# 2015-02-08 10:52:55  0.671755 -0.000277  0.148187 -1.471678 -0.310467
# 2015-02-15 10:52:55  0.739868  0.893813  1.981377  0.236416 -0.177063
# 2015-02-22 10:52:55  1.399461 -0.724410  0.868625  0.594773  1.066892
# 2015-03-01 10:52:55  0.126288  0.420132 -0.516766 -1.813736  0.470383
# 2015-03-08 10:52:55 -0.087725  0.086587  0.486407 -0.484896 -1.815492
# 2015-03-15 10:52:55  0.842889 -1.143274  1.222315 -2.256913  1.731464
# 2015-03-22 10:52:55 -1.140866 -0.338469  1.917042 -0.570230 -1.496650
# 2015-03-29 10:52:55  1.750260 -0.627178 -1.201213  0.193603 -1.238074
#
#                             f         g
# 2015-01-25 10:52:55  0.111893 -1.362370
# 2015-02-01 10:52:55 -1.379763  2.153197
# 2015-02-08 10:52:55 -0.320758 -0.502578
# ...

# %%
print 'what is a date_range object?\n\n', dates
# Out:
# what is a date_range object?
#
# DatetimeIndex(['2015-01-25 10:52:55', '2015-02-01 10:52:55',
#                '2015-02-08 10:52:55', '2015-02-15 10:52:55',
#                '2015-02-22 10:52:55', '2015-03-01 10:52:55',
#                '2015-03-08 10:52:55', '2015-03-15 10:52:55',
#                '2015-03-22 10:52:55', '2015-03-29 10:52:55'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
df2.loc['2015-01-25 10:52:55']
# Out:
# a   -0.857590
# b   -1.811853
# c    0.824819
# d    0.913699
# e   -0.030957
# f    0.111893
# g   -1.362370
# Name: 2015-01-25 10:52:55, dtype: float64

# %%
df2.loc['2015-01-25 10:52:55','g']
# Out:
# -1.3623703471219339

# %%
df1 = pd.DataFrame(np.random.randn(7,7), index=list('efghijk'),columns=list('EFGHIJK'))

df1
# Out:
#           E         F         G         H         I         J         K
# e  0.950538 -0.927370  0.716216 -0.288431  1.247130 -1.086026  0.111578
# f -1.038075 -0.162469 -0.247530 -1.340180 -0.784453 -0.715186 -1.489387
# g -0.900141  0.842222 -0.631801 -2.589454 -0.080663  0.367627 -0.961286
# h -0.184520  0.113391  0.999947 -0.946741 -0.978888 -1.212454  0.832316
# i -0.571617  0.516863  1.373872 -1.062569 -0.211286 -0.040679  1.437563
# j  1.830662  0.366928  0.602858  0.227468 -0.044297 -0.775810  1.070598
# k  0.824334  1.282223 -0.788210  0.486764  0.280990 -1.157835 -1.460381

# %%
df1.loc[['e','f'],'I':'K']
# Out:
#           I         J         K
# e  1.247130 -1.086026  0.111578
# f -0.784453 -0.715186 -1.489387

# %% [markdown]
# # Part 2: Data

# %%
gnacs_x = "id|postedTime|body|None|['twitter_entiteis:urls:url']|['None']|['actor:languages_list-items']|gnip:language:value|twitter_lang|[u'geo:coordinates_list-items']|geo:type|None|None|None|None|actor:utcOffset|None|None|None|None|None|None|None|None|None|actor:displayName|actor:preferredUsername|actor:id|gnip:klout_score|actor:followersCount|actor:friendsCount|actor:listedCount|actor:statusesCount|Tweet|None|None|None"
colnames = gnacs_x.split('|')

# %%
# prevent the automatic compression of wide dataframes (add scroll bar)
pd.set_option("display.max_columns", None)

# get some data, inspect
df1 = pd.read_csv('twitter_sample.csv', sep='|', names=colnames)

df1.tail(8)
# Out:
#                                                 id                postedTime  \
# 87  tag:search.twitter.com,2005:351835321056509952  2013-07-01T22:50:51.000Z
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 87  And I'm the one that always gets hit on. OKAAAAY.  None
# 88                             @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# ...

# %%
print df1.columns
print df1.drop( [u'None.1', u'None.2', u'None.3', u'None.4', u'None.5', u'None.6',
       u'None.7', u'None.8', u'None.9'],axis=1).columns
# Out:
# Index([u'id', u'postedTime', u'body', u'None',
#        u'['twitter_entiteis:urls:url']', u'['None']',
#        u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
#        u'None.1', u'None.2', u'None.3', u'None.4', u'actor:utcOffset',
#        u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10',
#        u'None.11', u'None.12', u'None.13', u'actor:displayName',
#        u'actor:preferredUsername', u'actor:id', u'gnip:klout_score',
#        u'actor:followersCount', u'actor:friendsCount', u'actor:listedCount',
#        u'actor:statusesCount', u'Tweet', u'None.14', u'None.15', u'None.16'],
#       dtype='object')
# Index([u'id', u'postedTime', u'body', u'None',
#        u'['twitter_entiteis:urls:url']', u'['None']',
#        u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
# ...

# %%
df1.tail(7)
# Out:
#                                                 id                postedTime  \
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 88                             @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# ...

# %%
df1[df1.twitter_lang == 'en'].head()
# Out:
#                                                 id                postedTime  \
# 8   tag:search.twitter.com,2005:351835318028222465  2013-07-01T22:50:51.000Z
# 9   tag:search.twitter.com,2005:351835318346981377  2013-07-01T22:50:51.000Z
# 11  tag:search.twitter.com,2005:351835318024028161  2013-07-01T22:50:51.000Z
# 12  tag:search.twitter.com,2005:351835318497980416  2013-07-01T22:50:51.000Z
# 15  tag:search.twitter.com,2005:351835318724468737  2013-07-01T22:50:51.000Z
#
#                                                  body  None  \
# 8                                @pafcdan Aww good! X  None
# 9   Newest hobby: sending videos back and forth of...  None
# 11                              ~FINALLY OFF OF WORK~  None
# 12  Rubbing/massaging my feet is like giving me he...  None
# 15         @Hayley_Brownn Same!!!! Very sad times😞😞😞😞  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# ...

# %%
df2 = df1[["gnip:klout_score","actor:followersCount", "actor:friendsCount", "actor:listedCount", "actor:statusesCount"]]

df2.head()
# Out:
#   gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0               35                   178                 129
# 1               32                   144                 215
# 2               18                    37                  54
# 3               50                   438                 174
# 4               21                    12                   6
#
#    actor:listedCount  actor:statusesCount
# 0                  0                 2028
# 1                  0                 4071
# 2                  0                 3505
# 3                  1                17636
# 4                  0                  145

# %%
df2.dtypes
# Out:
# gnip:klout_score        object
# actor:followersCount     int64
# actor:friendsCount       int64
# actor:listedCount        int64
# actor:statusesCount      int64
# dtype: object

# %%
def floatify(val):
    if val == None or val == 'None':
        return 0.0
    else:
        return float(val)

# %%
# assigning to an existing column overwrites that column 
df2['actor:followersCount'] = df2['actor:followersCount'].map(floatify)

# check again
df2.dtypes
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# gnip:klout_score        float64
# actor:followersCount    float64
# actor:friendsCount        int64
# actor:listedCount         int64
# actor:statusesCount       int64
# dtype: object

# %%
df2 = df2.astype(float)

df2.dtypes
# Out:
# gnip:klout_score        float64
# actor:followersCount    float64
# actor:friendsCount      float64
# actor:listedCount       float64
# actor:statusesCount     float64
# dtype: object

# %%
df2['fol/fr'] = df2['gnip:klout_score'] / df2['actor:friendsCount']

df2.head()
# Out:
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0              35.0                 178.0               129.0
# 1              32.0                 144.0               215.0
# 2              18.0                  37.0                54.0
# 3              50.0                 438.0               174.0
# 4              21.0                  12.0                 6.0
#
#    actor:listedCount  actor:statusesCount    fol/fr
# 0                0.0               2028.0  0.271318
# 1                0.0               4071.0  0.148837
# 2                0.0               3505.0  0.333333
# 3                1.0              17636.0  0.287356
# 4                0.0                145.0  3.500000

# %%
df1.head()
# Out:
#                                                id                postedTime  \
# 0  tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1  tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 2  tag:search.twitter.com,2005:351835317747191808  2013-07-01T22:50:51.000Z
# 3  tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 4  tag:search.twitter.com,2005:351835317755592705  2013-07-01T22:50:51.000Z
#
#                                                 body  \
# 0                         kavga edelim ama konuşalım
# 1                              @shane_joersz wooooow
# 2                           お前との肌のふれあいなんぞ求めてない。自重しろ。
# 3  @Gabo_navoficial yo tambien creo en ti mi char...
# 4  только ты об этом не знаешь... http://t.co/MOH...
#
#                                                 None  \
# 0                                               None
# 1                                               None
# ...

# %%
pop_df = df1[df1["actor:followersCount"] >= 200]

# %%
lang_gb = pop_df[['twitter_lang',\
             'gnip:klout_score',\
             'actor:followersCount',\
             'actor:friendsCount',\
             'actor:statusesCount']].groupby('twitter_lang')
lang_gb.head(5)
# Out:
#    twitter_lang gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 3            es               50                   438                 174
# 5            tr               41                   226                 346
# 6            pt               42                   247                  64
# 7            tr               40                   304                 233
# 8            en               38                   380                 860
# 10           es               62                 11873                  69
# 11           en               18                   290                 683
# 12           en               64                 40543                 116
# 15           en               42                   417                 259
# 16          und               53                  1179                 628
# 17           es               33                   231                 216
# ...

# %%
lang_gb_mean = lang_gb.aggregate(np.mean)  

lang_gb_mean.head()
# Out:
#               actor:followersCount  actor:friendsCount  actor:statusesCount
# twitter_lang
# ar                      458.000000          413.000000          1061.000000
# en                     2581.304348          772.565217         22353.869565
# es                     2023.444444          536.111111         12075.333333
# id                      463.000000          279.000000          8363.000000
# it                     3541.500000         2047.500000         45199.500000

# %% [markdown]
# # Part 3: Plotting

# %%
lang_gb_mean['actor:friendsCount'].plot(kind='bar', color='b')

# %%
plt.scatter(x=lang_gb_mean['actor:friendsCount'],\
            y=lang_gb_mean['actor:statusesCount'],\
            alpha=0.5,\
            s=50,\
            color='blue',\
            marker='o')

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(lang_gb_mean, alpha=0.5, figsize=(15,15), diagonal='kde', s=200)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc17933b410>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc178f601d0>]], dtype=object)

# %%
df = pd.DataFrame(np.random.randn(1000, 6), index=pd.date_range('12/1/2100', periods=1000), columns=list('HIJKLM'))
df = df.cumsum()
df.head()
# Out:
#                    H         I         J         K         L         M
# 2100-12-01 -2.106705 -0.395456  0.906210 -0.738388 -0.407496 -0.806288
# 2100-12-02 -3.345076  0.804291  2.683264 -0.484396 -2.079263 -0.738898
# 2100-12-03 -3.971970  0.304605  2.672543 -0.714336 -2.416002 -1.940096
# 2100-12-04 -4.522743  1.455200  5.567898 -0.024005 -3.117793 -1.065261
# 2100-12-05 -4.485909 -0.473425  5.945652 -1.031291 -4.775829 -1.927245

# %%
df.plot()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc177391f10>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc17731f110>]], dtype=object)

# %%
import prettyplotlib

df.plot()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc176d20150>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc176b90110>]], dtype=object)

# %% [markdown]
# # Visualizing the distribution of a dataset

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "distributions")))

# %% [markdown]
# # Plotting univariate distributions

# %%
x = np.random.normal(size=500)
sns.distplot(x);

# %%
sns.distplot(x, kde=False, rug=True);

# %%
sns.distplot(x, bins=40, kde=False, rug=True);

# %%
sns.distplot(x, hist=False, rug=True);

# %%
x = np.random.normal(0, 1, size=50)
bandwidth = 1.06 * x.std() * x.size ** (-1 / 5.)
support = np.linspace(-4, 4, 200)

kernels = []
for x_i in x:

    kernel = stats.norm(x_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel, color="r")

sns.rugplot(x, color=".2", linewidth=3);

# %%
density = np.sum(kernels, axis=0)
density /= integrate.trapz(density, support)
plt.plot(support, density);

# %%
sns.kdeplot(x, shade=True);

# %%
sns.kdeplot(x)
sns.kdeplot(x, bw=.2, label="bw: 0.2")
sns.kdeplot(x, bw=2, label="bw: 2")
plt.legend();

# %%
sns.kdeplot(x, shade=True, cut=0)
sns.rugplot(x);

# %%
x = np.random.gamma(6, size=200)
sns.distplot(x, kde=False, fit=stats.gamma);

# %% [markdown]
# # Plotting bivariate distributions

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

# %%
sns.jointplot(x="x", y="y", data=df);

# %%
x, y = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style("white"):
    sns.jointplot(x=x, y=y, kind="hex", color="k");

# %%
sns.jointplot(x="x", y="y", data=df, kind="kde");

# %%
f, ax = plt.subplots(figsize=(10, 10))
sns.kdeplot(df.x, df.y, ax=ax)
sns.rugplot(df.x, color="b", ax=ax)
sns.rugplot(df.y, vertical=True, ax=ax);

# %%
f, ax = plt.subplots(figsize=(10, 10))
cmap = sns.cubehelix_palette(as_cmap=True, dark=-1, light=2, reverse=True)
sns.kdeplot(df.x, df.y, cmap=cmap, n_levels=60, shade=True);

# %%
g = sns.jointplot(x="x", y="y", data=df, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$");

# %% [markdown]
# # Visualizing pairwise relationships in a dataset

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris);

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, cmap="Blues_d", n_levels=6);
# Out:
# No handlers could be found for logger "matplotlib.legend"
# /bda/app/anaconda2/lib/python2.7/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)

# %% [markdown]
# # Visualizing linear relationships

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "regression")))

# %%
tips = sns.load_dataset("tips")

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips, x_jitter=.05);

# %%
sns.lmplot(x="size", y="tip", data=tips, x_estimator=np.mean);

# %% [markdown]
# # Plotting with categorical data

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
np.random.seed(sum(map(ord, "categorical")))

# %%
titanic = sns.load_dataset("titanic")
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %%
sns.stripplot(x="day", y="total_bill", data=tips);

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True);

# %%
sns.swarmplot(x="day", y="total_bill", data=tips);

# %%
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips);

# %%
sns.swarmplot(x="size", y="total_bill", data=tips);

# %%
sns.boxplot(x="day", y="total_bill", hue="time", data=tips);

# %%
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
sns.boxplot(x="day", y="total_bill", hue="weekend", data=tips, dodge=False);

# %%
sns.violinplot(x="total_bill", y="day", hue="time", data=tips);

# %%
sns.violinplot(x="total_bill", y="day", hue="time", data=tips,
               bw=.1, scale="count", scale_hue=False);

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True);

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips,
               split=True, inner="stick", palette="Set3");

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
sns.swarmplot(x="day", y="total_bill", data=tips, color="w", alpha=.5);

# %%
sns.barplot(x="sex", y="survived", hue="class", data=titanic);

# %%
sns.countplot(x="deck", data=titanic, palette="Greens_d");

# %%
sns.countplot(y="deck", hue="class", data=titanic, palette="Greens_d");

# %%
sns.pointplot(x="sex", y="survived", hue="class", data=titanic);

# %%
sns.pointplot(x="class", y="survived", hue="sex", data=titanic,
              palette={"male": "g", "female": "m"},
              markers=["^", "o"], linestyles=["-", "--"]);

# %%
sns.factorplot(x="day", y="total_bill", hue="smoker", data=tips);

# %%
sns.factorplot(x="day", y="total_bill", hue="smoker", data=tips, kind="bar");

# %%
sns.factorplot(x="day", y="total_bill", hue="smoker",
               col="time", data=tips, kind="swarm");

# %%
sns.factorplot(x="time", y="total_bill", hue="smoker",
               col="day", data=tips, kind="box", size=4, aspect=.5);
