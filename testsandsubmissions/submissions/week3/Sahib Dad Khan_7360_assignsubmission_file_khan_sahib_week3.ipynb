# %%
gnacs_x = "id|postedTime|body|None|['twitter_entiteis:urls:url']|['None']|['actor:languages_list-items']|gnip:language:value|twitter_lang|[u'geo:coordinates_list-items']|geo:type|None|None|None|None|actor:utcOffset|None|None|None|None|None|None|None|None|None|actor:displayName|actor:preferredUsername|actor:id|gnip:klout_score|actor:followersCount|actor:friendsCount|actor:listedCount|actor:statusesCount|Tweet|None|None|None"
colnames = gnacs_x.split('|')

# %%
# %matplotlib inline
# import naming conventions 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 


# prevent the automatic compression of wide dataframes (add scroll bar)
pd.set_option("display.max_columns", None)

# %%
pwd
# Out:
# u'C:\\Users\\Ali\\Desktop'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 1EFC-8233
#
#  Directory of C:\Users\Ali\Desktop
#
# 01/29/2018  05:06 PM    <DIR>          .
# 01/29/2018  05:06 PM    <DIR>          ..
# 01/29/2018  03:39 PM    <DIR>          .ipynb_checkpoints
# 01/20/2018  05:20 PM            67,783 01 - Introduction to Python (Basics).ipynb
# 01/20/2018  12:16 PM           222,165 02 -  Intro to Pandas.ipynb
# 01/28/2018  07:58 AM         2,621,870 03 - Pandas - Data Structures Continued... and Data Visualization.ipynb
# 08/28/2017  08:32 PM           944,904 1-9Oart_Obx1cHDaFaNbCSZQ.jpeg
# 11/27/2017  05:19 PM           243,958 2017 Ontario Personal Tax Credits Return.pdf
# 11/27/2017  05:23 PM           174,242 2017 Personal Tax Credit Return.pdf
# 04/03/2017  04:17 AM         2,735,348 2587005 (1).pdf
# 03/30/2017  11:15 PM         2,735,377 2587005.pdf
# 04/03/2017  03:02 AM           856,655 401-Assign5-Ans-Plus-15w (1).pdf
# 04/03/2017  02:24 AM           856,655 401-Assign5-Ans-Plus-15w.pdf
# 04/06/2017  04:58 AM           277,587 401-assign5-ans-plus-17w.pdf
# 06/24/2017  11:01 AM           167,731 401-sq2-plus-3mar17.pdf
# 07/16/2017  01:56 AM    <DIR>          402
# 07/31/2017  04:51 PM           699,038 402tt1solutions.pdf
# 04/02/2017  02:41 PM            71,846 A4.csv
# 04/30/2017  07:31 PM            42,200 abc.png
# 09/11/2017  11:15 AM            31,201 aiQeT.png
# 09/13/2017  01:52 PM           307,720 amazon invoice.pdf
# 08/27/2017  12:35 PM    <DIR>          App3
# 09/11/2017  05:36 PM    <DIR>          App4
# 09/15/2017  06:39 PM    <DIR>          APP5
# 01/07/2018  07:41 PM            18,321 bmo interview.docx
# 04/03/2017  05:39 AM            14,200 bonusfinal.docx
# 04/23/2017  06:37 PM        35,257,343 cambridge-ielts-11-general-training.pdf
# 12/14/2017  08:40 PM    <DIR>          Canada D
# 06/02/2017  02:05 PM         2,423,337 ch1marketing.xps
# 01/08/2018  03:30 PM            99,597 Checkout _ School of Continuing Studies.pdf
# 08/25/2017  02:30 PM            14,392 Code Explained.docx
# 08/24/2017  08:08 PM               768 code.txt
# 08/25/2017  11:31 AM               821 codeapp2.txt
# 09/18/2017  12:00 PM    <DIR>          Cover letters
# 07/23/2017  05:35 PM    <DIR>          Data Assignment
# 07/23/2017  05:07 PM    <DIR>          datasetassignment
# 07/18/2017  05:29 PM           175,409 datasetvisualization.zip
# 08/27/2017  08:18 AM           504,140 data-wrangling-cheatsheet.pdf
# 06/02/2017  05:30 PM    <DIR>          ECON 483
# 05/24/2017  05:00 PM            38,454 Environment Scan.png
# 03/29/2017  02:12 PM           237,226 ewrwef.png
# 07/07/2017  12:07 PM    <DIR>          Excel
# 01/26/2018  03:36 PM    <DIR>          Excel Project
# 05/24/2017  05:00 PM            38,454 exhibitb.png
# 05/23/2017  08:39 PM            14,979 External analysis.docx
# 09/05/2017  07:05 AM           424,240 Fahad.pdf
# 07/31/2017  05:56 PM            59,505 Fall convocation ceremony dates and times _ Registrar's Office.pdf
# 11/29/2017  07:06 PM    <DIR>          FDM docs
# 01/04/2018  09:27 PM        20,730,880 FDM Presentation - Sahib Khan.ppt
# 01/04/2018  09:53 PM         2,108,107 FDM Presentation new form.pptx
# 01/04/2018  09:17 PM        20,730,880 FDM Presentation.ppt
# 11/20/2017  04:11 PM    <DIR>          FDM Scans
# 09/26/2017  10:14 AM    <DIR>          finalapp
# 06/20/2017  08:26 AM            13,389 Fintech Cover Letter - Sahib Khan.docx
# 09/22/2017  09:42 AM    <DIR>          form under progress
# 09/14/2017  01:48 PM             2,511 g7map.html
# 01/19/2018  08:32 PM           534,864 glossary.pdf
# 06/09/2017  12:54 PM                 7 Goals.rtf
# 07/27/2017  05:38 PM         2,046,036 graduateshotline_word_list.pdf
# 05/17/2017  01:34 PM            14,164 Group Contract.docx
# 05/24/2017  07:12 AM           283,794 Group-Contract final.pdf
# 01/04/2018  04:49 PM         1,797,394 Healthcare FDM Presentation.pptx
# 08/02/2017  03:56 PM               863 HeidiSQL.lnk
# 08/28/2017  06:11 PM           237,001 home-compressed.jpg
# 08/22/2017  08:51 AM         6,905,840 hospital_acquired_infection.pdf
# 07/31/2017  03:46 PM           806,049 hospital_acquired_infection_p1.pdf
# 09/15/2017  07:00 AM            25,072 iclicker.jpg
# 08/25/2017  07:37 AM         1,758,234 IMG_3001.JPG
# 05/01/2017  04:00 PM           466,714 IMM5257E.PDF
# 05/17/2017  03:25 PM            50,157 IMM5740_2-NR15S8E (1).pdf
# 05/18/2017  12:42 PM           870,052 Intermediate Microsoft Excel 2016 c1.pdf
# 08/15/2017  09:57 PM    <DIR>          IntroR
# 09/07/2017  12:46 PM            95,129 issue.png
# 01/01/2018  07:46 PM           117,316 itil report.docx
# 01/22/2018  07:08 PM             2,863 khan_sahib.ipynb
# 01/24/2018  03:12 PM            10,601 khan_sahib_assignment1.ipynb
# 08/25/2017  08:31 AM    <DIR>          learning to visualize with D3
# 05/17/2017  03:20 PM            12,635 Mail In word.docx
# 05/17/2017  03:19 PM            66,370 Mail in.png
# 09/14/2017  11:57 AM             3,603 maptest.html
# 05/03/2017  11:25 AM        19,311,192 marketing.pdf
# 08/28/2017  06:58 AM            14,056 Meeting with Dr.Nasser Aug 27th 2017.docx
# 08/04/2017  05:39 PM           291,357 MIT14_12F12_chapter6.pdf
# 08/14/2017  09:29 PM    <DIR>          MT1344
# 08/04/2017  06:02 PM           316,630 Nash Equilibrium and Dominant Strategies- Game Theory - Fundamental Finance.pdf
# 08/31/2017  08:52 AM                 0 New Text Document (2).txt
# 08/24/2017  08:08 PM               768 New Text Document.txt
# 11/25/2017  06:39 PM            12,564 Palette 2.docx
# 11/20/2017  04:10 PM           201,013 Passport Scan.docx
# 05/17/2017  06:06 PM           247,969 PDF Resume.pdf
# 06/09/2017  02:49 PM           106,363 pre edit group docc.pdf
# 01/04/2018  09:28 PM         2,098,205 Presentation - Sahib Khan.pptx
# 05/01/2017  04:08 PM    <DIR>          prof ryan
# 05/02/2017  01:41 PM               711 q2.htm
# 04/11/2017  06:06 AM           236,848 q2483.pdf
# 05/02/2017  01:41 PM           208,587 q2pix.jpg
# 08/24/2017  07:59 PM    <DIR>          Rassignmentcuriato
# 05/17/2017  06:13 PM           250,507 Resume pdf.pdf
# 05/17/2017  06:13 PM            16,442 Resume.docx
# 01/03/2018  01:33 AM           102,233 saferestore.pdf
# 01/01/2018  10:31 PM            12,375 saferm progress.docx
# 10/05/2017  10:28 AM            34,650 Sahib Khan Resume.docx
# 08/24/2017  06:03 AM            16,162 ScatterObese.png
# 05/09/2017  01:40 PM           192,542 schedule.jpg
# 09/20/2017  08:13 AM    <DIR>          sensor html objects
# 09/28/2017  09:33 AM    <DIR>          Sensor Test
# 08/24/2017  10:02 AM               898 shinyapp1.R
# 09/22/2017  09:33 PM    <DIR>          shinyapp2
# 05/17/2017  12:19 PM            17,605 Situation-Analysis-Grading-Scheme-GROUP-3.docx
# 03/27/2017  04:15 AM           185,016 slum water.jpg
# 08/17/2017  12:03 PM    <DIR>          soft
# 12/10/2017  08:09 PM            23,156 sql notes.docx
# 07/08/2017  07:15 PM    <DIR>          sqlcourse
# 09/14/2017  01:48 PM               791 stateinteractive.R
# 12/17/2017  03:11 PM    <DIR>          Study PERMIT FINAL
# 07/20/2017  04:27 AM           104,369 Sun Life Financial _ Financière Sun Life.pdf
# 05/02/2017  01:40 PM            18,794 SupplyDemand (1).docx
# 09/05/2017  11:47 AM    <DIR>          sync
# 09/13/2017  09:26 AM             9,135 test.xlsx
# 04/12/2017  09:05 PM            16,490 tiebout.docx
# 06/03/2017  10:06 AM         6,909,716 Todaro.pdf
# 01/24/2018  11:29 AM    <DIR>          Transcript
# 09/20/2017  06:53 PM    <DIR>          TRV
# 12/17/2017  03:19 PM    <DIR>          TRVFinal
# 01/29/2018  03:49 PM            48,445 twitter_sample.csv
# 01/20/2018  05:25 PM             2,304 Untitled.ipynb
# 01/29/2018  05:06 PM           705,274 Untitled1.ipynb
# 04/24/2017  09:49 AM    <DIR>          USB
# 10/05/2017  09:00 AM    <DIR>          usb backup
# 08/31/2017  10:37 AM                 0 Visualisation d3 examples.txt
# 04/11/2017  06:17 AM            20,138 What benefits and costs arise from suburban expansion.docx
# 01/24/2018  03:18 PM    <DIR>          WORK PERMIT DOCS
# 08/02/2017  03:03 PM         8,718,444 Yaar-Mere-by-Meesha-Shafi-CPR-S02.mp3
# 06/08/2017  03:31 PM           409,755 zehrs.png
#               98 File(s)    152,929,495 bytes
#               36 Dir(s)  204,545,093,632 bytes free

# %%
df1 = pd.read_csv('../twitter_sample.csv', sep='|', names=colnames)

# %%
df1.tail(12)
# Out:
#                                                 id                postedTime  \
# 83  tag:search.twitter.com,2005:351835320792252417  2013-07-01T22:50:51.000Z
# 84  tag:search.twitter.com,2005:351835320645459968  2013-07-01T22:50:51.000Z
# 85  tag:search.twitter.com,2005:351835320817426433  2013-07-01T22:50:51.000Z
# 86  tag:search.twitter.com,2005:351835321006170112  2013-07-01T22:50:51.000Z
# 87  tag:search.twitter.com,2005:351835321056509952  2013-07-01T22:50:51.000Z
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 83  sometimes i wonder if i will ever be smart #ke...  None
# 84    @JADEMEIMOUN1 mdrrrr ohh nan sa serai dommageee  None
# 85  Como cuando grito ¡¡*José*!! y la mayoria de m...  None
# 86                             Tweeting for no reason  None
# 87  And I'm the one that always gets hit on. OKAAAAY.  None
# 88                            @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# 92  O matheus André ta me falando aqui , tem quase...  None
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...  None
# 94                                          😕 Hmm...  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 83                          None     None                         ['en']
# 84                          None     None                         ['fr']
# 85                          None     None                         ['es']
# 86                          None     None                         ['en']
# 87                          None     None                         ['en']
# 88                          None     None                         ['en']
# 89                          None     None                         ['it']
# 90                          None     None                         ['it']
# 91                          None     None                         ['pt']
# 92                          None     None                         ['pt']
# 93                          None     None                         ['en']
# 94                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 83                  en           en     [28.87395867, -13.82116208]    Point
# 84                  en           fr       [48.88389837, 2.38612415]    Point
# 85                  en           es       [14.9673297, -91.7889038]    Point
# 86                  en           en      [47.0353488, -122.7995873]    Point
# 87                  en           en    [34.09956425, -117.40411515]    Point
# 88                  en           vi      [53.28722009, -3.21569687]    Point
# 89                  it           it                            None     None
# 90                  it           it          [41.73604, 12.2890263]    Point
# 91                  pt           pt                            None     None
# 92                  pt           pt    [-22.72046574, -43.57919689]    Point
# 93                  en           en       [52.21599153, 6.88528201]    Point
# 94                None           en     [42.21746118, -78.03367083]    Point
#
#                                                None.1   None.2  \
# 83  ['[-13.8821654, 28.8383932]', '[-13.8821654, 2...  Polygon
# 84  ['[2.2241006, 48.8155414]', '[2.2241006, 48.90...  Polygon
# 85  ['[-94.230569, 14.5319181]', '[-94.230569, 17....  Polygon
# 86  ['[-122.839691, 46.980616]', '[-122.839691, 47...  Polygon
# 87  ['[-117.436711, 34.023746]', '[-117.436711, 34...  Polygon
# 88  ['[-3.400604, 53.072143999999994]', '[-3.40060...  Polygon
# 89  ['[14.1332005, 40.7920697]', '[14.1332005, 40....  Polygon
# 90  ['[12.2344266, 41.6558738]', '[12.2344266, 42....  Polygon
# 91  ['[-50.899727999999996, -21.454719]', '[-50.89...  Polygon
# 92  ['[-43.645123999999996, -22.783967999999998]',...  Polygon
# 93  ['[6.7559955, 52.1611799]', '[6.7559955, 52.28...  Polygon
# 94  ['[-78.045887, 42.212985]', '[-78.045887, 42.2...  Polygon
#
#                        None.3 None.4 actor:utcOffset  \
# 83              Yaiza, Palmas     ES            None
# 84               Paris, Paris     FR            None
# 85            Chiapas, México     MX          -10800
# 86                  Lacey, WA     US            None
# 87                 Rialto, CA     US          -28800
# 88     Flintshire, Flintshire     GB               0
# 89             Napoli, Napoli     IT            None
# 90                 Roma, Roma     IT            7200
# 91       Araçatuba, São Paulo     BR          -10800
# 92  Queimados, Rio de Janeiro     BR          -10800
# 93                   Enschede     NL            3600
# 94                Belmont, NY     US            None
#
#                            None.5 None.6 None.7 None.8 None.9 None.10 None.11  \
# 83                           None   None   None   None   None    None    None
# 84                           None   None   None   None   None    None    None
# 85                      Guatemala   None   None   None   None    None    None
# 86                           None   None   None   None   None    None    None
# 87                   Arizona-Cali   None   None   None   None    None    None
# 88  Leeds- UK / Greenfield- Wales   None   None   None   None    None    None
# 89         #bagdr @limitdemibagdr   None   None   None   None    None    None
# 90                  Big Ben's tip   None   None   None   None    None    None
# 91             na cama do mari :p   None   None   None   None    None    None
# 92                 Rio de Janeiro   None   None   None   None    None    None
# 93           Netherlands\Enschede   None   None   None   None    None    None
# 94                           None   None   None   None   None    None    None
#
#    None.12 None.13    actor:displayName actor:preferredUsername    actor:id  \
# 83    None    None           iamabitch☯            poppylewisxo  1030915357
# 84    None    None    BIRTHHHHDAYYYYYYY            DvorahMergui   919844498
# 85    None    None          Pilar Ochoa               PiLigrOsa   107307381
# 86    None    None         aG€Nt ¥£  ¤w         godsgentlegiant  1518643968
# 87    None    None               Cilli♡            Cilli_021112   382278854
# 88    None    None              marshaa            marshaleighm   269323425
# 89    None    None                demi.               demibagdr  1542203100
# 90    None    None     She's my Louis ❤            xliamsdreams   562092674
# 91    None    None         lorena uai ∞            Fc_GritaAmor   397609113
# 92    None    None              Shelyda             ShelydaDays    70959019
# 93    None    None                    L                Karkooba  1252736376
# 94    None    None  Lindsey Chamberlain             Linnyy_Kayy   466042520
#
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 83               37                   275                 510
# 84               44                    94                  66
# 85               39                   280                 258
# 86               41                    71                  67
# 87               30                   557                 440
# 88               44                   767                 486
# 89               44                    64                  58
# 90               53                  5084                3802
# 91               44                  1248                1962
# 92               40                   128                  76
# 93               30                    48                  88
# 94               41                   198                 188
#
#     actor:listedCount  actor:statusesCount  Tweet  \
# 83                  0                  799  Tweet
# 84                  1                 5267  Reply
# 85                  0                 2632  Tweet
# 86                  0                 1474  Tweet
# 87                  1                18434  Tweet
# 88                  0                17549  Reply
# 89                  0                 1872  Reply
# 90                 11                30163  Reply
# 91                  0                11161  Tweet
# 92                  0                 1419  Tweet
# 93                  0                  957  Reply
# 94                  0                 1897  Tweet
#
#                                               None.14 None.15 None.16
# 83                                               None    None    None
# 84  http://twitter.com/JADEMEIMOUN1/statuses/35183...    None    None
# 85                                               None    None    None
# 86                                               None    None    None
# 87                                               None    None    None
# 88  http://twitter.com/CheniseFowlisX/statuses/351...    None    None
# 89  http://twitter.com/justinbagdr/statuses/351833...    None    None
# 90  http://twitter.com/xhazzasdimples/statuses/351...    None    None
# 91                                               None    None    None
# 92                                               None    None    None
# 93  http://twitter.com/Mulayhim/statuses/351817617...    None    None
# 94                                               None    None    None

# %%
del df1['None']

# %%
df1.tail(6)
# Out:
#                                                 id                postedTime  \
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  \
# 89           @justinbagdr no, non mi far star meglio.
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...
# 91  Mandei a foto do Piqué e o fc n respondeu até ...
# 92  O matheus André ta me falando aqui , tem quase...
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...
# 94                                          😕 Hmm...
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 89                          None     None                         ['it']
# 90                          None     None                         ['it']
# 91                          None     None                         ['pt']
# 92                          None     None                         ['pt']
# 93                          None     None                         ['en']
# 94                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 89                  it           it                            None     None
# 90                  it           it          [41.73604, 12.2890263]    Point
# 91                  pt           pt                            None     None
# 92                  pt           pt    [-22.72046574, -43.57919689]    Point
# 93                  en           en       [52.21599153, 6.88528201]    Point
# 94                None           en     [42.21746118, -78.03367083]    Point
#
#                                                None.1   None.2  \
# 89  ['[14.1332005, 40.7920697]', '[14.1332005, 40....  Polygon
# 90  ['[12.2344266, 41.6558738]', '[12.2344266, 42....  Polygon
# 91  ['[-50.899727999999996, -21.454719]', '[-50.89...  Polygon
# 92  ['[-43.645123999999996, -22.783967999999998]',...  Polygon
# 93  ['[6.7559955, 52.1611799]', '[6.7559955, 52.28...  Polygon
# 94  ['[-78.045887, 42.212985]', '[-78.045887, 42.2...  Polygon
#
#                        None.3 None.4 actor:utcOffset                  None.5  \
# 89             Napoli, Napoli     IT            None  #bagdr @limitdemibagdr
# 90                 Roma, Roma     IT            7200           Big Ben's tip
# 91       Araçatuba, São Paulo     BR          -10800      na cama do mari :p
# 92  Queimados, Rio de Janeiro     BR          -10800          Rio de Janeiro
# 93                   Enschede     NL            3600    Netherlands\Enschede
# 94                Belmont, NY     US            None                    None
#
#    None.6 None.7 None.8 None.9 None.10 None.11 None.12 None.13  \
# 89   None   None   None   None    None    None    None    None
# 90   None   None   None   None    None    None    None    None
# 91   None   None   None   None    None    None    None    None
# 92   None   None   None   None    None    None    None    None
# 93   None   None   None   None    None    None    None    None
# 94   None   None   None   None    None    None    None    None
#
#       actor:displayName actor:preferredUsername    actor:id gnip:klout_score  \
# 89                demi.               demibagdr  1542203100               44
# 90     She's my Louis ❤            xliamsdreams   562092674               53
# 91         lorena uai ∞            Fc_GritaAmor   397609113               44
# 92              Shelyda             ShelydaDays    70959019               40
# 93                    L                Karkooba  1252736376               30
# 94  Lindsey Chamberlain             Linnyy_Kayy   466042520               41
#
#     actor:followersCount  actor:friendsCount  actor:listedCount  \
# 89                    64                  58                  0
# 90                  5084                3802                 11
# 91                  1248                1962                  0
# 92                   128                  76                  0
# 93                    48                  88                  0
# 94                   198                 188                  0
#
#     actor:statusesCount  Tweet  \
# 89                 1872  Reply
# 90                30163  Reply
# 91                11161  Tweet
# 92                 1419  Tweet
# 93                  957  Reply
# 94                 1897  Tweet
#
#                                               None.14 None.15 None.16
# 89  http://twitter.com/justinbagdr/statuses/351833...    None    None
# 90  http://twitter.com/xhazzasdimples/statuses/351...    None    None
# 91                                               None    None    None
# 92                                               None    None    None
# 93  http://twitter.com/Mulayhim/statuses/351817617...    None    None
# 94                                               None    None    None

# %%
# inspect those rows with twitter-classified lang 'en' (scroll the right to see)
df1[df1.twitter_lang == 'en'].head(10)
# Out:
#                                                 id                postedTime  \
# 8   tag:search.twitter.com,2005:351835318028222465  2013-07-01T22:50:51.000Z
# 9   tag:search.twitter.com,2005:351835318346981377  2013-07-01T22:50:51.000Z
# 11  tag:search.twitter.com,2005:351835318024028161  2013-07-01T22:50:51.000Z
# 12  tag:search.twitter.com,2005:351835318497980416  2013-07-01T22:50:51.000Z
# 15  tag:search.twitter.com,2005:351835318724468737  2013-07-01T22:50:51.000Z
# 19  tag:search.twitter.com,2005:351835319085187072  2013-07-01T22:50:51.000Z
# 25  tag:search.twitter.com,2005:351835318682525697  2013-07-01T22:50:51.000Z
# 26  tag:search.twitter.com,2005:351835318602842113  2013-07-01T22:50:51.000Z
# 30  tag:search.twitter.com,2005:351835318443446273  2013-07-01T22:50:51.000Z
# 31  tag:search.twitter.com,2005:351835317898199040  2013-07-01T22:50:51.000Z
#
#                                                  body  \
# 8                                @pafcdan Aww good! X
# 9   Newest hobby: sending videos back and forth of...
# 11                              ~FINALLY OFF OF WORK~
# 12  Rubbing/massaging my feet is like giving me he...
# 15     @Hayley_Brownn Same!!!! Very sad times😞😞😞😞
# 19                        @Michael5SOS MIKEY I LOVE U
# 25  A Very Happy Great Gramma. #picoftheday #famil...
# 26                      I always mess things up fuck.
# 30  If it's in my cup, it's in MY cup, so don't fu...
# 31     @Verity97 just kiddin u bootiful dis u &gt; 👰
#
#    ['twitter_entiteis:urls:url']                                ['None']  \
# 8                           None                                    None
# 9                           None                                    None
# 11                          None                                    None
# 12                          None                                    None
# 15                          None                                    None
# 19                          None                                    None
# 25    ['http://t.co/DZk6HN22r1']  ['http://instagram.com/p/bPaB-FtSpQ/']
# 26                          None                                    None
# 30                          None                                    None
# 31                          None                                    None
#
#    ['actor:languages_list-items'] gnip:language:value twitter_lang  \
# 8                          ['en']                  en           en
# 9                          ['en']                  en           en
# 11                         ['en']                  en           en
# 12                         ['en']                  en           en
# 15                         ['en']                  en           en
# 19                         ['it']                  en           en
# 25                         ['en']                  en           en
# 26                         ['en']                  en           en
# 30                         ['en']                  en           en
# 31                         ['en']                  en           en
#
#    [u'geo:coordinates_list-items'] geo:type  \
# 8         [50.3582949, -4.0930973]    Point
# 9      [29.54588264, -95.10669141]    Point
# 11           [32.86107, -83.72062]    Point
# 12     [33.68890281, -84.27369741]    Point
# 15       [54.6884467, -3.51776393]    Point
# 19      [43.82758701, 12.99396517]    Point
# 25     [42.25865115, -83.20823908]    Point
# 26     [40.17004533, -87.64867445]    Point
# 30     [41.16183828, -81.42191721]    Point
# 31       [53.54338422, -1.4962159]    Point
#
#                                                None.1   None.2  \
# 8   ['[-4.209496, 50.3320883]', '[-4.209496, 50.44...  Polygon
# 9   ['[-95.145152, 29.506973]', '[-95.145152, 29.5...  Polygon
# 11  ['[-83.739741, 32.765651]', '[-83.739741, 32.8...  Polygon
# 12  ['[-85.605165, 30.355756999999997]', '[-85.605...  Polygon
# 15  ['[-3.580063, 54.454108]', '[-3.580063, 54.964...  Polygon
# 19  ['[12.9010202, 43.7535429]', '[12.9010202, 43....  Polygon
# 25  ['[-83.231911, 42.222783]', '[-83.231911, 42.3...  Polygon
# 26  ['[-87.665219, 40.103392]', '[-87.665219, 40.2...  Polygon
# 30  ['[-81.489745, 41.135556]', '[-81.489745, 41.2...  Polygon
# 31  ['[-1.822589, 53.438297]', '[-1.822589, 53.612...  Polygon
#
#                    None.3 None.4 actor:utcOffset          None.5 None.6  \
# 8      Plymouth, Plymouth     GB               0        Plymouth   None
# 9             Webster, TX     US            None  Houston, Texas   None
# 11              Macon, GA     US            None            None   None
# 12            Georgia, US     US          -18000          Atl...   None
# 15     Allerdale, Cumbria     GB          -36000            None   None
# 19  Fano, Pesaro e Urbino     IT            3600               ♡   None
# 25         Allen Park, MI     US          -18000         PCB/313   None
# 26           Danville, IL     US          -18000       d-ville ✌   None
# 30               Stow, OH     US          -21600      The Clouds   None
# 31     Barnsley, Barnsley     GB            None            None   None
#
#    None.7 None.8 None.9 None.10 None.11 None.12 None.13 actor:displayName  \
# 8    None   None   None    None    None    None    None           Becky ❤
# 9    None   None   None    None    None    None    None       lil beyoncé
# 11   None   None   None    None    None    None    None    Tomeisha Cross
# 12   None   None   None    None    None    None    None          Poison †
# 15   None   None   None    None    None    None    None         Karl Hine
# 19   None   None   None    None    None    None    None          meconio.
# 25   None   None   None    None    None    None    None   Kristopher Alan
# 26   None   None   None    None    None    None    None          geneva ✨
# 30   None   None   None    None    None    None    None        Jacob King
# 31   None   None   None    None    None    None    None        beth field
#
#    actor:preferredUsername   actor:id gnip:klout_score  actor:followersCount  \
# 8              BeckyLou90x   26568635               38                   380
# 9               beezlebrat  541953037               41                   160
# 11           MISSMEISHA223  242505369               18                   290
# 12              shanbonita   29619102               64                 40543
# 15                KarlHine  402334657               42                   417
# 19              liamsfaith  382824235               44                  5589
# 25          KristopherAlan   27737035               32                   342
# 26              seper4tion  482102969               40                   177
# 30            JacobviaKing  379819371               33                   243
# 31             _bethfieldx  601030480               31                   112
#
#     actor:friendsCount  actor:listedCount  actor:statusesCount  Tweet  \
# 8                  860                  0                 3116  Reply
# 9                  135                  0                 4170  Tweet
# 11                 683                  0                  540  Tweet
# 12                 116                486                60465  Tweet
# 15                 259                  1                 5242  Reply
# 19                2200                 17                51769  Tweet
# 25                2001                  0                  468  Tweet
# 26                  77                  0                 5581  Tweet
# 30                 290                  0                 6296  Tweet
# 31                 239                  0                  526  Reply
#
#                                               None.14 None.15 None.16
# 8   http://twitter.com/pafcdan/statuses/3518344574...    None    None
# 9                                                None    None    None
# 11                                               None    None    None
# 12                                               None    None    None
# 15  http://twitter.com/Hayley_Brownn/statuses/3518...    None    None
# 19                                               None    None    None
# 25                                               None    None    None
# 26                                               None    None    None
# 30                                               None    None    None
# 31  http://twitter.com/Verity97/statuses/351834475...    None    None

# %%
# create new dataframe from numerical columns
df2 = df1[["gnip:klout_score","actor:followersCount", "actor:friendsCount"]]

df2.head()
# Out:
#   gnip:klout_score  actor:followersCount  actor:friendsCount
# 0               35                   178                 129
# 1               32                   144                 215
# 2               18                    37                  54
# 3               50                   438                 174
# 4               21                    12                   6

# %%
## checking data type
df2.dtypes
# Out:
# gnip:klout_score        object
# actor:followersCount     int64
# actor:friendsCount       int64
# dtype: object

# %%
# convert ints / strings to floats, give up on anything else (call it 0.0)
def floatify(val):
    if val == None or val == 'None':
        return 0.0
    else:
        return float(val)

# %%
# assigning to an existing column overwrites that column 
df2['gnip:klout_score'] = df2['gnip:klout_score'].map(floatify)

# check again
df2.dtypes
# Out:
# C:\Users\Ali\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# gnip:klout_score        float64
# actor:followersCount      int64
# actor:friendsCount        int64
# dtype: object

# %%
df2['fol/fr'] = df2['gnip:klout_score'] / df2['actor:friendsCount']

df2.head()
# Out:
# C:\Users\Ali\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    gnip:klout_score  actor:followersCount  actor:friendsCount    fol/fr
# 0              35.0                   178                 129  0.271318
# 1              32.0                   144                 215  0.148837
# 2              18.0                    37                  54  0.333333
# 3              50.0                   438                 174  0.287356
# 4              21.0                    12                   6  3.500000

# %%
## grouping
pop_df = df1[df1["actor:followersCount"] >= 110]

# %%
df1.head()
# Out:
#                                                id                postedTime  \
# 0  tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1  tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 2  tag:search.twitter.com,2005:351835317747191808  2013-07-01T22:50:51.000Z
# 3  tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 4  tag:search.twitter.com,2005:351835317755592705  2013-07-01T22:50:51.000Z
#
#                                                 body  \
# 0                         kavga edelim ama konuşalım
# 1                              @shane_joersz wooooow
# 2                           お前との肌のふれあいなんぞ求めてない。自重しろ。
# 3  @Gabo_navoficial yo tambien creo en ti mi char...
# 4  только ты об этом не знаешь... http://t.co/MOH...
#
#   ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 0                          None     None                         ['tr']
# 1                          None     None                         ['en']
# 2                          None     None                         ['ja']
# 3                          None     None                         ['en']
# 4                          None     None                         ['ru']
#
#   gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 0                  en           tr                            None     None
# 1                  en           es     [47.29088246, -101.0379045]    Point
# 2                  en           ja     [35.70675048, 139.84273005]    Point
# 3                  en           es                            None     None
# 4                  en           ru                            None     None
#
#                                               None.1   None.2         None.3  \
# 0  ['[25.663883, 35.817497]', '[25.663883, 42.109...  Polygon        Türkiye
# 1  ['[-101.043785, 47.275933]', '[-101.043785, 47...  Polygon   Washburn, ND
# 2  ['[139.8332175, 35.6345694444444]', '[139.8332...  Polygon      江戸川区, 東京都
# 3  ['[-80.248663, 25.986366]', '[-80.248663, 26.0...  Polygon  Hollywood, FL
# 4  ['[23.179216999999998, 51.2626423]', '[23.1792...  Polygon        Belarus
#
#   None.4 actor:utcOffset             None.5 None.6 None.7 None.8 None.9  \
# 0     TR            7200               None   None   None   None   None
# 1     US          -21600         sevenohone   None   None   None   None
# 2     JP          -36000                 ちば   None   None   None   None
# 3     US          -14400  hollywood florida   None   None   None   None
# 4     BY            None               None   None   None   None   None
#
#   None.10 None.11 None.12 None.13 actor:displayName actor:preferredUsername  \
# 0    None    None    None    None   Rümeysa Özdemir           uykugibisiyok
# 1    None    None    None    None        cori▲alex.                 CoBerg_
# 2    None    None    None    None              黒い恋人          yamasyoyamasyo
# 3    None    None    None    None             MARIA            maria_e_pena
# 4    None    None    None    None         Элька Алб                 ElkaAlb
#
#      actor:id gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0   248312738               35                   178                 129
# 1    48025164               32                   144                 215
# 2   217987801               18                    37                  54
# 3   461188787               50                   438                 174
# 4  1433828712               21                    12                   6
#
#    actor:listedCount  actor:statusesCount  Tweet  \
# 0                  0                 2028  Tweet
# 1                  0                 4071  Reply
# 2                  0                 3505  Tweet
# 3                  1                17636  Reply
# 4                  0                  145  Tweet
#
#                                              None.14 None.15 None.16
# 0                                               None    None    None
# 1  http://twitter.com/shane_joersz/statuses/35182...    None    None
# 2                                               None    None    None
# 3  http://twitter.com/Gabo_navoficial/statuses/35...    None    None
# 4                                               None    None    None

# %%
# though this looks like a normal dataframe, the DataFrameGroupBy object has a heirarchical index
#  this means it may not act as you might expect.
lang_gb = pop_df[['twitter_lang',\
             'gnip:klout_score',\
             'actor:followersCount',\
             'actor:friendsCount',\
             'actor:statusesCount']].groupby('twitter_lang')

# %%
lang_gb.head(10)
# Out:
#    twitter_lang gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0            tr               35                   178                 129
# 1            es               32                   144                 215
# 3            es               50                   438                 174
# 5            tr               41                   226                 346
# 6            pt               42                   247                  64
# 7            tr               40                   304                 233
# 8            en               38                   380                 860
# 9            en               41                   160                 135
# 10           es               62                 11873                  69
# 11           en               18                   290                 683
# 12           en               64                 40543                 116
# 13           es               41                   162                 155
# 14           es               41                   172                 115
# 15           en               42                   417                 259
# 16          und               53                  1179                 628
# 17           es               33                   231                 216
# 18           he               37                   151                 284
# 19           en               44                  5589                2200
# 20           it               46                  1999                 293
# 21           pt               43                   137                  89
# 22           id               43                   258                 302
# 23           tr             None                   349                 244
# 24           pl               48                  2037                1984
# 25           en               32                   342                2001
# 26           en               40                   177                  77
# 27           pt               38                   231                 352
# 28           pt               47                   421                 345
# 29           id               33                   404                 378
# 30           en               33                   243                 290
# 31           en               31                   112                 239
# 33           ko               39                   170                 120
# 38          und               35                   228                 185
# 39           es               40                  3285                2106
# 41           es               34                  1121                1013
# 42           ar               40                   458                 413
# 43           fr               40                   116                 122
# 44           pt               44                   789                 150
# 45           es               41                   264                 198
# 46           es               33                   247                 256
# 50           pt               34                   274                 229
# 55           tr               44                   392                 152
# 57           id               48                   727                 157
# 64           ja               28                   152                 335
# 68           pt               30                   187                 231
# 74           id               49                   159                 145
# 76           pt               37                   759                 322
# 79           lv               41                   297                 237
# 88           vi               44                   767                 486
# 90           it               53                  5084                3802
# 91           pt               44                  1248                1962
# 92           pt               40                   128                  76
#
#     actor:statusesCount
# 0                  2028
# 1                  4071
# 3                 17636
# 5                  7759
# 6                  2438
# 7                  3558
# 8                  3116
# 9                  4170
# 10                 1991
# 11                  540
# 12                60465
# 13                  303
# 14                 7528
# 15                 5242
# 16                20141
# 17                11271
# 18                  641
# 19                51769
# 20                60236
# 21                 4047
# 22                 2732
# 23                12236
# 24                23240
# 25                  468
# 26                 5581
# 27                15233
# 28                15986
# 29                 9181
# 30                 6296
# 31                  526
# 33                 1094
# 38                24571
# 39                31002
# 41                 7590
# 42                 1061
# 43                 3174
# 44                10134
# 45                12569
# 46                 5527
# 50                30716
# 55                14064
# 57                13176
# 64                 2151
# 68                 5251
# 74                 8925
# 76                30559
# 79                 5221
# 88                17549
# 90                30163
# 91                11161
# 92                 1419

# %%
lang_gb_mean = lang_gb.aggregate(np.mean)  

lang_gb_mean.head(12)
# Out:
#               actor:followersCount  actor:friendsCount  actor:statusesCount
# twitter_lang
# ar                      458.000000          413.000000          1061.000000
# en                     1847.424242          598.090909         16827.878788
# es                     1359.285714          441.142857          8953.357143
# fr                      116.000000          122.000000          3174.000000
# he                      151.000000          284.000000           641.000000
# id                      387.000000          245.500000          8503.500000
# it                     3541.500000         2047.500000         45199.500000
# ja                      152.000000          335.000000          2151.000000
# ko                      170.000000          120.000000          1094.000000
# lv                      297.000000          237.000000          5221.000000
# pl                     2037.000000         1984.000000         23240.000000
# pt                      442.100000          382.000000         12694.400000

# %%
## part 3: plotting

lang_gb_mean['actor:followersCount'].plot(kind='bar', color='r')

# %%
plt.scatter(x=lang_gb_mean['actor:followersCount'],\
            y=lang_gb_mean['actor:friendsCount'],\
            alpha=0.5,\
            s=50,\
            color='green',\
            marker='o')

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(lang_gb_mean, alpha=0.5, figsize=(12,12), diagonal='kde', s=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000ABA9C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000ADD2EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AD67A90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000AEB4400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B02C320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B061A90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B1317B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B1FF438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B24C0B8>]], dtype=object)

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=pd.date_range('1/1/2000', periods=1000), columns=list('ABCD'))
df = df.cumsum()
df.head(12)
# Out:
#                    A         B         C         D
# 2000-01-01 -0.509305 -0.621912 -0.163455  0.170004
# 2000-01-02  0.768979 -1.979151 -1.940297  1.486053
# 2000-01-03  1.327489 -1.018248 -1.350686  1.050908
# 2000-01-04  0.028900 -1.684572 -0.193628  0.924171
# 2000-01-05 -0.535930 -1.669512  0.336446  1.064814
# 2000-01-06  0.568958 -1.230566 -0.635219  1.107840
# 2000-01-07 -1.227846 -1.718450 -1.459915  1.045781
# 2000-01-08 -1.502008 -2.111110 -0.837068  0.675855
# 2000-01-09 -2.114344 -1.820668 -0.625898 -0.348832
# 2000-01-10 -1.825736 -1.178101 -0.501808  1.066236
# 2000-01-11 -1.688048  0.612998  0.027632  1.473534
# 2000-01-12 -1.407738 -0.075901 -0.676707  1.580959

# %%
df.plot()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D4517B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D5BF1D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D63AE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D663588>]], dtype=object)

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "distributions")))

# %%
x = np.random.normal(size=200)
sns.distplot(x);

# %%
sns.distplot(x, kde=False, rug=True);

# %%
sns.distplot(x, bins=30, kde=False, rug=True);

# %%
sns.distplot(x, hist=False, rug=True);

# %%
x = np.random.normal(0, 1, size=30)
bandwidth = 1.06 * x.std() * x.size ** (-1 / 5.)
support = np.linspace(-4, 4, 200)

kernels = []
for x_i in x:

    kernel = stats.norm(x_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel, color="g")

sns.rugplot(x, color=".2", linewidth=3);

# %%
density = np.sum(kernels, axis=0)
density /= integrate.trapz(density, support)
plt.plot(support, density);

# %%
sns.kdeplot(x, shade=True);

# %%
sns.kdeplot(x)
sns.kdeplot(x, bw=.2, label="bw: 0.2")
sns.kdeplot(x, bw=2, label="bw: 2")
plt.legend();

# %%
sns.kdeplot(x, shade=True, cut=0)
sns.rugplot(x);

# %%
x = np.random.gamma(6, size=400)
sns.distplot(x, kde=False, fit=stats.gamma);

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

# %%
sns.jointplot(x="x", y="y", data=df);

# %%
x, y = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style("white"):
    sns.jointplot(x=x, y=y, kind="hex", color="k");

# %%
sns.jointplot(x="x", y="y", data=df, kind="kde");

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(df.x, df.y, ax=ax)
sns.rugplot(df.x, color="g", ax=ax)
sns.rugplot(df.y, vertical=True, ax=ax);

# %%
f, ax = plt.subplots(figsize=(6, 6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(df.x, df.y, cmap=cmap, n_levels=90, shade=True);

# %%
g = sns.jointplot(x="x", y="y", data=df, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=90, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$");

# %%
##Visualizing pairwise relationships in a dataset
iris = sns.load_dataset("iris")
sns.pairplot(iris);

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, cmap="Blues_d", n_levels=6);
# Out:
# C:\Users\Ali\Anaconda2\lib\site-packages\matplotlib\contour.py:967: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "regression")))

# %%
tips = sns.load_dataset("tips")

# %%
## Functions to draw linear regression models
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips);

# %%
## Fitting different kinds of models
anscombe = sns.load_dataset("anscombe")
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'I'"),
           ci=None, scatter_kws={"s": 80});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"),
           order=2, ci=None, scatter_kws={"s": 80});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'III'"),
           robust=True, ci=None, scatter_kws={"s": 80});

# %%
## Conditioning on other variables
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips,
           markers=["o", "x"], palette="Set1");

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker",
           col="time", row="sex", data=tips);

# %%
## Controlling the size and shape of the plot
sns.lmplot(x="total_bill", y="tip", col="day", data=tips,
           col_wrap=2, size=3);

# %%
sns.lmplot(x="total_bill", y="tip", col="day", data=tips,
           aspect=.5);

# %%
f, ax = plt.subplots(figsize=(5, 6))
sns.regplot(x="total_bill", y="tip", data=tips, ax=ax);

# %%
## Plotting a regression in other contexts
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");

# %%
sns.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"],
             size=5, aspect=.8, kind="reg");

# %%
sns.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"],
             hue="smoker", size=5, aspect=.8, kind="reg");

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
np.random.seed(sum(map(ord, "categorical")))

# %%
titanic = sns.load_dataset("titanic")
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %%
## Categorical scatterplots
sns.stripplot(x="day", y="total_bill", data=tips);

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True);

# %%
sns.swarmplot(x="size", y="total_bill", data=tips);

# %%
## Distributions of observations within categories

sns.boxplot(x="day", y="total_bill", hue="time", data=tips);

# %%
sns.violinplot(x="total_bill", y="day", hue="time", data=tips);

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True);

# %%
## Bar plots
sns.barplot(x="sex", y="survived", hue="class", data=titanic);

# %%
sns.countplot(y="deck", hue="class", data=titanic, palette="Greens_d");

# %%
sns.countplot(x="deck", data=titanic, palette="Greens_d");

# %%
## Point plots

sns.pointplot(x="sex", y="survived", hue="class", data=titanic);

# %%
sns.pointplot(x="class", y="survived", hue="sex", data=titanic,
              palette={"male": "g", "female": "m"},
              markers=["^", "o"], linestyles=["-", "--"]);

# %%
sns.violinplot(x=iris.species, y=iris.sepal_length);

# %%
sns.factorplot(x="day", y="total_bill", hue="smoker", data=tips);

# %%
sns.factorplot(x="time", y="total_bill", hue="smoker",
               col="day", data=tips, kind="box", size=4, aspect=.5);

# %%
g = sns.PairGrid(tips,
                 x_vars=["smoker", "time", "sex"],
                 y_vars=["total_bill", "tip"],
                 aspect=.75, size=3.5)
g.map(sns.violinplot, palette="pastel");

# %%
sns.factorplot(x="day", y="total_bill", hue="smoker",
               col="time", data=tips, kind="swarm");
