# %%
import pandas as pd

# %% [markdown]
# # Week 1

# %%
y = 7
h = 9
l = "glasses of water"
print h-y, l
# Out:
# 2 glasses of water

# %%
6+5
# Out:
# 11

# %%
9-3
# Out:
# 6

# %%
10/5
# Out:
# 2

# %%
38%14
# Out:
# 10

# %%
5/4
# Out:
# 1

# %%
6//8
# Out:
# 0

# %%
t = 6
t < 9
# Out:
# True

# %%
t >= 4
# Out:
# True

# %%
t != 6
# Out:
# False

# %%
print int("1101",2)
# Out:
# 13

# %%
print round(3.87656,3)
# Out:
# 3.877

# %%
print isinstance(4.5, int)
# Out:
# False

# %%
print cmp(4,10)
print cmp (10,6)
print cmp (12,12)
# Out:
# -1
# 1
# 0

# %%
print pow (23,8)
# Out:
# 78310985281

# %%
print range (6)
print range (2,10)
print range (3,54,12)
# Out:
# [0, 1, 2, 3, 4, 5]
# [2, 3, 4, 5, 6, 7, 8, 9]
# [3, 15, 27, 39, 51]

# %%
print 'hello'
print "Hello Hello"
print """Learning Python
Taking it slow"""
# Out:
# hello
# Hello Hello
# Learning Python
# Taking it slow

# %%
xy= 'hello'
z = 'wow'
print xy,z
print xy  +  z
print 'hello %s'%z
# Out:
# hello wow
# hellowow
# hello wow

# %%
a = ['red','blue']
b = ['yellow', 'pink']
c = [a,b]
print c
print a [-1]
print c [1][-2]
# Out:
# [['red', 'blue'], ['yellow', 'pink']]
# blue
# yellow

# %%
color = [1,24,5,76,78,90]
print color[1:3]
print color[:4]
print color[3:]
print len(color)
print min (color)
print max(color)
# Out:
# [24, 5]
# [1, 24, 5, 76]
# [76, 78, 90]
# 6
# 1
# 90

# %%
planets = ['venus','jupiter', 'mars','saturn']
'pluto' in planets
# Out:
# False

# %%
print max(planets, key=len)
print min(planets, key=len)
# Out:
# jupiter
# mars

# %%
host = [3,78,45,78,9,20,89]
host1 = [6,9,34,25]
host.append(host1)
print host
host.extend(host1)
print host
print host.index(78)
host.insert (3, 'yes')
print host
host[3] = 'no'
print host
host.remove ('no')
print host
host.reverse ()
print host
host.sort()
print host
host.sort(reverse= True)
print host
# Out:
# [3, 78, 45, 78, 9, 20, 89, [6, 9, 34, 25]]
# [3, 78, 45, 78, 9, 20, 89, [6, 9, 34, 25], 6, 9, 34, 25]
# 1
# [3, 78, 45, 'yes', 78, 9, 20, 89, [6, 9, 34, 25], 6, 9, 34, 25]
# [3, 78, 45, 'no', 78, 9, 20, 89, [6, 9, 34, 25], 6, 9, 34, 25]
# [3, 78, 45, 78, 9, 20, 89, [6, 9, 34, 25], 6, 9, 34, 25]
# [25, 34, 9, 6, [6, 9, 34, 25], 89, 20, 9, 78, 45, 78, 3]
# [3, 6, 9, 9, 20, 25, 34, 45, 78, 78, 89, [6, 9, 34, 25]]
# [[6, 9, 34, 25], 89, 78, 78, 45, 34, 25, 20, 9, 9, 6, 3]

# %%
numerical1 = [3,4,7,9,23]
numerical2 = numerical1[:]
print numerical2
numerical1.append(43)
print numerical1
print numerical2
# Out:
# [3, 4, 7, 9, 23]
# [3, 4, 7, 9, 23, 43]
# [3, 4, 7, 9, 23]

# %%
random1 = tuple([6,5,7])
random2 = tuple ('python')
print random1
print random2
(r,j,k) = ('randy', 'joan', 'kennedy')
print r, j, k
print random2.count ('o')
print random2.index ('h')
# Out:
# (6, 5, 7)
# ('p', 'y', 't', 'h', 'o', 'n')
# randy joan kennedy
# 1
# 3

# %%
math1 = set([3,4,7,6,9,6,4])
math2 = set ([6,9,20])
print math1
print math2
print math1.union(math2)
math1.add (5)
print math1
print math2.intersection (math1)
print math1.difference (math2)
# Out:
# set([9, 3, 4, 6, 7])
# set([9, 20, 6])
# set([3, 4, 6, 7, 9, 20])
# set([3, 4, 5, 6, 7, 9])
# set([9, 6])
# set([3, 4, 5, 7])

# %%
yes = 2
if yes > 4 :
    print 'hello'
else :
    print 'bye'
# Out:
# bye

# %%
done = 65
notdone = 45
if notdone > done:
    print 'notdone'
elif done > notdone :
    print 'done'
    if done == 65:
        print "It's 65 percent done"
else :
    print 'no clue'
# Out:
# done
# It's 65 percent done

# %%
for h in range(7):
    print h
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
v = 4
while v < 6:
    print 'no'
    v = v + 1
print 'ha'
# Out:
# no
# no
# ha

# %%
new = []
for h in range (1,30,5):
    t = h + 2
    new.append(t)
print new
# Out:
# [3, 8, 13, 18, 23, 28]

# %%
[100 + x for x in range (9,18,1)]
# Out:
# [109, 110, 111, 112, 113, 114, 115, 116, 117]

# %% [markdown]
# # Week 2

# %%
import pandas as pd
import datetime

# %%
dt = datetime.datetime(2010,12,1)
last = datetime.datetime(2010,12,8)
diff = datetime.timedelta (days=1)
dates = []

# %%
while dt < last :
    dates.append(dt.strftime( '%m-%d'))
    dt += diff
print dates
# Out:
# ['12-01', '12-02', '12-03', '12-04', '12-05', '12-06', '12-07']

# %% [markdown]
# The method strftime () converts a tuple to a string as specified by format argument

# %%
d = {'Date': dates, 'Tokyo':[3,4,6,18,7,9,2], 'Paris':[2,-1,0,-4,7,8,9], 'Mumbai':[23,24,30,32,19,20,28] }
print d
# Out:
# {'Date': ['12-01', '12-02', '12-03', '12-04', '12-05', '12-06', '12-07'], 'Paris': [2, -1, 0, -4, 7, 8, 9], 'Mumbai': [23, 24, 30, 32, 19, 20, 28], 'Tokyo': [3, 4, 6, 18, 7, 9, 2]}

# %%
temp = pd.DataFrame(d)
ntemp = temp ['Mumbai']
print ntemp
# Out:
# 0    23
# 1    24
# 2    30
# 3    32
# 4    19
# 5    20
# 6    28
# Name: Mumbai, dtype: int64

# %%
temp = temp.set_index ('Date')
print temp
# Out:
#        Mumbai  Paris  Tokyo
# Date
# 12-01      23      2      3
# 12-02      24     -1      4
# 12-03      30      0      6
# 12-04      32     -4     18
# 12-05      19      7      7
# 12-06      20      8      9
# 12-07      28      9      2

# %%
crime = pd.read_csv('../data/crime.csv')

# %%
crime.tail()
# Out:
#          State   Type of Crime                Crime  Year  Count
# 16417  Wyoming  Property Crime  Motor vehicle theft  2001    696
# 16418  Wyoming  Property Crime  Motor vehicle theft  2002    743
# 16419  Wyoming  Property Crime  Motor vehicle theft  2003    798
# 16420  Wyoming  Property Crime  Motor vehicle theft  2004    799
# 16421  Wyoming  Property Crime  Motor vehicle theft  2005    739

# %%
crime.Crime.value_counts()
# Out:
# Motor vehicle theft                     2346
# Aggravated assault                      2346
# Forcible rape                           2346
# Murder and nonnegligent Manslaughter    2346
# Robbery                                 2346
# Burglary                                2346
# Larceny-theft                           2346
# Name: Crime, dtype: int64

# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
import numpy as np
np.random.seed (12345)
import matplotlib.pyplot as plt
plt.rc ('figure', figsize = (10,6))
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.set_printoptions (precision=4, suppress =True)

# %%
o = pd.Series([2,3,1,9])
print o
# Out:
# 0    2
# 1    3
# 2    1
# 3    9
# dtype: int64

# %%
o2 = pd.Series ([3,9,4,3], index = ['a', 'e', 'y', 'r'])
o2
o2.index
# Out:
# Index([u'a', u'e', u'y', u'r'], dtype='object')

# %%
o2['a']
o2 ['y'] =7
o2 [['a','y','e']]
# Out:
# a    3
# y    7
# e    9
# dtype: int64

# %%
'c' in o2
# Out:
# False

# %%
s1 = {'yellow': 23, 'blue':34 ,'red':65 , 'pink': 3}
o3 = pd.Series(s1)
print o3
# Out:
# blue      34
# pink       3
# red       65
# yellow    23
# dtype: int64

# %%
o3.name= 'font'
o3.index.name= 'color'
print o3
# Out:
# color
# blue      34
# pink       3
# red       65
# yellow    23
# Name: font, dtype: int64

# %%
data = {'color' :['red', 'yellow','blue', 'black'],
        'font' :['sans', 'times', 'comic', 'arial'],
        'size' : [12,4,5,7] }
array = pd.DataFrame (data)
print array
# Out:
#     color   font  size
# 0     red   sans    12
# 1  yellow  times     4
# 2    blue  comic     5
# 3   black  arial     7

# %%
pd.DataFrame (data, columns= ['color', 'size','font'])
# Out:
#     color  size   font
# 0     red    12   sans
# 1  yellow     4  times
# 2    blue     5  comic
# 3   black     7  arial

# %%
array2 = pd.DataFrame (data, columns={'color', 'size', 'font','len'}, 
                       index = ['one', 'two', 'three', 'four'])
array2
array2.columns
# Out:
# Index([u'color', u'font', u'len', u'size'], dtype='object')

# %%
array2 ['color']
array2.font
# Out:
# one       sans
# two      times
# three    comic
# four     arial
# Name: font, dtype: object

# %%
array2.loc['four']
# Out:
# color    black
# font     arial
# len        NaN
# size         7
# Name: four, dtype: object

# %%
array2 ['len'] = 45
array2
array2 ['len']= np.arange (4.)
array2
# Out:
#         color   font  len  size
# one       red   sans  0.0    12
# two    yellow  times  1.0     4
# three    blue  comic  2.0     5
# four    black  arial  3.0     7

# %%
v= pd.Series ([8,7], index= ['two', 'four'])
array2['len'] = v
array2
# Out:
#         color   font  len  size
# one       red   sans  NaN    12
# two    yellow  times  8.0     4
# three    blue  comic  NaN     5
# four    black  arial  7.0     7

# %%
array2 ['dull']=array2.color == 'black'
array2
# Out:
#         color   font  len  size   dull
# one       red   sans  NaN    12  False
# two    yellow  times  8.0     4  False
# three    blue  comic  NaN     5  False
# four    black  arial  7.0     7   True

# %%
array2.T
# Out:
#          one     two  three   four
# color    red  yellow   blue  black
# font    sans   times  comic  arial
# len      NaN       8    NaN      7
# size      12       4      5      7
# dull   False   False  False   True

# %%
r = pd.Series([3,4,8,1], index = ['e', 'k', 'p', 's'])
print r
# Out:
# e    3
# k    4
# p    8
# s    1
# dtype: int64

# %%
r1 = r.reindex(['e', 'k','f','p','s'])
print r1
# Out:
# e    3.0
# k    4.0
# f    NaN
# p    8.0
# s    1.0
# dtype: float64

# %%
d = pd.DataFrame(np.arange(9).reshape ((3,3)), index=['red','yellow','blue'], columns= ['font','size','len'])
print d
# Out:
#         font  size  len
# red        0     1    2
# yellow     3     4    5
# blue       6     7    8

# %%
d.drop (['red'])
# Out:
#         font  size  len
# yellow     3     4    5
# blue       6     7    8

# %%
od =pd.DataFrame(np.arange(16).reshape((4,4)), 
                 index= ['yellow','red','blue','black'], columns=['one', 'two', 'three', 'four'])
od
od['two']
od[['three','one']]
# Out:
#         three  one
# yellow      2    0
# red         6    4
# blue       10    8
# black      14   12

# %%
od < 5
od [od < 5] = 0
print od
# Out:
#         one  two  three  four
# yellow    0    0      0     0
# red       0    5      6     7
# blue      8    9     10    11
# black    12   13     14    15

# %%
a = pd.Series (range(4), index= ['a', 'b', 'c','d'])
a.sort_index()
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
array = np.arange(12.).reshape((3,4))
array
array[1]
array -array [1]
# Out:
# array([[-4., -4., -4., -4.],
#        [ 0.,  0.,  0.,  0.],
#        [ 4.,  4.,  4.,  4.]])

# %% [markdown]
# # Week 3

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
v1= pd.Series([6,9,3,np.nan,2,4])
print v1
print v1[2]
# Out:
# 0    6.0
# 1    9.0
# 2    3.0
# 3    NaN
# 4    2.0
# 5    4.0
# dtype: float64
# 3.0

# %%
v2, v3 = pd.Series(np.random.randn(6)) , pd.Series(np.random.randn(6))
d1 = pd.DataFrame( {'X' : v1, 'Y': v2, 'Z': v3})
print d1
# Out:
#      X         Y         Z
# 0  6.0  0.274992  1.669025
# 1  9.0  0.228913 -0.438570
# 2  3.0  1.352917 -0.539741
# 3  NaN  0.886429  0.476985
# 4  2.0 -2.001637  3.248944
# 5  4.0 -0.371843 -1.021228

# %%
v4 = pd.Series(np.random.randn(8))
d2 = pd.DataFrame( {'X' :v1, 'Y' : v2, 'Z' :v3, 'L': v4})
print d2
# Out:
#           L    X         Y         Z
# 0 -0.577087  6.0  0.274992  1.669025
# 1  0.124121  9.0  0.228913 -0.438570
# 2  0.302614  3.0  1.352917 -0.539741
# 3  0.523772  NaN  0.886429  0.476985
# 4  0.000940  2.0 -2.001637  3.248944
# 5  1.343810  4.0 -0.371843 -1.021228
# 6 -0.713544  NaN       NaN       NaN
# 7 -0.831154  NaN       NaN       NaN

# %%
d3 = pd.DataFrame (np.random.randn(4,5))
print d3
# Out:
#           0         1         2         3         4
# 0  0.862580 -0.010032  0.050009  0.670216  0.852965
# 1 -0.955869 -0.023493 -2.304234 -0.652469 -1.218302
# 2 -1.332610  1.074623  0.723642  0.690002  1.001543
# 3 -0.503087 -0.622274 -0.921169 -0.726213  0.222896

# %%
d3.head(2)
# Out:
#           0         1         2         3         4
# 0  0.862580 -0.010032  0.050009  0.670216  0.852965
# 1 -0.955869 -0.023493 -2.304234 -0.652469 -1.218302

# %%
c = ['X', 'Y', 'Z', 'E', 'F']
d3.columns = c
dat = pd.date_range(start= '2010-12-13 15:43:12', freq='w', periods= 4)
d3.index = dat
print d3
# Out:
#                             X         Y         Z         E         F
# 2010-12-19 15:43:12  0.862580 -0.010032  0.050009  0.670216  0.852965
# 2010-12-26 15:43:12 -0.955869 -0.023493 -2.304234 -0.652469 -1.218302
# 2011-01-02 15:43:12 -1.332610  1.074623  0.723642  0.690002  1.001543
# 2011-01-09 15:43:12 -0.503087 -0.622274 -0.921169 -0.726213  0.222896

# %%
d3.loc['2010-12-19 15:43:12', 'E']
# Out:
# 0.67021559435025357

# %%
gnacs_x = "id|postedTime|body|None|['twitter_entiteis:urls:url']|['None']|['actor:languages_list-items']|gnip:language:value|twitter_lang|[u'geo:coordinates_list-items']|geo:type|None|None|None|None|actor:utcOffset|None|None|None|None|None|None|None|None|None|actor:displayName|actor:preferredUsername|actor:id|gnip:klout_score|actor:followersCount|actor:friendsCount|actor:listedCount|actor:statusesCount|Tweet|None|None|None"
colnames = gnacs_x.split('|')

# %%
pd.set_option("display.max_columns", None)
d1= pd.read_csv ('../data/twitter_sample.csv',sep = '|', names= colnames)
d1.tail (7)
# Out:
#                                                 id                postedTime  \
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 88                             @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# ...

# %%
print d1.drop( [u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10', u'None.11', u'None.12', u'None.13'],axis=1).columns
# Out:
# Index([u'id', u'postedTime', u'body', u'['twitter_entiteis:urls:url']',
#        u'['None']', u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
#        u'None.1', u'None.2', u'None.3', u'None.4', u'actor:utcOffset',
#        u'actor:displayName', u'actor:preferredUsername', u'actor:id',
#        u'gnip:klout_score', u'actor:followersCount', u'actor:friendsCount',
#        u'actor:listedCount', u'actor:statusesCount', u'Tweet', u'None.14',
#        u'None.15', u'None.16'],
#       dtype='object')

# %%
d1.tail(6)
# Out:
#                                                 id                postedTime  \
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  \
# 89           @justinbagdr no, non mi far star meglio.
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...
# 91  Mandei a foto do Piqué e o fc n respondeu até ...
# 92  O matheus André ta me falando aqui , tem quase...
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...
# 94                                           😕 Hmm...
#
# ...

# %%
d1[d1.twitter_lang == 'en'].head()
# Out:
#                                                 id                postedTime  \
# 8   tag:search.twitter.com,2005:351835318028222465  2013-07-01T22:50:51.000Z
# 9   tag:search.twitter.com,2005:351835318346981377  2013-07-01T22:50:51.000Z
# 11  tag:search.twitter.com,2005:351835318024028161  2013-07-01T22:50:51.000Z
# 12  tag:search.twitter.com,2005:351835318497980416  2013-07-01T22:50:51.000Z
# 15  tag:search.twitter.com,2005:351835318724468737  2013-07-01T22:50:51.000Z
#
#                                                  body  \
# 8                                @pafcdan Aww good! X
# 9   Newest hobby: sending videos back and forth of...
# 11                              ~FINALLY OFF OF WORK~
# 12  Rubbing/massaging my feet is like giving me he...
# 15         @Hayley_Brownn Same!!!! Very sad times😞😞😞😞
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 8                           None     None                         ['en']
# ...

# %%
d2 = d1 [["gnip:klout_score","actor:followersCount", "actor:friendsCount", "actor:listedCount"]]
d2.head()
# Out:
#   gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0               35                   178                 129
# 1               32                   144                 215
# 2               18                    37                  54
# 3               50                   438                 174
# 4               21                    12                   6
#
#    actor:listedCount
# 0                  0
# 1                  0
# 2                  0
# 3                  1
# 4                  0

# %%
d2.dtypes
# Out:
# gnip:klout_score        object
# actor:followersCount     int64
# actor:friendsCount       int64
# actor:listedCount        int64
# dtype: object

# %%
def floatify (v) :
    if v == None or v == 'None' :
        return 0.0
    else :
        return float (v)
d2['gnip:klout_score'] = d2 ['gnip:klout_score'].map(floatify)
d2.dtypes
# Out:
# gnip:klout_score        float64
# actor:followersCount    float64
# actor:friendsCount      float64
# actor:listedCount       float64
# fo/fr                   float64
# dtype: object

# %%
d2 = d2.astype (float)
d2.dtypes
# Out:
# gnip:klout_score        float64
# actor:followersCount    float64
# actor:friendsCount      float64
# actor:listedCount       float64
# fo/fr                   float64
# dtype: object

# %%
d2['fo/fr'] = d2['gnip:klout_score'] / d2['actor:followersCount']
d2.head()
# Out:
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0              35.0                 178.0               129.0
# 1              32.0                 144.0               215.0
# 2              18.0                  37.0                54.0
# 3              50.0                 438.0               174.0
# 4              21.0                  12.0                 6.0
#
#    actor:listedCount     fo/fr
# 0                0.0  0.196629
# 1                0.0  0.222222
# 2                0.0  0.486486
# 3                1.0  0.114155
# 4                0.0  1.750000

# %%
d1.head()
# Out:
#                                                id                postedTime  \
# 0  tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1  tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 2  tag:search.twitter.com,2005:351835317747191808  2013-07-01T22:50:51.000Z
# 3  tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 4  tag:search.twitter.com,2005:351835317755592705  2013-07-01T22:50:51.000Z
#
#                                                 body  \
# 0                         kavga edelim ama konuşalım
# 1                              @shane_joersz wooooow
# 2                           お前との肌のふれあいなんぞ求めてない。自重しろ。
# 3  @Gabo_navoficial yo tambien creo en ti mi char...
# 4  только ты об этом не знаешь... http://t.co/MOH...
#
#   ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 0                          None     None                         ['tr']
# ...

# %%
d1.dtypes
# Out:
# id                                 object
# postedTime                         object
# body                               object
# ['twitter_entiteis:urls:url']      object
# ['None']                           object
# ['actor:languages_list-items']     object
# gnip:language:value                object
# twitter_lang                       object
# [u'geo:coordinates_list-items']    object
# geo:type                           object
#                                     ...
# actor:id                            int64
# gnip:klout_score                   object
# actor:followersCount                int64
# actor:friendsCount                  int64
# actor:listedCount                   int64
# actor:statusesCount                 int64
# Tweet                              object
# None.14                            object
# None.15                            object
# None.16                            object
# Length: 36, dtype: object

# %%
l_b = d1[['twitter_lang',\
             'gnip:klout_score',\
             'actor:followersCount',\
             'actor:friendsCount',\
             'actor:statusesCount']].groupby('twitter_lang')

l_b.head (1)
# Out:
#    twitter_lang gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0            tr               35                   178                 129
# 1            es               32                   144                 215
# 2            ja               18                    37                  54
# 4            ru               21                    12                   6
# 6            pt               42                   247                  64
# 8            en               38                   380                 860
# 16          und               53                  1179                 628
# 18           he               37                   151                 284
# 20           it               46                  1999                 293
# 22           id               43                   258                 302
# 24           pl               48                  2037                1984
# ...

# %% [markdown]
# Did not use the filter to get the popular accounts since there seemed to be an issue with input types and while trying to convert the klout scores - an error was generated saying that input types don't match to run the filter - hence for now just went about grouping data based on the data assigned to d1 alone

# %%
l_b_m = l_b.aggregate(np.mean)  
l_b_m.head()
# Out:
#               actor:followersCount  actor:friendsCount  actor:statusesCount
# twitter_lang
# ar                      458.000000          413.000000          1061.000000
# da                       58.000000           92.000000          1117.000000
# en                     1572.282051          520.128205         14384.307692
# es                     1273.733333          421.066667          8404.666667
# fr                       96.333333           86.000000          4309.666667

# %%
l_b_m['actor:followersCount'].plot(kind='bar', color='g')

# %%
plt.scatter(x=l_b_m['actor:followersCount'],\
            y=l_b_m['actor:friendsCount'],\
            alpha=0.5,\
            s=50,\
            color='red',\
            marker='o')

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(l_b_m, alpha=0.5, figsize=(12,12), diagonal='kde', s=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efd44cddf50>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7efd449b8c50>]], dtype=object)

# %%
d = pd.DataFrame(np.random.randn(1000, 4), index=pd.date_range('1/1/2000', periods=1000), columns=list('XYZL'))
d = d.cumsum()
d.head()
# Out:
#                    X         Y         Z         L
# 2000-01-01  0.051316 -1.157719  0.816707  0.433610
# 2000-01-02  1.062053  0.667156 -0.180811  1.284201
# 2000-01-03  0.930475  1.579570  0.007399  3.453662
# 2000-01-04  0.815547  3.583267  0.037010  4.248915
# 2000-01-05  0.933657  2.834736  0.621979  4.401592

# %%
d.plot()
d.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efd3c517850>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7efd3c3bd750>]], dtype=object)

# %%
import prettyplotlib

d.plot()
d.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efd3c04bf90>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7efd3be76ed0>]], dtype=object)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "distributions")))

# %%
x = np.random.normal(size=50)
sns.distplot(x);

# %%
sns.distplot(x, bins= 10, kde=False, rug=True);

# %%
sns.distplot(x, hist=False, rug=True);

# %%
x = np.random.normal(0, 1, size= 20)
bandwidth = 1.06 * x.std() * x.size ** (-1 / 5.)
support = np.linspace(-4, 4, 200)

kernels = []
for x_i in x:

    kernel = stats.norm(x_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel, color="r")

sns.rugplot(x, color=".2", linewidth=3);

# %%
density = np.sum(kernels, axis=0)
density /= integrate.trapz(density, support)
plt.plot(support, density);

# %%
sns.kdeplot(x, shade=True);

# %%
sns.kdeplot(x)
sns.kdeplot(x, bw=.3, label="bw: 0.2")
sns.kdeplot(x, bw=5, label="bw: 2")
plt.legend();

# %%
sns.kdeplot(x, shade=True, cut=0)
sns.rugplot(x);

# %%
x = np.random.gamma(6, size=200)
sns.distplot(x, kde=False, fit=stats.gamma);

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
d8 = pd.DataFrame(data, columns=["a", "b"])

# %%
sns.jointplot(x="a", y="b", data=d8);

# %%
x, y = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style("white"):
    sns.jointplot(x=x, y=y, kind="hex", color="k");

# %%
sns.jointplot(x="a", y="b", data=d8, kind="kde");

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(d8.a, d8.b, ax=ax)
sns.rugplot(d8.a, color="g", ax=ax)
sns.rugplot(d8.b, vertical=True, ax=ax);

# %%
f, ax = plt.subplots(figsize=(6, 6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(d8.a, d8.b, cmap=cmap, n_levels=60, shade=True);

# %%
g = sns.jointplot(x="a", y="b", data=d8, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$A$", "$B$");

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris);

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, cmap="Blues_d", n_levels=6);
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "regression")))

# %%
tips = sns.load_dataset("tips")

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips, x_jitter=.1);

# %%
sns.lmplot(x="size", y="tip", data=tips, x_estimator=np.mean);

# %%
anscombe = sns.load_dataset("anscombe")
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'I'"),
           ci=None, scatter_kws={"s": 80});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"),
           ci=None, scatter_kws={"s": 80});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"),
           order=2, ci=None, scatter_kws={"s": 80});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'III'"),
           ci=None, scatter_kws={"s": 80});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'III'"),
           robust=True, ci=None, scatter_kws={"s": 80});

# %%
tips["big_tip"] = (tips.tip / tips.total_bill) > .15
sns.lmplot(x="total_bill", y="big_tip", data=tips,
           y_jitter=.03);

# %%
sns.lmplot(x="total_bill", y="big_tip", data=tips,
           logistic=True, y_jitter=.03);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips,
           lowess=True);

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'I'"),
              scatter_kws={"s": 80});

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'II'"),
              scatter_kws={"s": 80});

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="time", data=tips);

# %%
f, ax = plt.subplots(figsize=(7, 6))
sns.regplot(x="total_bill", y="tip", data=tips, ax=ax);

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");

# %%
sns.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"],
             hue="smoker", size=5, aspect=.8, kind="reg");

# %%
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
np.random.seed(sum(map(ord, "categorical")))

# %%
titanic = sns.load_dataset("titanic")
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %%
sns.stripplot(x="day", y="total_bill", data=tips);

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True);

# %%
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips);

# %%
sns.boxplot(x="day", y="total_bill", hue="time", data=tips);

# %%
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
sns.boxplot(x="day", y="total_bill", hue="weekend", data=tips, dodge=False);

# %%
sns.violinplot(x="total_bill", y="day", hue="time", data=tips,
               bw=.1, scale="count", scale_hue=False);

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
sns.swarmplot(x="day", y="total_bill", data=tips, color="w", alpha=.5);

# %%
sns.barplot(x="sex", y="survived", hue="class", data=titanic);

# %%
sns.pointplot(x="sex", y="survived", hue="class", data=titanic);

# %%
sns.boxplot(data=iris, orient="h");

# %%
f, ax = plt.subplots(figsize=(7, 3))
sns.countplot(y="deck", data=titanic, color="c");

# %%
sns.factorplot(x="day", y="total_bill", hue="smoker", data=tips);

# %%
sns.factorplot(x="time", y="total_bill", hue="smoker",
               col="day", data=tips, kind="box", size=4, aspect=.5);

# %%
g = sns.PairGrid(tips,
                 x_vars=["smoker", "time", "sex"],
                 y_vars=["total_bill", "tip"],
                 aspect=.75, size=3.5)
g.map(sns.violinplot, palette="pastel");
