# %% [markdown]
# # Week 3 Notebook
#
# # Student Name: Ho Chuen Choi (Jarrod)
# # Student Number: 301932
#
# # Date : Jan 31st 2018

# %%
# %matplotlib inline
# import naming conventions 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

# (further reading on mpl imports: http://bit.ly/197aGoq )

# %% [markdown]
# # part 2: data

# %%
gnacs_x = "id|postedTime|body|None|['twitter_entiteis:urls:url']|['None']|['actor:languages_list-items']|gnip:language:value|twitter_lang|[u'geo:coordinates_list-items']|geo:type|None|None|None|None|actor:utcOffset|None|None|None|None|None|None|None|None|None|actor:displayName|actor:preferredUsername|actor:id|gnip:klout_score|actor:followersCount|actor:friendsCount|actor:listedCount|actor:statusesCount|Tweet|None|None|None"
colnames = gnacs_x.split('|')

# %%
# prevent the automatic compression of wide dataframes (add scroll bar)
pd.set_option("display.max_columns", None)

# get some data, inspect
df0= pd.read_csv('./Data/twitter_sample.csv', sep='|', names=colnames)

df0.tail(7)
# Out:
#                                                 id                postedTime  \
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 88                             @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# 92  O matheus André ta me falando aqui , tem quase...  None
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...  None
# 94                                           😕 Hmm...  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 88                          None     None                         ['en']
# 89                          None     None                         ['it']
# 90                          None     None                         ['it']
# 91                          None     None                         ['pt']
# 92                          None     None                         ['pt']
# 93                          None     None                         ['en']
# 94                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 88                  en           vi      [53.28722009, -3.21569687]    Point
# 89                  it           it                            None     None
# 90                  it           it          [41.73604, 12.2890263]    Point
# 91                  pt           pt                            None     None
# 92                  pt           pt    [-22.72046574, -43.57919689]    Point
# 93                  en           en       [52.21599153, 6.88528201]    Point
# 94                None           en     [42.21746118, -78.03367083]    Point
#
#                                                None.1   None.2  \
# 88  ['[-3.400604, 53.072143999999994]', '[-3.40060...  Polygon
# 89  ['[14.1332005, 40.7920697]', '[14.1332005, 40....  Polygon
# 90  ['[12.2344266, 41.6558738]', '[12.2344266, 42....  Polygon
# 91  ['[-50.899727999999996, -21.454719]', '[-50.89...  Polygon
# 92  ['[-43.645123999999996, -22.783967999999998]',...  Polygon
# 93  ['[6.7559955, 52.1611799]', '[6.7559955, 52.28...  Polygon
# 94  ['[-78.045887, 42.212985]', '[-78.045887, 42.2...  Polygon
#
#                        None.3 None.4 actor:utcOffset  \
# 88     Flintshire, Flintshire     GB               0
# 89             Napoli, Napoli     IT            None
# 90                 Roma, Roma     IT            7200
# 91       Araçatuba, São Paulo     BR          -10800
# 92  Queimados, Rio de Janeiro     BR          -10800
# 93                   Enschede     NL            3600
# 94                Belmont, NY     US            None
#
#                            None.5 None.6 None.7 None.8 None.9 None.10 None.11  \
# 88  Leeds- UK / Greenfield- Wales   None   None   None   None    None    None
# 89         #bagdr @limitdemibagdr   None   None   None   None    None    None
# 90                  Big Ben's tip   None   None   None   None    None    None
# 91             na cama do mari :p   None   None   None   None    None    None
# 92                 Rio de Janeiro   None   None   None   None    None    None
# 93           Netherlands\Enschede   None   None   None   None    None    None
# 94                           None   None   None   None   None    None    None
#
#    None.12 None.13    actor:displayName actor:preferredUsername    actor:id  \
# 88    None    None              marshaa            marshaleighm   269323425
# 89    None    None                demi.               demibagdr  1542203100
# 90    None    None     She's my Louis ❤            xliamsdreams   562092674
# 91    None    None         lorena uai ∞            Fc_GritaAmor   397609113
# 92    None    None              Shelyda             ShelydaDays    70959019
# 93    None    None                    L                Karkooba  1252736376
# 94    None    None  Lindsey Chamberlain             Linnyy_Kayy   466042520
#
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 88               44                   767                 486
# 89               44                    64                  58
# 90               53                  5084                3802
# 91               44                  1248                1962
# 92               40                   128                  76
# 93               30                    48                  88
# 94               41                   198                 188
#
#     actor:listedCount  actor:statusesCount  Tweet  \
# 88                  0                17549  Reply
# 89                  0                 1872  Reply
# 90                 11                30163  Reply
# 91                  0                11161  Tweet
# 92                  0                 1419  Tweet
# 93                  0                  957  Reply
# 94                  0                 1897  Tweet
#
#                                               None.14 None.15 None.16
# 88  http://twitter.com/CheniseFowlisX/statuses/351...    None    None
# 89  http://twitter.com/justinbagdr/statuses/351833...    None    None
# 90  http://twitter.com/xhazzasdimples/statuses/351...    None    None
# 91                                               None    None    None
# 92                                               None    None    None
# 93  http://twitter.com/Mulayhim/statuses/351817617...    None    None
# 94                                               None    None    None

# %%
# n.b.: this is an *in-place* delete -- unusual for a pandas structure
print df0.columns
print df0.drop( [u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10',
       u'None.11', u'None.12', u'None.13'],axis=1).columns
# Out:
# Index([u'id', u'postedTime', u'body', u'None',
#        u'['twitter_entiteis:urls:url']', u'['None']',
#        u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
#        u'None.1', u'None.2', u'None.3', u'None.4', u'actor:utcOffset',
#        u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10',
#        u'None.11', u'None.12', u'None.13', u'actor:displayName',
#        u'actor:preferredUsername', u'actor:id', u'gnip:klout_score',
#        u'actor:followersCount', u'actor:friendsCount', u'actor:listedCount',
#        u'actor:statusesCount', u'Tweet', u'None.14', u'None.15', u'None.16'],
#       dtype='object')
# Index([u'id', u'postedTime', u'body', u'None',
#        u'['twitter_entiteis:urls:url']', u'['None']',
#        u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
#        u'None.1', u'None.2', u'None.3', u'None.4', u'actor:utcOffset',
#        u'actor:displayName', u'actor:preferredUsername', u'actor:id',
#        u'gnip:klout_score', u'actor:followersCount', u'actor:friendsCount',
#        u'actor:listedCount', u'actor:statusesCount', u'Tweet', u'None.14',
#        u'None.15', u'None.16'],
#       dtype='object')

# %%
# have a peek
df0.tail(6)
# Out:
#                                                 id                postedTime  \
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# 92  O matheus André ta me falando aqui , tem quase...  None
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...  None
# 94                                           😕 Hmm...  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 89                          None     None                         ['it']
# 90                          None     None                         ['it']
# 91                          None     None                         ['pt']
# 92                          None     None                         ['pt']
# 93                          None     None                         ['en']
# 94                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 89                  it           it                            None     None
# 90                  it           it          [41.73604, 12.2890263]    Point
# 91                  pt           pt                            None     None
# 92                  pt           pt    [-22.72046574, -43.57919689]    Point
# 93                  en           en       [52.21599153, 6.88528201]    Point
# 94                None           en     [42.21746118, -78.03367083]    Point
#
#                                                None.1   None.2  \
# 89  ['[14.1332005, 40.7920697]', '[14.1332005, 40....  Polygon
# 90  ['[12.2344266, 41.6558738]', '[12.2344266, 42....  Polygon
# 91  ['[-50.899727999999996, -21.454719]', '[-50.89...  Polygon
# 92  ['[-43.645123999999996, -22.783967999999998]',...  Polygon
# 93  ['[6.7559955, 52.1611799]', '[6.7559955, 52.28...  Polygon
# 94  ['[-78.045887, 42.212985]', '[-78.045887, 42.2...  Polygon
#
#                        None.3 None.4 actor:utcOffset                  None.5  \
# 89             Napoli, Napoli     IT            None  #bagdr @limitdemibagdr
# 90                 Roma, Roma     IT            7200           Big Ben's tip
# 91       Araçatuba, São Paulo     BR          -10800      na cama do mari :p
# 92  Queimados, Rio de Janeiro     BR          -10800          Rio de Janeiro
# 93                   Enschede     NL            3600    Netherlands\Enschede
# 94                Belmont, NY     US            None                    None
#
#    None.6 None.7 None.8 None.9 None.10 None.11 None.12 None.13  \
# 89   None   None   None   None    None    None    None    None
# 90   None   None   None   None    None    None    None    None
# 91   None   None   None   None    None    None    None    None
# 92   None   None   None   None    None    None    None    None
# 93   None   None   None   None    None    None    None    None
# 94   None   None   None   None    None    None    None    None
#
#       actor:displayName actor:preferredUsername    actor:id gnip:klout_score  \
# 89                demi.               demibagdr  1542203100               44
# 90     She's my Louis ❤            xliamsdreams   562092674               53
# 91         lorena uai ∞            Fc_GritaAmor   397609113               44
# 92              Shelyda             ShelydaDays    70959019               40
# 93                    L                Karkooba  1252736376               30
# 94  Lindsey Chamberlain             Linnyy_Kayy   466042520               41
#
#     actor:followersCount  actor:friendsCount  actor:listedCount  \
# 89                    64                  58                  0
# 90                  5084                3802                 11
# 91                  1248                1962                  0
# 92                   128                  76                  0
# 93                    48                  88                  0
# 94                   198                 188                  0
#
#     actor:statusesCount  Tweet  \
# 89                 1872  Reply
# 90                30163  Reply
# 91                11161  Tweet
# 92                 1419  Tweet
# 93                  957  Reply
# 94                 1897  Tweet
#
#                                               None.14 None.15 None.16
# 89  http://twitter.com/justinbagdr/statuses/351833...    None    None
# 90  http://twitter.com/xhazzasdimples/statuses/351...    None    None
# 91                                               None    None    None
# 92                                               None    None    None
# 93  http://twitter.com/Mulayhim/statuses/351817617...    None    None
# 94                                               None    None    None

# %% [markdown]
# ## slicing & combining

# %%
# inspect those rows with twitter-classified lang 'en' (scroll the right to see)
df0[df0.twitter_lang == 'en'].head()

# the colons in the column name below won't allow dot-access to the column, so we can quote them and still filter.
#df0[df0["gnip:language:value"] == 'en'].head()
# Out:
#                                                 id                postedTime  \
# 8   tag:search.twitter.com,2005:351835318028222465  2013-07-01T22:50:51.000Z
# 9   tag:search.twitter.com,2005:351835318346981377  2013-07-01T22:50:51.000Z
# 11  tag:search.twitter.com,2005:351835318024028161  2013-07-01T22:50:51.000Z
# 12  tag:search.twitter.com,2005:351835318497980416  2013-07-01T22:50:51.000Z
# 15  tag:search.twitter.com,2005:351835318724468737  2013-07-01T22:50:51.000Z
#
#                                                  body  None  \
# 8                                @pafcdan Aww good! X  None
# 9   Newest hobby: sending videos back and forth of...  None
# 11                              ~FINALLY OFF OF WORK~  None
# 12  Rubbing/massaging my feet is like giving me he...  None
# 15         @Hayley_Brownn Same!!!! Very sad times😞😞😞😞  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 8                           None     None                         ['en']
# 9                           None     None                         ['en']
# 11                          None     None                         ['en']
# 12                          None     None                         ['en']
# 15                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 8                   en           en        [50.3582949, -4.0930973]    Point
# 9                   en           en     [29.54588264, -95.10669141]    Point
# 11                  en           en           [32.86107, -83.72062]    Point
# 12                  en           en     [33.68890281, -84.27369741]    Point
# 15                  en           en       [54.6884467, -3.51776393]    Point
#
#                                                None.1   None.2  \
# 8   ['[-4.209496, 50.3320883]', '[-4.209496, 50.44...  Polygon
# 9   ['[-95.145152, 29.506973]', '[-95.145152, 29.5...  Polygon
# 11  ['[-83.739741, 32.765651]', '[-83.739741, 32.8...  Polygon
# 12  ['[-85.605165, 30.355756999999997]', '[-85.605...  Polygon
# 15  ['[-3.580063, 54.454108]', '[-3.580063, 54.964...  Polygon
#
#                 None.3 None.4 actor:utcOffset          None.5 None.6 None.7  \
# 8   Plymouth, Plymouth     GB               0        Plymouth   None   None
# 9          Webster, TX     US            None  Houston, Texas   None   None
# 11           Macon, GA     US            None            None   None   None
# 12         Georgia, US     US          -18000          Atl...   None   None
# 15  Allerdale, Cumbria     GB          -36000            None   None   None
#
#    None.8 None.9 None.10 None.11 None.12 None.13 actor:displayName  \
# 8    None   None    None    None    None    None           Becky ❤
# 9    None   None    None    None    None    None       lil beyoncé
# 11   None   None    None    None    None    None    Tomeisha Cross
# 12   None   None    None    None    None    None          Poison †
# 15   None   None    None    None    None    None         Karl Hine
#
#    actor:preferredUsername   actor:id gnip:klout_score  actor:followersCount  \
# 8              BeckyLou90x   26568635               38                   380
# 9               beezlebrat  541953037               41                   160
# 11           MISSMEISHA223  242505369               18                   290
# 12              shanbonita   29619102               64                 40543
# 15                KarlHine  402334657               42                   417
#
#     actor:friendsCount  actor:listedCount  actor:statusesCount  Tweet  \
# 8                  860                  0                 3116  Reply
# 9                  135                  0                 4170  Tweet
# 11                 683                  0                  540  Tweet
# 12                 116                486                60465  Tweet
# 15                 259                  1                 5242  Reply
#
#                                               None.14 None.15 None.16
# 8   http://twitter.com/pafcdan/statuses/3518344574...    None    None
# 9                                                None    None    None
# 11                                               None    None    None
# 12                                               None    None    None
# 15  http://twitter.com/Hayley_Brownn/statuses/3518...    None    None

# %% [markdown]
# Let's get a subset of this dataframe that has numerical values so we can eventually do some stuff.

# %%
# create new dataframe from numerical columns
df1 = df0[["gnip:klout_score","actor:followersCount", "actor:friendsCount", "actor:listedCount"]]

df1.head()
# Out:
#   gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0               35                   178                 129
# 1               32                   144                 215
# 2               18                    37                  54
# 3               50                   438                 174
# 4               21                    12                   6
#
#    actor:listedCount
# 0                  0
# 1                  0
# 2                  0
# 3                  1
# 4                  0

# %%
# because I happen to know the answer, let's check data types of the columns...
df1.dtypes
# Out:
# gnip:klout_score        object
# actor:followersCount     int64
# actor:friendsCount       int64
# actor:listedCount        int64
# dtype: object

# %% [markdown]
# The object type means that the column has multiple types of data in it. This is a good opportunity to 'fix' a section of the DataFrame by way of a function & the map() function

# %%
# convert ints / strings to floats, give up on anything else (call it 0.0)
def floatify(val):
    if val == None or val == 'None':
        return 0.0
    else:
        return float(val)

# %%
# assigning to an existing column overwrites that column 
df1['gnip:klout_score'] = df1['gnip:klout_score'].map(floatify)

# check again
df1.dtypes
# Out:
# /bda/app/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# gnip:klout_score        float64
# actor:followersCount      int64
# actor:friendsCount        int64
# actor:listedCount         int64
# dtype: object

# %%
# use all floats just for fun. 
#  this only works if the elements can all be converted to floats (e.g. ints or something python can handle) 
df1 = df1.astype(float)

df1.dtypes
# Out:
# gnip:klout_score        float64
# actor:followersCount    float64
# actor:friendsCount      float64
# actor:listedCount       float64
# dtype: object

# %% [markdown]
# Since they're all numbers now, we can do math and also add new columns to the DataFrame. Combining values from separate columns occurs on a row-by-row basis, as expected.

# %%
# look at some activity ratios - add col to df
df1['fol/fr'] = df1['gnip:klout_score'] / df1['actor:followersCount']

df1.head()

# can also use the built-in describe() method to get quick descriptive stats on the dataframe
#df1.describe()
# Out:
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0              35.0                 178.0               129.0
# 1              32.0                 144.0               215.0
# 2              18.0                  37.0                54.0
# 3              50.0                 438.0               174.0
# 4              21.0                  12.0                 6.0
#
#    actor:listedCount    fol/fr
# 0                0.0  0.196629
# 1                0.0  0.222222
# 2                0.0  0.486486
# 3                1.0  0.114155
# 4                0.0  1.750000

# %% [markdown]
# ## grouping
#
# groupby() is used for the split-apply-combine process. I'm led to believe that this is one of the stronger aspects of `pandas`' approach to DataFrames (versus R's), but haven't yet had a chance to really see the power.

# %%
# back to bigger df, without 'None' cols
df0.head()
# Out:
#                                                id                postedTime  \
# 0  tag:search.twitter.com,2005:351835317671690241  2013-07-01T22:50:51.000Z
# 1  tag:search.twitter.com,2005:351835317604593666  2013-07-01T22:50:51.000Z
# 2  tag:search.twitter.com,2005:351835317747191808  2013-07-01T22:50:51.000Z
# 3  tag:search.twitter.com,2005:351835317608792064  2013-07-01T22:50:51.000Z
# 4  tag:search.twitter.com,2005:351835317755592705  2013-07-01T22:50:51.000Z
#
#                                                 body  \
# 0                         kavga edelim ama konuşalım
# 1                              @shane_joersz wooooow
# 2                           お前との肌のふれあいなんぞ求めてない。自重しろ。
# 3  @Gabo_navoficial yo tambien creo en ti mi char...
# 4  только ты об этом не знаешь... http://t.co/MOH...
#
#                                                 None  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  ['http://twitter.com/ElkaAlb/status/3518353177...
#
#   ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 0                          None     None                         ['tr']
# 1                          None     None                         ['en']
# 2                          None     None                         ['ja']
# 3                          None     None                         ['en']
# 4                          None     None                         ['ru']
#
#   gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 0                  en           tr                            None     None
# 1                  en           es     [47.29088246, -101.0379045]    Point
# 2                  en           ja     [35.70675048, 139.84273005]    Point
# 3                  en           es                            None     None
# 4                  en           ru                            None     None
#
#                                               None.1   None.2         None.3  \
# 0  ['[25.663883, 35.817497]', '[25.663883, 42.109...  Polygon        Türkiye
# 1  ['[-101.043785, 47.275933]', '[-101.043785, 47...  Polygon   Washburn, ND
# 2  ['[139.8332175, 35.6345694444444]', '[139.8332...  Polygon      江戸川区, 東京都
# 3  ['[-80.248663, 25.986366]', '[-80.248663, 26.0...  Polygon  Hollywood, FL
# 4  ['[23.179216999999998, 51.2626423]', '[23.1792...  Polygon        Belarus
#
#   None.4 actor:utcOffset             None.5 None.6 None.7 None.8 None.9  \
# 0     TR            7200               None   None   None   None   None
# 1     US          -21600         sevenohone   None   None   None   None
# 2     JP          -36000                 ちば   None   None   None   None
# 3     US          -14400  hollywood florida   None   None   None   None
# 4     BY            None               None   None   None   None   None
#
#   None.10 None.11 None.12 None.13 actor:displayName actor:preferredUsername  \
# 0    None    None    None    None   Rümeysa Özdemir           uykugibisiyok
# 1    None    None    None    None        cori▲alex.                 CoBerg_
# 2    None    None    None    None              黒い恋人          yamasyoyamasyo
# 3    None    None    None    None             MARIA            maria_e_pena
# 4    None    None    None    None         Элька Алб                 ElkaAlb
#
#      actor:id gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0   248312738               35                   178                 129
# 1    48025164               32                   144                 215
# 2   217987801               18                    37                  54
# 3   461188787               50                   438                 174
# 4  1433828712               21                    12                   6
#
#    actor:listedCount  actor:statusesCount  Tweet  \
# 0                  0                 2028  Tweet
# 1                  0                 4071  Reply
# 2                  0                 3505  Tweet
# 3                  1                17636  Reply
# 4                  0                  145  Tweet
#
#                                              None.14 None.15 None.16
# 0                                               None    None    None
# 1  http://twitter.com/shane_joersz/statuses/35182...    None    None
# 2                                               None    None    None
# 3  http://twitter.com/Gabo_navoficial/statuses/35...    None    None
# 4                                               None    None    None

# %% [markdown]
# Use a groupby to collect all rows by language value, and subsequently use some of the methods available to GroupBy DataFrames. Note that the GroupBy methods will only act on (and the method call only return) values for columns where numerical calculation makes sense.

# %%
# subset df, create new df with only 'popular' accounts -- those matching the filter condition given
pop_df = df0[df0["actor:followersCount"] >= 100]

# fix the klout scores again
#pop_df['gnip:klout_score'] = pop_df['gnip:klout_score'].map(floatify)

# in case you need to remind yourself of the dataframe
#pop_df.head()

# use GroupBy methods for stats on each group:
#pop_df.groupby("twitter_lang").size()      # number of elements per group
#pop_df.groupby("twitter_lang").sum()       # sum of elements in each group (obviously doesn't make sense for some cols) 
#pop_df.groupby("twitter_lang").mean()      # algebraic mean of elements per group

# %%
# though this looks like a normal dataframe, the DataFrameGroupBy object has a heirarchical index
#  this means it may not act as you might expect.
lang_gb = pop_df[['twitter_lang',\
             'gnip:klout_score',\
             'actor:followersCount',\
             'actor:friendsCount',\
             'actor:statusesCount']].groupby('twitter_lang')


# note the new index 'twitter_lang' -- in this case, .head(n) returns <= n elements for each index
lang_gb.head(2)  

# see that they type is DataFrameGroupBy object
#lang_gb
# Out:
#    twitter_lang gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0            tr               35                   178                 129
# 1            es               32                   144                 215
# 3            es               50                   438                 174
# 5            tr               41                   226                 346
# 6            pt               42                   247                  64
# 8            en               38                   380                 860
# 9            en               41                   160                 135
# 16          und               53                  1179                 628
# 18           he               37                   151                 284
# 20           it               46                  1999                 293
# 21           pt               43                   137                  89
# 22           id               43                   258                 302
# 24           pl               48                  2037                1984
# 29           id               33                   404                 378
# 33           ko               39                   170                 120
# 38          und               35                   228                 185
# 42           ar               40                   458                 413
# 43           fr               40                   116                 122
# 64           ja               28                   152                 335
# 79           lv               41                   297                 237
# 88           vi               44                   767                 486
# 90           it               53                  5084                3802
#
#     actor:statusesCount
# 0                  2028
# 1                  4071
# 3                 17636
# 5                  7759
# 6                  2438
# 8                  3116
# 9                  4170
# 16                20141
# 18                  641
# 20                60236
# 21                 4047
# 22                 2732
# 24                23240
# 29                 9181
# 33                 1094
# 38                24571
# 42                 1061
# 43                 3174
# 64                 2151
# 79                 5221
# 88                17549
# 90                30163

# %%
# to get a DataFrame object that responds more like I'm used to, create a new one using the 
#   aggregate method, which results in a single-index DataFrame
lang_gb_mean = lang_gb.aggregate(np.mean)  

lang_gb_mean.head()

# verify the single index
#lang_gb_mean.index
# Out:
#               actor:followersCount  actor:friendsCount  actor:statusesCount
# twitter_lang
# ar                      458.000000          413.000000          1061.000000
# en                     1796.147059          582.735294         16364.352941
# es                     1359.285714          441.142857          8953.357143
# fr                      116.000000          122.000000          3174.000000
# he                      151.000000          284.000000           641.000000

# %% [markdown]
# # part 3: plotting

# %%
# .plot() is a pandas wrapper for matplotlib's plt.plot() 
lang_gb_mean['actor:followersCount'].plot(kind='bar', color='g')

# %%
# more base matplotlib 
plt.scatter(x=lang_gb_mean['actor:followersCount'],\
            y=lang_gb_mean['actor:friendsCount'],\
            alpha=0.5,\
            s=50,\
            color='blue',\
            marker='x')

# %%
# now read the docs and copypasta a neat-looking plot
from pandas.plotting import scatter_matrix

scatter_matrix(lang_gb_mean, alpha=0.5, figsize=(12,12), diagonal='kde', s=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0a0bc0be90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0a0ba5a2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0a0ba1bc50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0a0b9e7c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0a0b9335d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0a0b961fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0a0b8b5910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0a0b8d5e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0a0b845cd0>]], dtype=object)

# %% [markdown]
# Finally, a short taste of some other plotting libraries. My munging + plotting skillz in this world are still a work in progress, so I will definitely return to this section with an actual use-case in the future. For now, we'll make up some data for illustrative purposes.

# %%
# make up some data with large-scale patterns and a datetime index
df = pd.DataFrame(np.random.randn(1000, 4), index=pd.date_range('1/1/2011', periods=1000), columns=list('ABCD'))
df = df.cumsum()
df.head()
# Out:
#                    A         B         C         D
# 2011-01-01 -0.082648  0.415547  0.218374  0.187261
# 2011-01-02 -1.209353  0.032960  1.291770  0.094392
# 2011-01-03  0.365818 -0.402609 -0.004736 -0.664939
# 2011-01-04  0.547632  0.050576  0.474032  0.664646
# 2011-01-05 -0.423961 -0.019996 -0.216810  0.219105

# %%
df.plot()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0a038f7e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0a038adb50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0a0387b410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0a0383cd90>]], dtype=object)

# %% [markdown]
# Now, let's use some other matplotlib wrappers to get a sense of how we can make this look a little better....
#
#     prettyplotlib essentially just fixes a bunch of matplotlib settings behind the scenes so your base methods lead to e.g. ColorBrewer palettes. This essentially overwrites the .matplotlibrc settings for this session with palettes and settings that are slightly nicer. The settings will remain until you start a new session.

# %%
import prettyplotlib

df.plot()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0a03526e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0a034de7d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0a03580e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0a034571d0>]], dtype=object)

# %% [markdown]
# # Visualizing the distribution of a dataset

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "distributions")))

# %% [markdown]
# # Plotting univariate distributions

# %%
y = np.random.normal(size=500)
sns.distplot(y);

# %% [markdown]
# Histograms

# %%
sns.distplot(y, kde=False, rug=True);

# %% [markdown]
# Kernel density estimaton

# %%
sns.distplot(y, hist=False, rug=True);

# %% [markdown]
# Fitting parametric distributions

# %%
y = np.random.gamma(6, size=500)
sns.distplot(y, kde=False, fit=stats.gamma);

# %% [markdown]
# # Plotting bivariate distributions

# %%
mean, cov = [0, 1], [(1, .25), (.25, 1)]
data = np.random.multivariate_normal(mean, cov, 500)
df = pd.DataFrame(data, columns=["x1", "y1"])

# %% [markdown]
# Scatterplots

# %%
sns.jointplot(x="x1", y="y1", data=df);

# %% [markdown]
# Hexbin plots

# %%
x, y = np.random.multivariate_normal(mean, cov, 500).T
with sns.axes_style("white"):
    sns.jointplot(x=x, y=y, kind="hex", color="k");

# %% [markdown]
# Kernel density estimation

# %%
sns.jointplot(x="x1", y="y1", data=df, kind="kde");

# %% [markdown]
# # Visualizing pairwise relationships in a dataset

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris);

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels=6);

# %% [markdown]
# # Visualizing linear relationships

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "regression")))

# %%
tips = sns.load_dataset("tips")

# %% [markdown]
# Functions to draw linear regression models

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips, x_jitter=.05);

# %%
sns.lmplot(x="size", y="tip", data=tips, x_estimator=np.mean);

# %% [markdown]
# # Plotting with categorical data

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
titanic = pd.read_csv("./Data/titanic.csv")
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %% [markdown]
# Categorical scatterplots

# %%
sns.stripplot(x="day", y="total_bill", data=tips);

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True);

# %%
sns.swarmplot(x="day", y="total_bill", data=tips);

# %%
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips);

# %%
sns.swarmplot(x="size", y="total_bill", data=tips);

# %%
sns.swarmplot(x="total_bill", y="day", hue="time", data=tips);
