# %%
# %matplotlib inline
# import naming conventions 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s1 = pd.Series([1,2,4,np.nan,7,9])
s1
# Out:
# 0    1.0
# 1    2.0
# 2    4.0
# 3    NaN
# 4    7.0
# 5    9.0
# dtype: float64

# %%
s1[4]
# Out:
# 7.0

# %%
s2, s3 = pd.Series(np.random.randn(6)), pd.Series(np.random.randn(6))
s2
s3
# Out:
# 0    0.945941
# 1    1.395131
# 2   -0.738842
# 3   -0.493720
# 4   -0.523297
# 5   -0.179852
# dtype: float64

# %%
df_1 = pd.DataFrame({'a':s1, 'b':s2, 'c':s3})
df_1
# Out:
#      a         b         c
# 0  1.0  1.445265  0.945941
# 1  2.0  0.847916  1.395131
# 2  4.0  0.489995 -0.738842
# 3  NaN -0.614814 -0.493720
# 4  7.0  0.623442 -0.523297
# 5  9.0 -0.054907 -0.179852

# %%
s4 = pd.Series(np.random.randn(8))
s4
df_1 = pd.DataFrame({'a':s1, 'b':s2, 'c':s3, 'd':s4})
df_1
# Out:
#      a         b         c         d
# 0  1.0  1.445265  0.945941  0.227609
# 1  2.0  0.847916  1.395131  1.405918
# 2  4.0  0.489995 -0.738842  0.112985
# 3  NaN -0.614814 -0.493720  0.118036
# 4  7.0  0.623442 -0.523297 -2.177399
# 5  9.0 -0.054907 -0.179852 -0.170701
# 6  NaN       NaN       NaN -0.374586
# 7  NaN       NaN       NaN -0.455051

# %%
df2 = pd.DataFrame(np.random.randn(6,4))
df2
#print df2
# Out:
#           0         1         2         3
# 0 -0.041274 -1.451707  1.558958  1.012101
# 1  0.949890 -0.544777 -0.503844 -1.732629
# 2  0.535538  1.731656 -0.199197  1.356699
# 3 -0.851322  2.087467  2.184826  0.488251
# 4  1.932565  0.278782  0.160796  1.417690
# 5  0.088252  0.885263  0.441876 -0.731545

# %%
df2.head(3)
# Out:
#           0         1         2         3
# 0 -0.041274 -1.451707  1.558958  1.012101
# 1  0.949890 -0.544777 -0.503844 -1.732629
# 2  0.535538  1.731656 -0.199197  1.356699

# %%
cols = ['a', 'b', 'c', 'd']
df2.columns = cols

# %%
dates = pd.date_range(start='2018-01-28 11:22:33', freq='W', periods=6)
df2.index = dates
df2
# Out:
#                             a         b         c         d
# 2018-01-28 11:22:33 -0.041274 -1.451707  1.558958  1.012101
# 2018-02-04 11:22:33  0.949890 -0.544777 -0.503844 -1.732629
# 2018-02-11 11:22:33  0.535538  1.731656 -0.199197  1.356699
# 2018-02-18 11:22:33 -0.851322  2.087467  2.184826  0.488251
# 2018-02-25 11:22:33  1.932565  0.278782  0.160796  1.417690
# 2018-03-04 11:22:33  0.088252  0.885263  0.441876 -0.731545

# %%
print dates
# Out:
# DatetimeIndex(['2018-01-28 11:22:33', '2018-02-04 11:22:33',
#                '2018-02-11 11:22:33', '2018-02-18 11:22:33',
#                '2018-02-25 11:22:33', '2018-03-04 11:22:33'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
df2.loc['2018-01-28 11:22:33','d']
# Out:
# 1.0121006848466079

# %%
df1 = pd.DataFrame(np.random.randn(6,4), index=list('123456'),columns=list('abcd'))
df1
# Out:
#           a         b         c         d
# 1  1.246342 -0.046090  0.651752  0.708627
# 2  0.848399 -0.393351  0.047899  0.233629
# 3 -0.844961  0.085197  1.463756 -0.134586
# 4  0.461246 -0.231975 -0.801899  0.853481
# 5  0.930585 -1.354516 -2.017017 -0.468617
# 6 -0.361839 -0.392030  0.692607  1.182614

# %%
df1.loc[['3','5'],['a','c']]
df1.loc[['3','5'],'a':'c']
# Out:
#           a         b         c
# 3 -0.844961  0.085197  1.463756
# 5  0.930585 -1.354516 -2.017017

# %%
gnacs_x = "id|postedTime|body|None|['twitter_entiteis:urls:url']|['None']|['actor:languages_list-items']|gnip:language:value|twitter_lang|[u'geo:coordinates_list-items']|geo:type|None|None|None|None|actor:utcOffset|None|None|None|None|None|None|None|None|None|actor:displayName|actor:preferredUsername|actor:id|gnip:klout_score|actor:followersCount|actor:friendsCount|actor:listedCount|actor:statusesCount|Tweet|None|None|None"
colnames = gnacs_x.split('|')
pd.set_option("display.max_columns", None)
df1 = pd.read_csv('../data/twitter_sample.csv', sep='|', names=colnames)
df1.tail(7)
# Out:
#                                                 id                postedTime  \
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 88                            @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# 92  O matheus André ta me falando aqui , tem quase...  None
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...  None
# 94                                          😕 Hmm...  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 88                          None     None                         ['en']
# 89                          None     None                         ['it']
# 90                          None     None                         ['it']
# 91                          None     None                         ['pt']
# 92                          None     None                         ['pt']
# 93                          None     None                         ['en']
# 94                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 88                  en           vi      [53.28722009, -3.21569687]    Point
# 89                  it           it                            None     None
# 90                  it           it          [41.73604, 12.2890263]    Point
# 91                  pt           pt                            None     None
# 92                  pt           pt    [-22.72046574, -43.57919689]    Point
# 93                  en           en       [52.21599153, 6.88528201]    Point
# 94                None           en     [42.21746118, -78.03367083]    Point
#
#                                                None.1   None.2  \
# 88  ['[-3.400604, 53.072143999999994]', '[-3.40060...  Polygon
# 89  ['[14.1332005, 40.7920697]', '[14.1332005, 40....  Polygon
# 90  ['[12.2344266, 41.6558738]', '[12.2344266, 42....  Polygon
# 91  ['[-50.899727999999996, -21.454719]', '[-50.89...  Polygon
# 92  ['[-43.645123999999996, -22.783967999999998]',...  Polygon
# 93  ['[6.7559955, 52.1611799]', '[6.7559955, 52.28...  Polygon
# 94  ['[-78.045887, 42.212985]', '[-78.045887, 42.2...  Polygon
#
#                        None.3 None.4 actor:utcOffset  \
# 88     Flintshire, Flintshire     GB               0
# 89             Napoli, Napoli     IT            None
# 90                 Roma, Roma     IT            7200
# 91       Araçatuba, São Paulo     BR          -10800
# 92  Queimados, Rio de Janeiro     BR          -10800
# 93                   Enschede     NL            3600
# 94                Belmont, NY     US            None
#
#                            None.5 None.6 None.7 None.8 None.9 None.10 None.11  \
# 88  Leeds- UK / Greenfield- Wales   None   None   None   None    None    None
# 89         #bagdr @limitdemibagdr   None   None   None   None    None    None
# 90                  Big Ben's tip   None   None   None   None    None    None
# 91             na cama do mari :p   None   None   None   None    None    None
# 92                 Rio de Janeiro   None   None   None   None    None    None
# 93           Netherlands\Enschede   None   None   None   None    None    None
# 94                           None   None   None   None   None    None    None
#
#    None.12 None.13    actor:displayName actor:preferredUsername    actor:id  \
# 88    None    None              marshaa            marshaleighm   269323425
# 89    None    None                demi.               demibagdr  1542203100
# 90    None    None     She's my Louis ❤            xliamsdreams   562092674
# 91    None    None         lorena uai ∞            Fc_GritaAmor   397609113
# 92    None    None              Shelyda             ShelydaDays    70959019
# 93    None    None                    L                Karkooba  1252736376
# 94    None    None  Lindsey Chamberlain             Linnyy_Kayy   466042520
#
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 88               44                   767                 486
# 89               44                    64                  58
# 90               53                  5084                3802
# 91               44                  1248                1962
# 92               40                   128                  76
# 93               30                    48                  88
# 94               41                   198                 188
#
#     actor:listedCount  actor:statusesCount  Tweet  \
# 88                  0                17549  Reply
# 89                  0                 1872  Reply
# 90                 11                30163  Reply
# 91                  0                11161  Tweet
# 92                  0                 1419  Tweet
# 93                  0                  957  Reply
# 94                  0                 1897  Tweet
#
#                                               None.14 None.15 None.16
# 88  http://twitter.com/CheniseFowlisX/statuses/351...    None    None
# 89  http://twitter.com/justinbagdr/statuses/351833...    None    None
# 90  http://twitter.com/xhazzasdimples/statuses/351...    None    None
# 91                                               None    None    None
# 92                                               None    None    None
# 93  http://twitter.com/Mulayhim/statuses/351817617...    None    None
# 94                                               None    None    None

# %%
print df1.columns
print df1.drop( [u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10',
       u'None.11', u'None.12', u'None.13'],axis=1).columns
# Out:
# Index([u'id', u'postedTime', u'body', u'None',
#        u'['twitter_entiteis:urls:url']', u'['None']',
#        u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
#        u'None.1', u'None.2', u'None.3', u'None.4', u'actor:utcOffset',
#        u'None.5', u'None.6', u'None.7', u'None.8', u'None.9', u'None.10',
#        u'None.11', u'None.12', u'None.13', u'actor:displayName',
#        u'actor:preferredUsername', u'actor:id', u'gnip:klout_score',
#        u'actor:followersCount', u'actor:friendsCount', u'actor:listedCount',
#        u'actor:statusesCount', u'Tweet', u'None.14', u'None.15', u'None.16'],
#       dtype='object')
# Index([u'id', u'postedTime', u'body', u'None',
#        u'['twitter_entiteis:urls:url']', u'['None']',
#        u'['actor:languages_list-items']', u'gnip:language:value',
#        u'twitter_lang', u'[u'geo:coordinates_list-items']', u'geo:type',
#        u'None.1', u'None.2', u'None.3', u'None.4', u'actor:utcOffset',
#        u'actor:displayName', u'actor:preferredUsername', u'actor:id',
#        u'gnip:klout_score', u'actor:followersCount', u'actor:friendsCount',
#        u'actor:listedCount', u'actor:statusesCount', u'Tweet', u'None.14',
#        u'None.15', u'None.16'],
#       dtype='object')

# %%
df1.tail(7)
# Out:
#                                                 id                postedTime  \
# 88  tag:search.twitter.com,2005:351835320297328640  2013-07-01T22:50:51.000Z
# 89  tag:search.twitter.com,2005:351835321220075524  2013-07-01T22:50:52.000Z
# 90  tag:search.twitter.com,2005:351835321081659392  2013-07-01T22:50:51.000Z
# 91  tag:search.twitter.com,2005:351835321442385921  2013-07-01T22:50:52.000Z
# 92  tag:search.twitter.com,2005:351835321425608704  2013-07-01T22:50:52.000Z
# 93  tag:search.twitter.com,2005:351835320859369475  2013-07-01T22:50:51.000Z
# 94  tag:search.twitter.com,2005:351835321471746048  2013-07-01T22:50:52.000Z
#
#                                                  body  None  \
# 88                            @CheniseFowlisX yeah 😂  None
# 89           @justinbagdr no, non mi far star meglio.  None
# 90  @xhazzasdimples Probabile AHAHHAHAHAHAHAHAHAHA...  None
# 91  Mandei a foto do Piqué e o fc n respondeu até ...  None
# 92  O matheus André ta me falando aqui , tem quase...  None
# 93  @Mulayhim hatha bs one exam. Other exams y6l3o...  None
# 94                                          😕 Hmm...  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 88                          None     None                         ['en']
# 89                          None     None                         ['it']
# 90                          None     None                         ['it']
# 91                          None     None                         ['pt']
# 92                          None     None                         ['pt']
# 93                          None     None                         ['en']
# 94                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 88                  en           vi      [53.28722009, -3.21569687]    Point
# 89                  it           it                            None     None
# 90                  it           it          [41.73604, 12.2890263]    Point
# 91                  pt           pt                            None     None
# 92                  pt           pt    [-22.72046574, -43.57919689]    Point
# 93                  en           en       [52.21599153, 6.88528201]    Point
# 94                None           en     [42.21746118, -78.03367083]    Point
#
#                                                None.1   None.2  \
# 88  ['[-3.400604, 53.072143999999994]', '[-3.40060...  Polygon
# 89  ['[14.1332005, 40.7920697]', '[14.1332005, 40....  Polygon
# 90  ['[12.2344266, 41.6558738]', '[12.2344266, 42....  Polygon
# 91  ['[-50.899727999999996, -21.454719]', '[-50.89...  Polygon
# 92  ['[-43.645123999999996, -22.783967999999998]',...  Polygon
# 93  ['[6.7559955, 52.1611799]', '[6.7559955, 52.28...  Polygon
# 94  ['[-78.045887, 42.212985]', '[-78.045887, 42.2...  Polygon
#
#                        None.3 None.4 actor:utcOffset  \
# 88     Flintshire, Flintshire     GB               0
# 89             Napoli, Napoli     IT            None
# 90                 Roma, Roma     IT            7200
# 91       Araçatuba, São Paulo     BR          -10800
# 92  Queimados, Rio de Janeiro     BR          -10800
# 93                   Enschede     NL            3600
# 94                Belmont, NY     US            None
#
#                            None.5 None.6 None.7 None.8 None.9 None.10 None.11  \
# 88  Leeds- UK / Greenfield- Wales   None   None   None   None    None    None
# 89         #bagdr @limitdemibagdr   None   None   None   None    None    None
# 90                  Big Ben's tip   None   None   None   None    None    None
# 91             na cama do mari :p   None   None   None   None    None    None
# 92                 Rio de Janeiro   None   None   None   None    None    None
# 93           Netherlands\Enschede   None   None   None   None    None    None
# 94                           None   None   None   None   None    None    None
#
#    None.12 None.13    actor:displayName actor:preferredUsername    actor:id  \
# 88    None    None              marshaa            marshaleighm   269323425
# 89    None    None                demi.               demibagdr  1542203100
# 90    None    None     She's my Louis ❤            xliamsdreams   562092674
# 91    None    None         lorena uai ∞            Fc_GritaAmor   397609113
# 92    None    None              Shelyda             ShelydaDays    70959019
# 93    None    None                    L                Karkooba  1252736376
# 94    None    None  Lindsey Chamberlain             Linnyy_Kayy   466042520
#
#    gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 88               44                   767                 486
# 89               44                    64                  58
# 90               53                  5084                3802
# 91               44                  1248                1962
# 92               40                   128                  76
# 93               30                    48                  88
# 94               41                   198                 188
#
#     actor:listedCount  actor:statusesCount  Tweet  \
# 88                  0                17549  Reply
# 89                  0                 1872  Reply
# 90                 11                30163  Reply
# 91                  0                11161  Tweet
# 92                  0                 1419  Tweet
# 93                  0                  957  Reply
# 94                  0                 1897  Tweet
#
#                                               None.14 None.15 None.16
# 88  http://twitter.com/CheniseFowlisX/statuses/351...    None    None
# 89  http://twitter.com/justinbagdr/statuses/351833...    None    None
# 90  http://twitter.com/xhazzasdimples/statuses/351...    None    None
# 91                                               None    None    None
# 92                                               None    None    None
# 93  http://twitter.com/Mulayhim/statuses/351817617...    None    None
# 94                                               None    None    None

# %%
df1[df1.twitter_lang == 'en'].head()
# Out:
#                                                 id                postedTime  \
# 8   tag:search.twitter.com,2005:351835318028222465  2013-07-01T22:50:51.000Z
# 9   tag:search.twitter.com,2005:351835318346981377  2013-07-01T22:50:51.000Z
# 11  tag:search.twitter.com,2005:351835318024028161  2013-07-01T22:50:51.000Z
# 12  tag:search.twitter.com,2005:351835318497980416  2013-07-01T22:50:51.000Z
# 15  tag:search.twitter.com,2005:351835318724468737  2013-07-01T22:50:51.000Z
#
#                                                  body  None  \
# 8                                @pafcdan Aww good! X  None
# 9   Newest hobby: sending videos back and forth of...  None
# 11                              ~FINALLY OFF OF WORK~  None
# 12  Rubbing/massaging my feet is like giving me he...  None
# 15     @Hayley_Brownn Same!!!! Very sad times😞😞😞😞  None
#
#    ['twitter_entiteis:urls:url'] ['None'] ['actor:languages_list-items']  \
# 8                           None     None                         ['en']
# 9                           None     None                         ['en']
# 11                          None     None                         ['en']
# 12                          None     None                         ['en']
# 15                          None     None                         ['en']
#
#    gnip:language:value twitter_lang [u'geo:coordinates_list-items'] geo:type  \
# 8                   en           en        [50.3582949, -4.0930973]    Point
# 9                   en           en     [29.54588264, -95.10669141]    Point
# 11                  en           en           [32.86107, -83.72062]    Point
# 12                  en           en     [33.68890281, -84.27369741]    Point
# 15                  en           en       [54.6884467, -3.51776393]    Point
#
#                                                None.1   None.2  \
# 8   ['[-4.209496, 50.3320883]', '[-4.209496, 50.44...  Polygon
# 9   ['[-95.145152, 29.506973]', '[-95.145152, 29.5...  Polygon
# 11  ['[-83.739741, 32.765651]', '[-83.739741, 32.8...  Polygon
# 12  ['[-85.605165, 30.355756999999997]', '[-85.605...  Polygon
# 15  ['[-3.580063, 54.454108]', '[-3.580063, 54.964...  Polygon
#
#                 None.3 None.4 actor:utcOffset          None.5 None.6 None.7  \
# 8   Plymouth, Plymouth     GB               0        Plymouth   None   None
# 9          Webster, TX     US            None  Houston, Texas   None   None
# 11           Macon, GA     US            None            None   None   None
# 12         Georgia, US     US          -18000          Atl...   None   None
# 15  Allerdale, Cumbria     GB          -36000            None   None   None
#
#    None.8 None.9 None.10 None.11 None.12 None.13 actor:displayName  \
# 8    None   None    None    None    None    None           Becky ❤
# 9    None   None    None    None    None    None       lil beyoncé
# 11   None   None    None    None    None    None    Tomeisha Cross
# 12   None   None    None    None    None    None          Poison †
# 15   None   None    None    None    None    None         Karl Hine
#
#    actor:preferredUsername   actor:id gnip:klout_score  actor:followersCount  \
# 8              BeckyLou90x   26568635               38                   380
# 9               beezlebrat  541953037               41                   160
# 11           MISSMEISHA223  242505369               18                   290
# 12              shanbonita   29619102               64                 40543
# 15                KarlHine  402334657               42                   417
#
#     actor:friendsCount  actor:listedCount  actor:statusesCount  Tweet  \
# 8                  860                  0                 3116  Reply
# 9                  135                  0                 4170  Tweet
# 11                 683                  0                  540  Tweet
# 12                 116                486                60465  Tweet
# 15                 259                  1                 5242  Reply
#
#                                               None.14 None.15 None.16
# 8   http://twitter.com/pafcdan/statuses/3518344574...    None    None
# 9                                                None    None    None
# 11                                               None    None    None
# 12                                               None    None    None
# 15  http://twitter.com/Hayley_Brownn/statuses/3518...    None    None

# %%
df2 = df1[["postedTime", "gnip:klout_score","actor:followersCount", "actor:friendsCount", "actor:listedCount"]]
df2.head()
# Out:
#                  postedTime gnip:klout_score  actor:followersCount  \
# 0  2013-07-01T22:50:51.000Z               35                   178
# 1  2013-07-01T22:50:51.000Z               32                   144
# 2  2013-07-01T22:50:51.000Z               18                    37
# 3  2013-07-01T22:50:51.000Z               50                   438
# 4  2013-07-01T22:50:51.000Z               21                    12
#
#    actor:friendsCount  actor:listedCount
# 0                 129                  0
# 1                 215                  0
# 2                  54                  0
# 3                 174                  1
# 4                   6                  0

# %%
df2.dtypes
# Out:
# postedTime              object
# gnip:klout_score        object
# actor:followersCount     int64
# actor:friendsCount       int64
# actor:listedCount        int64
# dtype: object

# %%
def floatify(val):
    if val == None or val == 'None':
        return 0.0
    else:
        return float(val)

# %%
df2['gnip:klout_score'] = df2['gnip:klout_score'].map(floatify)

df2.dtypes
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# postedTime               object
# gnip:klout_score        float64
# actor:followersCount      int64
# actor:friendsCount        int64
# actor:listedCount         int64
# dtype: object

# %%
df2['fol//fr'] = df2['gnip:klout_score'] / df2['actor:followersCount']

df2.head()
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                  postedTime  gnip:klout_score  actor:followersCount  \
# 0  2013-07-01T22:50:51.000Z              35.0                   178
# 1  2013-07-01T22:50:51.000Z              32.0                   144
# 2  2013-07-01T22:50:51.000Z              18.0                    37
# 3  2013-07-01T22:50:51.000Z              50.0                   438
# 4  2013-07-01T22:50:51.000Z              21.0                    12
#
#    actor:friendsCount  actor:listedCount   fol//fr
# 0                 129                  0  0.196629
# 1                 215                  0  0.222222
# 2                  54                  0  0.486486
# 3                 174                  1  0.114155
# 4                   6                  0  1.750000

# %%
pop_df = df1[df1["actor:followersCount"] >= 100]
df1
pop_df.head
lang_gb = pop_df[['twitter_lang',\
             'gnip:klout_score',\
             'actor:followersCount',\
             'actor:friendsCount',\
             'actor:statusesCount']].groupby('twitter_lang')
lang_gb.head(2)
# Out:
#    twitter_lang gnip:klout_score  actor:followersCount  actor:friendsCount  \
# 0            tr               35                   178                 129
# 1            es               32                   144                 215
# 3            es               50                   438                 174
# 5            tr               41                   226                 346
# 6            pt               42                   247                  64
# 8            en               38                   380                 860
# 9            en               41                   160                 135
# 16          und               53                  1179                 628
# 18           he               37                   151                 284
# 20           it               46                  1999                 293
# 21           pt               43                   137                  89
# 22           id               43                   258                 302
# 24           pl               48                  2037                1984
# 29           id               33                   404                 378
# 33           ko               39                   170                 120
# 38          und               35                   228                 185
# 42           ar               40                   458                 413
# 43           fr               40                   116                 122
# 64           ja               28                   152                 335
# 79           lv               41                   297                 237
# 88           vi               44                   767                 486
# 90           it               53                  5084                3802
#
#     actor:statusesCount
# 0                  2028
# 1                  4071
# 3                 17636
# 5                  7759
# 6                  2438
# 8                  3116
# 9                  4170
# 16                20141
# 18                  641
# 20                60236
# 21                 4047
# 22                 2732
# 24                23240
# 29                 9181
# 33                 1094
# 38                24571
# 42                 1061
# 43                 3174
# 64                 2151
# 79                 5221
# 88                17549
# 90                30163

# %%
lang_gb_mean = lang_gb.aggregate(np.mean)  
lang_gb_mean.head()
# Out:
#               actor:followersCount  actor:friendsCount  actor:statusesCount
# twitter_lang
# ar                      458.000000          413.000000          1061.000000
# en                     1796.147059          582.735294         16364.352941
# es                     1359.285714          441.142857          8953.357143
# fr                      116.000000          122.000000          3174.000000
# he                      151.000000          284.000000           641.000000

# %%
lang_gb_mean['actor:followersCount'].plot(kind='bar', color='g')

# %%
plt.scatter(x=lang_gb_mean['actor:followersCount'],\
            y=lang_gb_mean['actor:friendsCount'],\
            alpha=0.5,\
            s=50,\
            color='red',\
            marker='o')

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(lang_gb_mean, alpha=0.5, figsize=(12,12), diagonal='kde', s=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B1222B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E6F09B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E73C550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E7A1160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E84BDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E910550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E974C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EA29E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EB43B00>]], dtype=object)

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=pd.date_range('1/1/2000', periods=1000), columns=list('ABCD'))
df = df.cumsum()
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01 -0.290084  2.094964  0.165290 -0.220582
# 2000-01-02 -0.692753  1.254318  0.940285 -0.141980
# 2000-01-03  1.127837 -0.348395  0.818267 -0.639649
# 2000-01-04  2.020224  0.036535  1.003420  0.276489
# 2000-01-05  1.405537  0.234176 -1.005713 -0.290359

# %%
df.plot()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F2EF550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F3BA1D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F41F4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F306630>]], dtype=object)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))

# %%
x = np.random.normal(size=90)
sns.distplot(x);

# %%
sns.distplot(x, kde=False, rug=True);

# %%
sns.distplot(x, bins=30, kde=False, rug=True);

# %%
sns.distplot(x, hist=False, rug=True);

# %%
x = np.random.normal(0, 1, size=40)
bandwidth = 1.06 * x.std() * x.size ** (-1 / 5.)
support = np.linspace(-3, 4, 220)

kernels = []
for x_i in x:

    kernel = stats.norm(x_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel, color="r")

sns.rugplot(x, color=".3", linewidth=2);

# %%
density = np.sum(kernels, axis=0)
density /= integrate.trapz(density, support)
plt.plot(support, density);

# %%
sns.kdeplot(x, shade=True);

# %%
sns.kdeplot(x)
sns.kdeplot(x, bw=.3, label="bw: 0.3")
sns.kdeplot(x, bw=3, label="bw: 3")
plt.legend();

# %%
sns.kdeplot(x, shade=True, cut=0)
sns.rugplot(x);

# %%
x = np.random.gamma(6, size=300)
sns.distplot(x, kde=False, fit=stats.gamma);

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])
sns.jointplot(x="x", y="y", data=df);

# %%
x, y = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style("dark"):
    sns.jointplot(x=x, y=y, kind="hex", color="k");

# %%
sns.jointplot(x="x", y="y", data=df, kind="kde");

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(df.x, df.y, ax=ax)
sns.rugplot(df.x, color="r", ax=ax)
sns.rugplot(df.y, vertical=True, ax=ax);

# %%
f, ax = plt.subplots(figsize=(3, 3))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(df.x, df.y, cmap=cmap, n_levels=40, shade=True);

# %%
g = sns.jointplot(x="x", y="y", data=df, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$");

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris);

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, cmap="Blues_d", n_levels=6);

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips, x_jitter=.05);

# %%
sns.lmplot(x="size", y="tip", data=tips, x_estimator=np.mean);

# %%
anscombe = sns.load_dataset("anscombe")
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'I'"),
           ci=None, scatter_kws={"s": 60});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"),
           order=2, ci=None, scatter_kws={"s": 50});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'III'"),
           robust=True, ci=None, scatter_kws={"s": 100});

# %%
tips["big_tip"] = (tips.tip / tips.total_bill) > .15
sns.lmplot(x="total_bill", y="big_tip", data=tips,
           y_jitter=.03);

# %%
sns.lmplot(x="total_bill", y="big_tip", data=tips,
           logistic=True, y_jitter=.03);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips,
           lowess=True);

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'I'"),
              scatter_kws={"s": 80});

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'II'"),
              scatter_kws={"s": 80});

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips,
           markers=["o", "x"], palette="Set1");

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="time", data=tips);

# %%
f, ax = plt.subplots(figsize=(5, 6))
sns.regplot(x="total_bill", y="tip", data=tips, ax=ax);

# %%
np.random.seed(sum(map(ord, "categorical")))
titanic = sns.load_dataset("titanic")
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")
sns.stripplot(x="day", y="total_bill", data=tips);

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True);

# %%
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips);

# %%
sns.swarmplot(x="total_bill", y="day", hue="time", data=tips);

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips,
               split=True, inner="stick", palette="Set3");
